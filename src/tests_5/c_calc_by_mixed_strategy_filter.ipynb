# %% [markdown]
# Try to generate different terms with different filtering approaches
# * LO & RI
# * LO & LI & RI & RO
# * Rand

# %%
import random
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
from fitter import Fitter, get_common_distributions
from deap import tools, base, creator
import seaborn as sns

sys.path.append("../")
from calculus.term import *
from calculus.strategy import *
from calculus.generation import *
from calculus.generation_threading import *

from calculus_utils.drawing import *
from calculus_utils.algorithms import *
from calculus_utils.outliers_cleaning import clear_arr

from vd_env.lambda_env import LambdaEnv
from vd_env.run_greedy_policy import run_greedy_policy
from vd_env.run_e_greedy_policy import run_e_greedy_policy

# %% [markdown]
# ## Generating with (LO, RI)-filtering

# %%
RANDOM_AVERAGE_COUNT = 20

terms, steps_mix = gen_filtered_lambda_terms_v2(
    count_terms=100,
    filtering_strategy=MixedStrategy(
        [LeftmostOutermostStrategy(), RightmostOutermostStrategy()], [0.5, 0.5]
    ),
)
stepsRI = [term.normalize(RightmostInnermostStrategy())[1] for term in tqdm(terms)]
stepsLO = [term.normalize(LeftmostOutermostStrategy())[1] for term in tqdm(terms)]
stepsRand = [
    sum(term.normalize(RandomStrategy())[1] for i in range(RANDOM_AVERAGE_COUNT))
    / RANDOM_AVERAGE_COUNT
    for term in tqdm(terms)
]
# Out:
# 100%|██████████| 101/101 [00:10<00:00, 10.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 604.65it/s]
# 100%|██████████| 101/101 [00:03<00:00, 30.62it/s]

# %%
comp_data = {
    "Mixed": (steps_mix, "-"),
    "LO": (stepsLO, "-"),
    "RI": (stepsRI, "-"),
    "Rand": (stepsRand, "-"),
}
draw_cumulative_avg_comparison(comp_data, title="AvgCum steps LO & RI")

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps LO & RI")

# %%
steps_mixed_all = []
expected_values = []
values = list(range(0, 101, 5))
iters = len(values) - 1

for inx, p_lo in enumerate(values):
    p = (p_lo / 100, 1 - p_lo / 100)
    steps = [
        sum(
            [
                term.normalize(
                    MixedStrategy(
                        [LeftmostOutermostStrategy(), RightmostInnermostStrategy()], p
                    )
                )[1]
                for i in range(RANDOM_AVERAGE_COUNT)
            ]
        )
        / RANDOM_AVERAGE_COUNT
        for term in tqdm(terms, desc=f"it {inx} / {iters}")
    ]
    steps_mixed_all.append(steps)
# Out:
# it 0 / 20: 100%|██████████| 101/101 [03:21<00:00,  1.99s/it]
# it 1 / 20: 100%|██████████| 101/101 [00:04<00:00, 22.26it/s]
# it 2 / 20: 100%|██████████| 101/101 [00:03<00:00, 30.97it/s]
# it 3 / 20: 100%|██████████| 101/101 [00:03<00:00, 29.38it/s]
# it 4 / 20: 100%|██████████| 101/101 [00:03<00:00, 25.63it/s]
# it 5 / 20: 100%|██████████| 101/101 [00:04<00:00, 25.19it/s]
# it 6 / 20: 100%|██████████| 101/101 [00:04<00:00, 24.41it/s]
# it 7 / 20: 100%|██████████| 101/101 [00:03<00:00, 25.92it/s]
# it 8 / 20: 100%|██████████| 101/101 [00:04<00:00, 24.87it/s]
# it 9 / 20: 100%|██████████| 101/101 [00:03<00:00, 26.81it/s]
# it 10 / 20: 100%|██████████| 101/101 [00:03<00:00, 27.13it/s]
# it 11 / 20: 100%|██████████| 101/101 [00:03<00:00, 27.11it/s]
# it 12 / 20: 100%|██████████| 101/101 [00:03<00:00, 28.00it/s]
# it 13 / 20: 100%|██████████| 101/101 [00:03<00:00, 29.81it/s]
# it 14 / 20: 100%|██████████| 101/101 [00:03<00:00, 29.10it/s]
# it 15 / 20: 100%|██████████| 101/101 [00:03<00:00, 27.90it/s]
# it 16 / 20: 100%|██████████| 101/101 [00:03<00:00, 28.81it/s]
# it 17 / 20: 100%|██████████| 101/101 [00:03<00:00, 27.35it/s]
# it 18 / 20: 100%|██████████| 101/101 [00:03<00:00, 27.62it/s]
# it 19 / 20: 100%|██████████| 101/101 [00:03<00:00, 28.80it/s]
# it 20 / 20: 100%|██████████| 101/101 [00:03<00:00, 30.53it/s]

# %%
for steps in steps_mixed_all:
    steps = list(filter(lambda x: x != float("inf"), steps))
    steps = list(filter(lambda x: x != 0, steps))

    distributions = get_common_distributions()
    distributions.remove("expon")
    f_ln = Fitter([np.log(step) for step in steps], distributions=distributions)
    f_ln.fit()

    mu, sigma = f_ln.fitted_param["norm"]
    result = np.e ** (mu + (sigma**2) / 2)
    expected_values.append(result)

plt.plot(values, expected_values)
plt.xlabel("p_LO")
plt.ylabel("Expected number of steps")
plt.title("for RO-filtered terms")
plt.show()
# Out:
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 25.93it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.60it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 27.43it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.70it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.08it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.70it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.92it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 34.34it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 36.28it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 35.12it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.83it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 35.29it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.96it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 34.76it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.99it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 31.03it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.70it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 27.52it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.72it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.12it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 30.60it/s]

# %%
inx_best = expected_values.index(min(expected_values))
inx_best
# Out:
# 20

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "Mixed_Best": (clear_arr(steps_mixed_all[inx_best]), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps LO & RI")

# %% [markdown]
# ## Generating with (LO & LI & RI & RO)-filtering

# %%
RANDOM_AVERAGE_COUNT = 20

terms, steps_mix = gen_filtered_lambda_terms_v2(
    count_terms=100,
    filtering_strategy=MixedStrategy(
        [
            LeftmostOutermostStrategy(),
            LeftmostInnermostStrategy(),
            RightmostInnermostStrategy(),
            RightmostOutermostStrategy(),
        ],
        [0.25, 0.25, 0.25, 0.25],
    ),
)
stepsRI = [term.normalize(RightmostInnermostStrategy())[1] for term in tqdm(terms)]
stepsLO = [term.normalize(LeftmostOutermostStrategy())[1] for term in tqdm(terms)]
stepsRand = [
    sum(term.normalize(RandomStrategy())[1] for i in range(RANDOM_AVERAGE_COUNT))
    / RANDOM_AVERAGE_COUNT
    for term in tqdm(terms)
]
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 80.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 534.63it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.37it/s]

# %%
comp_data = {
    "Mixed": (steps_mix, "-"),
    "LO": (stepsLO, "-"),
    "RI": (stepsRI, "-"),
    "Rand": (stepsRand, "-"),
}
draw_cumulative_avg_comparison(comp_data, title="AvgCum steps LO, LI, RI, RO")

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps LO, LI, RI, RO")

# %%
steps_mixed_all = []
expected_values = []
values = list(range(0, 101, 5))
iters = len(values) - 1

for inx, p_lo in enumerate(values):
    p = (p_lo / 100, 1 - p_lo / 100)
    steps = [
        sum(
            [
                term.normalize(
                    MixedStrategy(
                        [LeftmostOutermostStrategy(), RightmostInnermostStrategy()], p
                    )
                )[1]
                for i in range(RANDOM_AVERAGE_COUNT)
            ]
        )
        / RANDOM_AVERAGE_COUNT
        for term in tqdm(terms, desc=f"it {inx} / {iters}")
    ]
    steps_mixed_all.append(steps)
# Out:
# it 0 / 20: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
# it 1 / 20: 100%|██████████| 100/100 [00:05<00:00, 17.01it/s]
# it 2 / 20: 100%|██████████| 100/100 [00:11<00:00,  8.95it/s]
# it 3 / 20: 100%|██████████| 100/100 [00:08<00:00, 11.61it/s]
# it 4 / 20: 100%|██████████| 100/100 [00:05<00:00, 18.70it/s]
# it 5 / 20: 100%|██████████| 100/100 [00:05<00:00, 19.39it/s]
# it 6 / 20: 100%|██████████| 100/100 [00:05<00:00, 19.46it/s]
# it 7 / 20: 100%|██████████| 100/100 [00:04<00:00, 21.80it/s]
# it 8 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.28it/s]
# it 9 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.29it/s]
# it 10 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.64it/s]
# it 11 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.93it/s]
# it 12 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.73it/s]
# it 13 / 20: 100%|██████████| 100/100 [00:03<00:00, 25.91it/s]
# it 14 / 20: 100%|██████████| 100/100 [00:03<00:00, 25.02it/s]
# it 15 / 20: 100%|██████████| 100/100 [00:03<00:00, 25.82it/s]
# it 16 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.33it/s]
# it 17 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.25it/s]
# it 18 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.97it/s]
# it 19 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.28it/s]
# it 20 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.76it/s]

# %%
for steps in steps_mixed_all:
    steps = list(filter(lambda x: x != float("inf"), steps))
    steps = list(filter(lambda x: x != 0, steps))

    distributions = get_common_distributions()
    distributions.remove("expon")
    f_ln = Fitter([np.log(step) for step in steps], distributions=distributions)
    f_ln.fit()

    mu, sigma = f_ln.fitted_param["norm"]
    result = np.e ** (mu + (sigma**2) / 2)
    expected_values.append(result)

plt.plot(values, expected_values)
plt.xlabel("p_LO")
plt.ylabel("Expected number of steps")
plt.title("for RO-filtered terms")
plt.show()
# Out:
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 28.82it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 36.88it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 38.80it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 36.88it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 42.64it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 45.44it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 44.33it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 39.46it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.03it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 31.57it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 36.58it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.33it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.96it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.04it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 34.21it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.94it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.08it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.11it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 28.47it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 27.02it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 26.46it/s]

# %%
inx_best = expected_values.index(min(expected_values))
inx_best
# Out:
# 20

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "Mixed_Best": (clear_arr(steps_mixed_all[inx_best]), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps LO, LI, RI, RO")

# %% [markdown]
# ## Generating with (Rand)-filtering

# %%
RANDOM_AVERAGE_COUNT = 20

terms, steps_mix = gen_filtered_lambda_terms_v2(
    count_terms=100, filtering_strategy=RandomStrategy()
)
stepsRI = [term.normalize(RightmostInnermostStrategy())[1] for term in tqdm(terms)]
stepsLO = [term.normalize(LeftmostOutermostStrategy())[1] for term in tqdm(terms)]
stepsRand = [
    sum(term.normalize(RandomStrategy())[1] for i in range(RANDOM_AVERAGE_COUNT))
    / RANDOM_AVERAGE_COUNT
    for term in tqdm(terms)
]
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 793.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 763.14it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.40it/s]

# %%
comp_data = {
    "Mixed": (steps_mix, "-"),
    "LO": (stepsLO, "-"),
    "RI": (stepsRI, "-"),
    "Rand": (stepsRand, "-"),
}
draw_cumulative_avg_comparison(comp_data, title="AvgCum steps Random")

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps Random")

# %%
steps_mixed_all = []
expected_values = []
values = list(range(0, 101, 5))
iters = len(values) - 1

for inx, p_lo in enumerate(values):
    p = (p_lo / 100, 1 - p_lo / 100)
    steps = [
        sum(
            [
                term.normalize(
                    MixedStrategy(
                        [LeftmostOutermostStrategy(), RightmostInnermostStrategy()], p
                    )
                )[1]
                for i in range(RANDOM_AVERAGE_COUNT)
            ]
        )
        / RANDOM_AVERAGE_COUNT
        for term in tqdm(terms, desc=f"it {inx} / {iters}")
    ]
    steps_mixed_all.append(steps)
# Out:
# it 0 / 20: 100%|██████████| 100/100 [00:02<00:00, 39.39it/s]
# it 1 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.31it/s]
# it 2 / 20: 100%|██████████| 100/100 [00:03<00:00, 28.95it/s]
# it 3 / 20: 100%|██████████| 100/100 [00:03<00:00, 27.61it/s]
# it 4 / 20: 100%|██████████| 100/100 [00:03<00:00, 27.03it/s]
# it 5 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.37it/s]
# it 6 / 20: 100%|██████████| 100/100 [00:04<00:00, 24.96it/s]
# it 7 / 20: 100%|██████████| 100/100 [00:03<00:00, 25.59it/s]
# it 8 / 20: 100%|██████████| 100/100 [00:03<00:00, 27.19it/s]
# it 9 / 20: 100%|██████████| 100/100 [00:03<00:00, 26.21it/s]
# it 10 / 20: 100%|██████████| 100/100 [00:03<00:00, 25.92it/s]
# it 11 / 20: 100%|██████████| 100/100 [00:03<00:00, 28.49it/s]
# it 12 / 20: 100%|██████████| 100/100 [00:03<00:00, 28.21it/s]
# it 13 / 20: 100%|██████████| 100/100 [00:03<00:00, 28.72it/s]
# it 14 / 20: 100%|██████████| 100/100 [00:03<00:00, 31.64it/s]
# it 15 / 20: 100%|██████████| 100/100 [00:03<00:00, 32.55it/s]
# it 16 / 20: 100%|██████████| 100/100 [00:02<00:00, 34.47it/s]
# it 17 / 20: 100%|██████████| 100/100 [00:02<00:00, 35.88it/s]
# it 18 / 20: 100%|██████████| 100/100 [00:02<00:00, 36.32it/s]
# it 19 / 20: 100%|██████████| 100/100 [00:02<00:00, 37.41it/s]
# it 20 / 20: 100%|██████████| 100/100 [00:02<00:00, 38.12it/s]

# %%
for steps in steps_mixed_all:
    steps = list(filter(lambda x: x != float("inf"), steps))
    steps = list(filter(lambda x: x != 0, steps))

    distributions = get_common_distributions()
    distributions.remove("expon")
    f_ln = Fitter([np.log(step) for step in steps], distributions=distributions)
    f_ln.fit()

    mu, sigma = f_ln.fitted_param["norm"]
    result = np.e ** (mu + (sigma**2) / 2)
    expected_values.append(result)

plt.plot(values, expected_values)
plt.xlabel("p_LO")
plt.ylabel("Expected number of steps")
plt.title("for RO-filtered terms")
plt.show()
# Out:
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 28.21it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 26.16it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 38.62it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 40.53it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 42.64it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 46.38it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 42.85it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 45.38it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 45.22it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 30.51it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 37.49it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 39.29it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.37it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.17it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.21it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 32.12it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 31.68it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 29.27it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 22.71it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.33it/s]
# Fitting 9 distributions: 100%|██████████| 9/9 [00:00<00:00, 33.57it/s]

# %%
inx_best = expected_values.index(min(expected_values))
inx_best
# Out:
# 20

# %%
comp_data = {
    "Mixed": (clear_arr(steps_mix), "-"),
    "Mixed_Best": (clear_arr(steps_mixed_all[inx_best]), "-"),
    "LO": (clear_arr(stepsLO), "-"),
    "RI": (clear_arr(stepsRI), "-"),
    "Rand": (clear_arr(stepsRand), "-"),
}
draw_cumulative_avg_comparison(comp_data, title="Clear AvgCum steps Random")
