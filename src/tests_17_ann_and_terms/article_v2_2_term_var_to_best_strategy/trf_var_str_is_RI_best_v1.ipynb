# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time
# Out:
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=117,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 30

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("prepare_data/data_steps/steps_vars_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}")
all_data = all_data.drop_duplicates(subset="vars_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["vars_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_lo_test = all_data["LO_steps_num"].tolist()
y_ri_test = all_data["RI_steps_num"].tolist()

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4282
# Count original terms: 4282
#
# number samples: 4282
# number samples only reducable: 4251
#
# max RI steps count: 386
# max LO steps count: 219
# Count TESTING samples: 4251

# %%
all_data = pd.read_csv("prepare_data/data_steps/steps_vars_term_str_train.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}")
all_data = all_data.drop_duplicates(subset="vars_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["vars_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_lo_train = all_data["LO_steps_num"].tolist()
y_ri_train = all_data["RI_steps_num"].tolist()

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 45038
# Count original terms: 45038
#
# number samples: 45038
# number samples only reducable: 42912
#
# max RI steps count: 400
# max LO steps count: 308
# Count TRAINING samples: 42912

# %%
test_vars = set()
for x_ in x_test:
    test_vars.update(x_.replace("λ", " ").replace("(", " ").replace(")", " ").replace(".", " ").split(" "))
    
train_vars = set()
for x_ in x_train:
    train_vars.update(x_.replace("λ", " ").replace("(", " ").replace(")", " ").replace(".", " ").split(" "))

# %%
vars_to_sym_dict = dict()

list_vars = "x y z a b c d e j i n m t r q w u o p s f g h k l v".split()
greek_small = "α β γ δ ε ζ η θ ι κ λ μ ν ξ ο π ρ σ τ υ φ χ ψ ω Α Β".split()
greek_big = "Γ Δ Ε Ζ Η Θ Ι Κ Λ Μ Ν Ξ Ο Π Ρ Σ Τ Υ Φ Χ Ψ Ω 1 2 3 4".split()
            
for kv_ in list_vars:
    vars_to_sym_dict[kv_] = kv_

for key_, val_ in zip(list_vars, "X Y Z A B C D E J I N M T R Q W U O P S F G H K L V".split()):
    vars_to_sym_dict[key_ + "_1"] = val_
    
for key_, val_ in zip(list_vars, greek_small):
    vars_to_sym_dict[key_ + "_2"] = val_
    
for key_, val_ in zip(list_vars, greek_big):
    vars_to_sym_dict[key_ + "_3"] = val_
    
for key_, val_ in zip(list_vars[:6], "5 6 7 8 9 0".split()):
    vars_to_sym_dict[key_ + "_4"] = val_

for x_ in test_vars:
    if x_ and x_ not in vars_to_sym_dict:
        vars_to_sym_dict[x_] = x_[0]
        
for x_ in train_vars:
    if x_ and x_ not in vars_to_sym_dict:
        vars_to_sym_dict[x_] = x_[0]

for x_ in list_vars:
    del vars_to_sym_dict[x_]

print(vars_to_sym_dict)
# Out:
# {'x_1': 'X', 'y_1': 'Y', 'z_1': 'Z', 'a_1': 'A', 'b_1': 'B', 'c_1': 'C', 'd_1': 'D', 'e_1': 'E', 'j_1': 'J', 'i_1': 'I', 'n_1': 'N', 'm_1': 'M', 't_1': 'T', 'r_1': 'R', 'q_1': 'Q', 'w_1': 'W', 'u_1': 'U', 'o_1': 'O', 'p_1': 'P', 's_1': 'S', 'f_1': 'F', 'g_1': 'G', 'h_1': 'H', 'k_1': 'K', 'l_1': 'L', 'v_1': 'V', 'x_2': 'α', 'y_2': 'β', 'z_2': 'γ', 'a_2': 'δ', 'b_2': 'ε', 'c_2': 'ζ', 'd_2': 'η', 'e_2': 'θ', 'j_2': 'ι', 'i_2': 'κ', 'n_2': 'λ', 'm_2': 'μ', 't_2': 'ν', 'r_2': 'ξ', 'q_2': 'ο', 'w_2': 'π', 'u_2': 'ρ', 'o_2': 'σ', 'p_2': 'τ', 's_2': 'υ', 'f_2': 'φ', 'g_2': 'χ', 'h_2': 'ψ', 'k_2': 'ω', 'l_2': 'Α', 'v_2': 'Β', 'x_3': 'Γ', 'y_3': 'Δ', 'z_3': 'Ε', 'a_3': 'Ζ', 'b_3': 'Η', 'c_3': 'Θ', 'd_3': 'Ι', 'e_3': 'Κ', 'j_3': 'Λ', 'i_3': 'Μ', 'n_3': 'Ν', 'm_3': 'Ξ', 't_3': 'Ο', 'r_3': 'Π', 'q_3': 'Ρ', 'w_3': 'Σ', 'u_3': 'Τ', 'o_3': 'Υ', 'p_3': 'Φ', 's_3': 'Χ', 'f_3': 'Ψ', 'g_3': 'Ω', 'h_3': '1', 'k_3': '2', 'l_3': '3', 'v_3': '4', 'x_4': '5', 'y_4': '6', 'z_4': '7', 'a_4': '8', 'b_4': '9', 'c_4': '0', 'j_4': 'j', 'v_4': 'v', 'w_4': 'w', 'u_4': 'u', 'm_7': 'm', 'v_5': 'v', 'b_8': 'b', 'b_5': 'b', 'l_6': 'l', 'o_6': 'o', 'l_5': 'l', 'a_6': 'a', 'o_5': 'o', 'd_5': 'd', 'w_7': 'w', 'x_7': 'x', 'n_5': 'n', 'o_7': 'o', 'r_4': 'r', 's_8': 's', 'c_5': 'c', 'q_4': 'q', 'b_6': 'b', 'e_6': 'e', 'i_4': 'i', 'c_6': 'c', 'r_6': 'r', 'u_8': 'u', 'p_8': 'p', 'g_4': 'g', 'k_4': 'k', 'x_6': 'x', 'o_4': 'o', 'z_8': 'z', 'n_8': 'n', 'y_7': 'y', 's_7': 's', 'q_7': 'q', 'u_7': 'u', 'f_7': 'f', 'p_4': 'p', 'w_8': 'w', 'r_8': 'r', 't_6': 't', 'j_5': 'j', 's_6': 's', 'p_5': 'p', 'd_7': 'd', 'm_5': 'm', 'f_5': 'f', 'j_6': 'j', 'z_7': 'z', 'h_6': 'h', 'a_7': 'a', 'h_8': 'h', 'c_8': 'c', 'k_5': 'k', 'v_6': 'v', 'l_7': 'l', 't_8': 't', 'w_6': 'w', 'q_5': 'q', 'i_7': 'i', 'r_7': 'r', 'h_5': 'h', 'x_5': 'x', 'e_7': 'e', 'e_4': 'e', 'h_4': 'h', 'd_6': 'd', 'j_8': 'j', 'n_6': 'n', 'k_6': 'k', 'x_8': 'x', 'p_6': 'p', 'u_6': 'u', 'g_7': 'g', 'y_5': 'y', 'f_4': 'f', 'z_6': 'z', 'q_6': 'q', 'h_7': 'h', 's_4': 's', 'u_5': 'u', 'i_8': 'i', 'w_5': 'w', 'y_8': 'y', 'f_8': 'f', 'i_5': 'i', 't_5': 't', 'm_6': 'm', 'c_7': 'c', 'n_7': 'n', 'y_6': 'y', 'k_8': 'k', 'g_6': 'g', 'b_7': 'b', 'p_7': 'p', 'd_8': 'd', 'q_8': 'q', 'k_7': 'k', 'm_4': 'm', 'i_6': 'i', 'd_4': 'd', 'g_5': 'g', 'r_5': 'r', 'e_8': 'e', 'g_8': 'g', 'a_5': 'a', 'f_6': 'f', 'a_8': 'a', 'm_8': 'm', 'e_5': 'e', 't_7': 't', 'v_7': 'v', 'j_7': 'j', 'n_4': 'n', 't_4': 't', 'l_4': 'l', 'o_8': 'o', 'z_5': 'z', 's_5': 's', 'b_22': 'b', 'u_15': 'u', 'g_22': 'g', 'x_18': 'x', 'd_12': 'd', 'x_20': 'x', 'u_16': 'u', 'r_26': 'r', 'z_24': 'z', 'd_28': 'd', 'n_12': 'n', 'd_25': 'd', 'z_10': 'z', 'n_10': 'n', 'b_23': 'b', 'o_24': 'o', 'v_16': 'v', 'u_11': 'u', 's_11': 's', 'n_11': 'n', 'm_25': 'm', 'g_27': 'g', 'j_28': 'j', 'u_22': 'u', 'c_10': 'c', 'o_21': 'o', 'j_11': 'j', 'o_18': 'o', 'g_21': 'g', 'j_26': 'j', 'p_10': 'p', 'b_15': 'b', 'm_28': 'm', 'd_19': 'd', 't_27': 't', 'e_12': 'e', 'j_12': 'j', 'y_21': 'y', 'v_22': 'v', 'u_24': 'u', 'v_27': 'v', 'f_16': 'f', 'm_17': 'm', 'l_19': 'l', 'f_26': 'f', 'q_14': 'q', 'b_10': 'b', 'e_14': 'e', 'e_10': 'e', 'p_25': 'p', 'y_12': 'y', 'w_11': 'w', 'e_17': 'e', 'i_22': 'i', 'a_25': 'a', 't_10': 't', 'x_26': 'x', 'm_10': 'm', 'a_9': 'a', 'a_16': 'a', 'w_14': 'w', 't_9': 't', 'i_16': 'i', 'b_20': 'b', 'd_20': 'd', 'p_9': 'p', 'd_15': 'd', 'p_27': 'p', 'h_12': 'h', 'z_27': 'z', 'f_22': 'f', 'k_16': 'k', 'i_10': 'i', 'l_14': 'l', 'n_24': 'n', 'i_28': 'i', 'z_19': 'z', 'u_10': 'u', 'j_10': 'j', 'b_11': 'b', 'v_17': 'v', 's_10': 's', 'o_20': 'o', 'e_16': 'e', 'd_13': 'd', 't_21': 't', 'n_9': 'n', 'd_18': 'd', 'y_27': 'y', 'k_11': 'k', 'a_18': 'a', 'h_17': 'h', 'p_23': 'p', 'w_17': 'w', 'i_21': 'i', 't_12': 't', 'd_26': 'd', 'h_19': 'h', 'u_9': 'u', 'l_25': 'l', 't_18': 't', 'h_22': 'h', 'w_13': 'w', 'k_13': 'k', 'x_12': 'x', 't_24': 't', 'f_10': 'f', 'v_24': 'v', 'c_26': 'c', 'a_23': 'a', 'm_13': 'm', 'b_24': 'b', 'w_9': 'w', 'y_24': 'y', 'k_18': 'k', 'm_18': 'm', 'u_25': 'u', 'p_14': 'p', ...

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("tokenizer_data", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train_prep = []
for x_ in x_train:
    x_ = x_.replace("λ", "@")
    for key_, val_ in vars_to_sym_dict.items():
        x_ = x_.replace(key_, val_)
    x_ = x_.replace(".", "").replace(" ", "")
    x_train_prep.append(x_)
    
x_test_prep = []
for x_ in x_test:
    x_ = x_.replace("λ", "@")
    for key_, val_ in vars_to_sym_dict.items():
        x_ = x_.replace(key_, val_)
    x_ = x_.replace(".", "").replace(" ", "")
    x_test_prep.append(x_)

train_df = pd.DataFrame({
    "term_str": x_train_prep, "is_ri_best": y_train,
    "lo_steps": y_lo_train, "ri_steps": y_ri_train,
    "sample_weights": [(abs(ri_ - lo_) / (max(ri_, lo_) + 0.001)) + 0.001 for ri_, lo_ in zip(y_ri_train, y_lo_train)],
})
test_df = pd.DataFrame({
    "term_str": x_test_prep, "is_ri_best": y_test,
    "lo_steps": y_lo_test, "ri_steps": y_ri_test,
    "sample_weights": [(abs(ri_ - lo_) / (max(ri_, lo_) + 0.001)) + 0.001 for ri_, lo_ in zip(y_ri_test, y_lo_test)],
})

# %%
train_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  ((((((@xx)(@yy))((@zz)(@aa)))((@b((@cc)((@d(((...           0        14
# 1  (((@x(@y(y(@z(@az)))))((@bb)(@c(((@dd)(@e(@je)...           0        10
# 2  (((@x(@yy))(@z(@aa)))(@b(b(b(b((@cb)(((@d(@ee)...           0         3
# 3        (@x(@y((x(((yy)((xx)x))((x(xx))(@zx))))y)))           0         0
# 4  (@x(@y(@z((((x(((((x(yy))((yy)(yy)))(yy))((((z...           0         4
# 5  (@x(@y(@z((@a(xy))(@b((@c((@dz)x))(b((z((((b((...           0         1
# 6  ((@x(((@y(y(@z((@az)(((((@by)(y(@c(y(y(@d((@ee...           0        18
# 7  ((((@x((@y(@z((((@az)((@bb)y))z)(@c(@dd)))))(@...           0         7
# 8  (@x(((@y(@zz))((x((x(@a(ax)))(@b(x((@c(@db))((...           0         3
# 9   (@x(x(((@yy)(@z(@a(@b(bz)))))(@c(@d(@e(ec)))))))           0         2
#
#    ri_steps  sample_weights
# 0        21        0.334317
# 1        14        0.286694
# 2         5        0.400920
# 3         0        0.001000
# 4         4        0.001000
# 5         6        0.834194
# 6        22        0.182810
# 7        36        0.806533
# 8         6        0.500917
# 9         2        0.001000

# %%
test_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0                               (@x((@y(@zy))(@aa)))           0         1
# 1  (@x(((x(((x(@yy))(x(((x((xx)((@zx)x)))((((@a(x...           0         2
# 2  (((@x(((x(@y((@z((@a(@bz))(@cy)))y)))((@d((@e(...           0        12
# 3  (((@xx)(@y((@z(@aa))y)))(@b((@c(@d(@e(e(@j(b((...           0         3
# 4  ((@x((((xx)((((x(xx))x)x)(((@y(xy))(xx))x)))((...           0        10
# 5  (@x(@y(@z((y(x(x((x((@ax)((x((@bz)(xy)))x)))(@...           0         2
# 6  (@x((x(@y((@zy)(((yy)(@aa))(@b(y(((@cy)((@d(@e...           0         1
# 7  ((@x(@y((yy)((@z(@a(a(((a((zy)y))a)a))))(((x(x...           0        10
# 8  (((@x((((@y((@zx)(@a(((@bx)(@c((@d((@e((((@jy)...           0        19
# 9  ((@x(@y(@zx)))(@a(@b((((@c(@dd))(@ee))(@jj))(@...           0         4
#
#    ri_steps  sample_weights
# 0         1        0.001000
# 1         2        0.001000
# 2        13        0.077917
# 3         6        0.500917
# 4        50        0.800984
# 5         7        0.715184
# 6         3        0.667445
# 7        12        0.167653
# 8        21        0.096234
# 9         4        0.001000

# %%
def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    sample_weights = tf.convert_to_tensor(example["sample_weights"])
    return tokenized_texts, labels, sample_weights


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1], tokenized_train_data[2])).batch(batch_size)
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define & Train the Model

# %%
# Define the model
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  139904      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 140,745
# Trainable params: 140,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_structure = model.to_json()
with open("./fine_models/model_vars_ri.json", 'w') as json_file:
    json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_vars_ri_f1.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_vars_ri.h5', save_weights_only=True, save_freq=1)

# %%
def draw_training_statistic(history_):
    plt.plot(range(1, epochs + 1), history_.history['loss'], label="loss")
    plt.plot(range(1, epochs + 1), history_.history['val_loss'], label="val_loss")
    plt.xlabel("epochs")
    plt.title("total loss")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['accuracy'], label="accuracy")
    plt.plot(range(1, epochs + 1), history_.history['val_accuracy'], label="val_accuracy")
    plt.xlabel("epochs")
    plt.title("total accuracy")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['precision'], label="precision")
    plt.plot(range(1, epochs + 1), history_.history['val_precision'], label="val_precision")
    plt.xlabel("epochs")
    plt.title("total precision")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['recall'], label="recall")
    plt.plot(range(1, epochs + 1), history_.history['val_recall'], label="val_recall")
    plt.xlabel("epochs")
    plt.title("total recall")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['f1_score'], label="F1-score")
    plt.plot(range(1, epochs + 1), history_.history['val_f1_score'], label="val F1-score")
    plt.xlabel("epochs")
    plt.title("total F1-score")
    plt.legend()
    plt.show()

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 671/671 [==============================] - 138s 199ms/step - loss: 0.3384 - accuracy: 0.8798 - precision: 0.5489 - recall: 0.0646 - f1_score: 0.1156 - val_loss: 0.2661 - val_accuracy: 0.9104 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 671/671 [==============================] - 135s 201ms/step - loss: 0.3181 - accuracy: 0.8846 - precision: 0.7131 - recall: 0.0853 - f1_score: 0.1523 - val_loss: 0.2549 - val_accuracy: 0.9106 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/30
# 671/671 [==============================] - 137s 204ms/step - loss: 0.3103 - accuracy: 0.8850 - precision: 0.7029 - recall: 0.0943 - f1_score: 0.1663 - val_loss: 0.2614 - val_accuracy: 0.9097 - val_precision: 0.3810 - val_recall: 0.0211 - val_f1_score: 0.0400
# Epoch 4/30
# 671/671 [==============================] - 137s 204ms/step - loss: 0.3035 - accuracy: 0.8862 - precision: 0.7049 - recall: 0.1108 - f1_score: 0.1915 - val_loss: 0.2591 - val_accuracy: 0.9092 - val_precision: 0.3333 - val_recall: 0.0185 - val_f1_score: 0.0350
# Epoch 5/30
# 671/671 [==============================] - 135s 202ms/step - loss: 0.2987 - accuracy: 0.8879 - precision: 0.7043 - recall: 0.1351 - f1_score: 0.2267 - val_loss: 0.2639 - val_accuracy: 0.9083 - val_precision: 0.3226 - val_recall: 0.0264 - val_f1_score: 0.0488
# Epoch 6/30
# 671/671 [==============================] - 130s 194ms/step - loss: 0.2947 - accuracy: 0.8885 - precision: 0.7000 - recall: 0.1449 - f1_score: 0.2401 - val_loss: 0.2610 - val_accuracy: 0.9078 - val_precision: 0.2759 - val_recall: 0.0211 - val_f1_score: 0.0392
# Epoch 7/30
# 671/671 [==============================] - 129s 192ms/step - loss: 0.2897 - accuracy: 0.8892 - precision: 0.6871 - recall: 0.1633 - f1_score: 0.2639 - val_loss: 0.2677 - val_accuracy: 0.9050 - val_precision: 0.3288 - val_recall: 0.0633 - val_f1_score: 0.1062
# Epoch 8/30
# 671/671 [==============================] - 128s 191ms/step - loss: 0.2855 - accuracy: 0.8907 - precision: 0.6969 - recall: 0.1794 - f1_score: 0.2853 - val_loss: 0.2663 - val_accuracy: 0.9052 - val_precision: 0.2273 - val_recall: 0.0264 - val_f1_score: 0.0473
# Epoch 9/30
# 671/671 [==============================] - 130s 193ms/step - loss: 0.2812 - accuracy: 0.8920 - precision: 0.6961 - recall: 0.1980 - f1_score: 0.3083 - val_loss: 0.2673 - val_accuracy: 0.9014 - val_precision: 0.2561 - val_recall: 0.0554 - val_f1_score: 0.0911
# Epoch 10/30
# 671/671 [==============================] - 130s 193ms/step - loss: 0.2771 - accuracy: 0.8934 - precision: 0.7019 - recall: 0.2148 - f1_score: 0.3290 - val_loss: 0.2679 - val_accuracy: 0.9033 - val_precision: 0.3000 - val_recall: 0.0633 - val_f1_score: 0.1046
# Epoch 11/30
# 671/671 [==============================] - 130s 194ms/step - loss: 0.2719 - accuracy: 0.8942 - precision: 0.6977 - recall: 0.2286 - f1_score: 0.3444 - val_loss: 0.2763 - val_accuracy: 0.8988 - val_precision: 0.2475 - val_recall: 0.0660 - val_f1_score: 0.1042
# Epoch 12/30
# 671/671 [==============================] - 131s 196ms/step - loss: 0.2688 - accuracy: 0.8954 - precision: 0.6963 - recall: 0.2474 - f1_score: 0.3651 - val_loss: 0.2764 - val_accuracy: 0.9007 - val_precision: 0.2913 - val_recall: 0.0792 - val_f1_score: 0.1245
# Epoch 13/30
# 671/671 [==============================] - 131s 195ms/step - loss: 0.2649 - accuracy: 0.8966 - precision: 0.7049 - recall: 0.2578 - f1_score: 0.3775 - val_loss: 0.2856 - val_accuracy: 0.8977 - val_precision: 0.2941 - val_recall: 0.1055 - val_f1_score: 0.1553
# Epoch 14/30
# 671/671 [==============================] - 132s 197ms/step - loss: 0.2607 - accuracy: 0.8987 - precision: 0.7147 - recall: 0.2785 - f1_score: 0.4008 - val_loss: 0.2790 - val_accuracy: 0.8984 - val_precision: 0.2880 - val_recall: 0.0950 - val_f1_score: 0.1429
# Epoch 15/30
# 671/671 [==============================] - 146s 217ms/step - loss: 0.2569 - accuracy: 0.9001 - precision: 0.7189 - recall: 0.2926 - f1_score: 0.4160 - val_loss: 0.2840 - val_accuracy: 0.8993 - val_precision: 0.2975 - val_recall: 0.0950 - val_f1_score: 0.1440
# Epoch 16/30
# 671/671 [==============================] - 160s 239ms/step - loss: 0.2541 - accuracy: 0.9002 - precision: 0.7116 - recall: 0.3013 - f1_score: 0.4233 - val_loss: 0.2829 - val_accuracy: 0.9005 - val_precision: 0.2925 - val_recall: 0.0818 - val_f1_score: 0.1278
# Epoch 17/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.2498 - accuracy: 0.9018 - precision: 0.7185 - recall: 0.3160 - f1_score: 0.4390 - val_loss: 0.3011 - val_accuracy: 0.8885 - val_precision: 0.2460 - val_recall: 0.1214 - val_f1_score: 0.1625
# Epoch 18/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.2487 - accuracy: 0.9029 - precision: 0.7243 - recall: 0.3258 - f1_score: 0.4494 - val_loss: 0.3077 - val_accuracy: 0.8885 - val_precision: 0.2487 - val_recall: 0.1240 - val_f1_score: 0.1655
# Epoch 19/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.2428 - accuracy: 0.9051 - precision: 0.7301 - recall: 0.3478 - f1_score: 0.4712 - val_loss: 0.3074 - val_accuracy: 0.8923 - val_precision: 0.2577 - val_recall: 0.1108 - val_f1_score: 0.1550
# Epoch 20/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.2396 - accuracy: 0.9064 - precision: 0.7353 - recall: 0.3593 - f1_score: 0.4827 - val_loss: 0.3127 - val_accuracy: 0.8904 - val_precision: 0.2331 - val_recall: 0.1003 - val_f1_score: 0.1402
# Epoch 21/30
# 671/671 [==============================] - 164s 245ms/step - loss: 0.2353 - accuracy: 0.9074 - precision: 0.7380 - recall: 0.3699 - f1_score: 0.4928 - val_loss: 0.3191 - val_accuracy: 0.8883 - val_precision: 0.2474 - val_recall: 0.1240 - val_f1_score: 0.1652
# Epoch 22/30
# 671/671 [==============================] - 166s 248ms/step - loss: 0.2337 - accuracy: 0.9075 - precision: 0.7307 - recall: 0.3785 - f1_score: 0.4987 - val_loss: 0.3131 - val_accuracy: 0.8885 - val_precision: 0.2487 - val_recall: 0.1240 - val_f1_score: 0.1655
# Epoch 23/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.2275 - accuracy: 0.9101 - precision: 0.7401 - recall: 0.4017 - f1_score: 0.5207 - val_loss: 0.3361 - val_accuracy: 0.8831 - val_precision: 0.2677 - val_recall: 0.1794 - val_f1_score: 0.2148
# Epoch 24/30
# 671/671 [==============================] - 163s 242ms/step - loss: 0.2271 - accuracy: 0.9109 - precision: 0.7504 - recall: 0.4009 - f1_score: 0.5226 - val_loss: 0.3267 - val_accuracy: 0.8878 - val_precision: 0.2667 - val_recall: 0.1478 - val_f1_score: 0.1902
# Epoch 25/30
# 671/671 [==============================] - 160s 239ms/step - loss: 0.2225 - accuracy: 0.9125 - precision: 0.7530 - recall: 0.4178 - f1_score: 0.5374 - val_loss: 0.3301 - val_accuracy: 0.8864 - val_precision: 0.2547 - val_recall: 0.1425 - val_f1_score: 0.1827
# Epoch 26/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.2201 - accuracy: 0.9127 - precision: 0.7453 - recall: 0.4289 - f1_score: 0.5445 - val_loss: 0.3401 - val_accuracy: 0.8880 - val_precision: 0.2744 - val_recall: 0.1557 - val_f1_score: 0.1987
# Epoch 27/30
# 671/671 [==============================] - 160s 239ms/step - loss: 0.2182 - accuracy: 0.9141 - precision: 0.7583 - recall: 0.4310 - f1_score: 0.5496 - val_loss: 0.3486 - val_accuracy: 0.8852 - val_precision: 0.2681 - val_recall: 0.1662 - val_f1_score: 0.2052
# Epoch 28/30
# 671/671 [==============================] - 164s 244ms/step - loss: 0.2121 - accuracy: 0.9154 - precision: 0.7545 - recall: 0.4511 - f1_score: 0.5646 - val_loss: 0.3663 - val_accuracy: 0.8803 - val_precision: 0.2575 - val_recall: 0.1821 - val_f1_score: 0.2133
# Epoch 29/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.2143 - accuracy: 0.9156 - precision: 0.7638 - recall: 0.4425 - f1_score: 0.5604 - val_loss: 0.3631 - val_accuracy: 0.8777 - val_precision: 0.2399 - val_recall: 0.1715 - val_f1_score: 0.2000
# Epoch 30/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.2081 - accuracy: 0.9164 - precision: 0.7537 - recall: 0.4645 - f1_score: 0.5748 - val_loss: 0.3508 - val_accuracy: 0.8810 - val_precision: 0.2567 - val_recall: 0.1768 - val_f1_score: 0.2094

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.2085 - accuracy: 0.9165 - precision: 0.7508 - recall: 0.4690 - f1_score: 0.5773 - val_loss: 0.3543 - val_accuracy: 0.8821 - val_precision: 0.2500 - val_recall: 0.1609 - val_f1_score: 0.1958
# Epoch 2/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.2025 - accuracy: 0.9187 - precision: 0.7628 - recall: 0.4814 - f1_score: 0.5903 - val_loss: 0.3646 - val_accuracy: 0.8709 - val_precision: 0.2128 - val_recall: 0.1662 - val_f1_score: 0.1867
# Epoch 3/30
# 671/671 [==============================] - 163s 243ms/step - loss: 0.2021 - accuracy: 0.9206 - precision: 0.7733 - recall: 0.4910 - f1_score: 0.6006 - val_loss: 0.3780 - val_accuracy: 0.8756 - val_precision: 0.2466 - val_recall: 0.1926 - val_f1_score: 0.2163
# Epoch 4/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.2008 - accuracy: 0.9200 - precision: 0.7666 - recall: 0.4916 - f1_score: 0.5990 - val_loss: 0.3780 - val_accuracy: 0.8786 - val_precision: 0.2527 - val_recall: 0.1847 - val_f1_score: 0.2134
# Epoch 5/30
# 671/671 [==============================] - 166s 247ms/step - loss: 0.1949 - accuracy: 0.9228 - precision: 0.7750 - recall: 0.5142 - f1_score: 0.6182 - val_loss: 0.3861 - val_accuracy: 0.8786 - val_precision: 0.2562 - val_recall: 0.1900 - val_f1_score: 0.2182
# Epoch 6/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.1936 - accuracy: 0.9222 - precision: 0.7718 - recall: 0.5113 - f1_score: 0.6151 - val_loss: 0.3791 - val_accuracy: 0.8819 - val_precision: 0.2644 - val_recall: 0.1821 - val_f1_score: 0.2156
# Epoch 7/30
# 671/671 [==============================] - 169s 252ms/step - loss: 0.1920 - accuracy: 0.9226 - precision: 0.7722 - recall: 0.5157 - f1_score: 0.6184 - val_loss: 0.3990 - val_accuracy: 0.8723 - val_precision: 0.2574 - val_recall: 0.2296 - val_f1_score: 0.2427
# Epoch 8/30
# 671/671 [==============================] - 187s 279ms/step - loss: 0.1905 - accuracy: 0.9229 - precision: 0.7731 - recall: 0.5184 - f1_score: 0.6206 - val_loss: 0.3966 - val_accuracy: 0.8744 - val_precision: 0.2540 - val_recall: 0.2111 - val_f1_score: 0.2305
# Epoch 9/30
# 671/671 [==============================] - 190s 283ms/step - loss: 0.1866 - accuracy: 0.9254 - precision: 0.7798 - recall: 0.5383 - f1_score: 0.6370 - val_loss: 0.4107 - val_accuracy: 0.8640 - val_precision: 0.2332 - val_recall: 0.2296 - val_f1_score: 0.2314
# Epoch 10/30
# 671/671 [==============================] - 178s 266ms/step - loss: 0.1833 - accuracy: 0.9262 - precision: 0.7851 - recall: 0.5418 - f1_score: 0.6411 - val_loss: 0.4197 - val_accuracy: 0.8676 - val_precision: 0.2310 - val_recall: 0.2084 - val_f1_score: 0.2191
# Epoch 11/30
# 671/671 [==============================] - 173s 258ms/step - loss: 0.1839 - accuracy: 0.9268 - precision: 0.7852 - recall: 0.5479 - f1_score: 0.6454 - val_loss: 0.4167 - val_accuracy: 0.8610 - val_precision: 0.2211 - val_recall: 0.2216 - val_f1_score: 0.2213
# Epoch 12/30
# 671/671 [==============================] - 172s 256ms/step - loss: 0.1808 - accuracy: 0.9265 - precision: 0.7801 - recall: 0.5508 - f1_score: 0.6457 - val_loss: 0.4139 - val_accuracy: 0.8624 - val_precision: 0.2399 - val_recall: 0.2507 - val_f1_score: 0.2452
# Epoch 13/30
# 671/671 [==============================] - 165s 245ms/step - loss: 0.1782 - accuracy: 0.9290 - precision: 0.7907 - recall: 0.5655 - f1_score: 0.6594 - val_loss: 0.4140 - val_accuracy: 0.8652 - val_precision: 0.2406 - val_recall: 0.2375 - val_f1_score: 0.2390
# Epoch 14/30
# 671/671 [==============================] - 171s 255ms/step - loss: 0.1753 - accuracy: 0.9293 - precision: 0.7899 - recall: 0.5707 - f1_score: 0.6627 - val_loss: 0.4518 - val_accuracy: 0.8506 - val_precision: 0.2104 - val_recall: 0.2454 - val_f1_score: 0.2266
# Epoch 15/30
# 671/671 [==============================] - 164s 245ms/step - loss: 0.1731 - accuracy: 0.9301 - precision: 0.7890 - recall: 0.5799 - f1_score: 0.6685 - val_loss: 0.4363 - val_accuracy: 0.8697 - val_precision: 0.2291 - val_recall: 0.1953 - val_f1_score: 0.2108
# Epoch 16/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.1739 - accuracy: 0.9292 - precision: 0.7880 - recall: 0.5719 - f1_score: 0.6627 - val_loss: 0.4392 - val_accuracy: 0.8596 - val_precision: 0.2086 - val_recall: 0.2058 - val_f1_score: 0.2072
# Epoch 17/30
# 671/671 [==============================] - 161s 241ms/step - loss: 0.1719 - accuracy: 0.9308 - precision: 0.7903 - recall: 0.5864 - f1_score: 0.6733 - val_loss: 0.4307 - val_accuracy: 0.8579 - val_precision: 0.2166 - val_recall: 0.2269 - val_f1_score: 0.2216
# Epoch 18/30
# 671/671 [==============================] - 163s 243ms/step - loss: 0.1702 - accuracy: 0.9327 - precision: 0.8038 - recall: 0.5905 - f1_score: 0.6808 - val_loss: 0.4278 - val_accuracy: 0.8676 - val_precision: 0.2514 - val_recall: 0.2454 - val_f1_score: 0.2483
# Epoch 19/30
# 671/671 [==============================] - 165s 246ms/step - loss: 0.1683 - accuracy: 0.9319 - precision: 0.7975 - recall: 0.5893 - f1_score: 0.6778 - val_loss: 0.4500 - val_accuracy: 0.8699 - val_precision: 0.2456 - val_recall: 0.2216 - val_f1_score: 0.2330
# Epoch 20/30
# 671/671 [==============================] - 163s 243ms/step - loss: 0.1658 - accuracy: 0.9327 - precision: 0.7998 - recall: 0.5958 - f1_score: 0.6829 - val_loss: 0.4620 - val_accuracy: 0.8584 - val_precision: 0.2389 - val_recall: 0.2691 - val_f1_score: 0.2531
# Epoch 21/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.1635 - accuracy: 0.9337 - precision: 0.7986 - recall: 0.6081 - f1_score: 0.6905 - val_loss: 0.4546 - val_accuracy: 0.8647 - val_precision: 0.2394 - val_recall: 0.2375 - val_f1_score: 0.2384
# Epoch 22/30
# 671/671 [==============================] - 156s 233ms/step - loss: 0.1638 - accuracy: 0.9336 - precision: 0.8031 - recall: 0.6018 - f1_score: 0.6880 - val_loss: 0.4505 - val_accuracy: 0.8622 - val_precision: 0.2255 - val_recall: 0.2243 - val_f1_score: 0.2249
# Epoch 23/30
# 671/671 [==============================] - 158s 236ms/step - loss: 0.1619 - accuracy: 0.9347 - precision: 0.8035 - recall: 0.6129 - f1_score: 0.6954 - val_loss: 0.4584 - val_accuracy: 0.8673 - val_precision: 0.2480 - val_recall: 0.2401 - val_f1_score: 0.2440
# Epoch 24/30
# 671/671 [==============================] - 158s 236ms/step - loss: 0.1577 - accuracy: 0.9366 - precision: 0.8092 - recall: 0.6267 - f1_score: 0.7063 - val_loss: 0.4654 - val_accuracy: 0.8504 - val_precision: 0.2073 - val_recall: 0.2401 - val_f1_score: 0.2225
# Epoch 25/30
# 671/671 [==============================] - 158s 236ms/step - loss: 0.1572 - accuracy: 0.9365 - precision: 0.8091 - recall: 0.6255 - f1_score: 0.7056 - val_loss: 0.4705 - val_accuracy: 0.8631 - val_precision: 0.2377 - val_recall: 0.2427 - val_f1_score: 0.2402
# Epoch 26/30
# 671/671 [==============================] - 158s 236ms/step - loss: 0.1553 - accuracy: 0.9386 - precision: 0.8178 - recall: 0.6366 - f1_score: 0.7159 - val_loss: 0.4779 - val_accuracy: 0.8542 - val_precision: 0.1980 - val_recall: 0.2084 - val_f1_score: 0.2031
# Epoch 27/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1546 - accuracy: 0.9384 - precision: 0.8134 - recall: 0.6401 - f1_score: 0.7164 - val_loss: 0.4929 - val_accuracy: 0.8494 - val_precision: 0.2119 - val_recall: 0.2533 - val_f1_score: 0.2308
# Epoch 28/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1551 - accuracy: 0.9369 - precision: 0.8024 - recall: 0.6380 - f1_score: 0.7108 - val_loss: 0.4875 - val_accuracy: 0.8605 - val_precision: 0.2242 - val_recall: 0.2296 - val_f1_score: 0.2269
# Epoch 29/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1542 - accuracy: 0.9377 - precision: 0.8069 - recall: 0.6414 - f1_score: 0.7147 - val_loss: 0.4964 - val_accuracy: 0.8560 - val_precision: 0.2109 - val_recall: 0.2243 - val_f1_score: 0.2174
# Epoch 30/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1485 - accuracy: 0.9399 - precision: 0.8161 - recall: 0.6524 - f1_score: 0.7251 - val_loss: 0.4803 - val_accuracy: 0.8680 - val_precision: 0.2191 - val_recall: 0.1873 - val_f1_score: 0.2020

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1504 - accuracy: 0.9392 - precision: 0.8140 - recall: 0.6485 - f1_score: 0.7219 - val_loss: 0.4960 - val_accuracy: 0.8492 - val_precision: 0.2089 - val_recall: 0.2480 - val_f1_score: 0.2268
# Epoch 2/30
# 671/671 [==============================] - 157s 233ms/step - loss: 0.1455 - accuracy: 0.9411 - precision: 0.8176 - recall: 0.6640 - f1_score: 0.7329 - val_loss: 0.4928 - val_accuracy: 0.8607 - val_precision: 0.2066 - val_recall: 0.1979 - val_f1_score: 0.2022
# Epoch 3/30
# 671/671 [==============================] - 159s 237ms/step - loss: 0.1464 - accuracy: 0.9423 - precision: 0.8251 - recall: 0.6663 - f1_score: 0.7373 - val_loss: 0.5055 - val_accuracy: 0.8669 - val_precision: 0.2013 - val_recall: 0.1662 - val_f1_score: 0.1821
# Epoch 4/30
# 671/671 [==============================] - 158s 236ms/step - loss: 0.1444 - accuracy: 0.9415 - precision: 0.8179 - recall: 0.6671 - f1_score: 0.7349 - val_loss: 0.5300 - val_accuracy: 0.8386 - val_precision: 0.2098 - val_recall: 0.2929 - val_f1_score: 0.2445
# Epoch 5/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1443 - accuracy: 0.9407 - precision: 0.8136 - recall: 0.6642 - f1_score: 0.7314 - val_loss: 0.5153 - val_accuracy: 0.8424 - val_precision: 0.2000 - val_recall: 0.2559 - val_f1_score: 0.2245
# Epoch 6/30
# 671/671 [==============================] - 160s 239ms/step - loss: 0.1385 - accuracy: 0.9446 - precision: 0.8303 - recall: 0.6846 - f1_score: 0.7504 - val_loss: 0.5352 - val_accuracy: 0.8556 - val_precision: 0.2261 - val_recall: 0.2559 - val_f1_score: 0.2401
# Epoch 7/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1416 - accuracy: 0.9424 - precision: 0.8186 - recall: 0.6761 - f1_score: 0.7406 - val_loss: 0.5109 - val_accuracy: 0.8539 - val_precision: 0.2091 - val_recall: 0.2296 - val_f1_score: 0.2189
# Epoch 8/30
# 671/671 [==============================] - 161s 239ms/step - loss: 0.1408 - accuracy: 0.9428 - precision: 0.8205 - recall: 0.6778 - f1_score: 0.7424 - val_loss: 0.5184 - val_accuracy: 0.8556 - val_precision: 0.2169 - val_recall: 0.2375 - val_f1_score: 0.2267
# Epoch 9/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.1374 - accuracy: 0.9444 - precision: 0.8237 - recall: 0.6911 - f1_score: 0.7516 - val_loss: 0.5415 - val_accuracy: 0.8570 - val_precision: 0.2187 - val_recall: 0.2348 - val_f1_score: 0.2265
# Epoch 10/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1366 - accuracy: 0.9449 - precision: 0.8287 - recall: 0.6897 - f1_score: 0.7529 - val_loss: 0.5135 - val_accuracy: 0.8558 - val_precision: 0.2132 - val_recall: 0.2296 - val_f1_score: 0.2211
# Epoch 11/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1344 - accuracy: 0.9452 - precision: 0.8275 - recall: 0.6939 - f1_score: 0.7548 - val_loss: 0.5348 - val_accuracy: 0.8516 - val_precision: 0.2200 - val_recall: 0.2612 - val_f1_score: 0.2388
# Epoch 12/30
# 671/671 [==============================] - 161s 239ms/step - loss: 0.1362 - accuracy: 0.9461 - precision: 0.8321 - recall: 0.6970 - f1_score: 0.7586 - val_loss: 0.5460 - val_accuracy: 0.8454 - val_precision: 0.2104 - val_recall: 0.2665 - val_f1_score: 0.2352
# Epoch 13/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1323 - accuracy: 0.9466 - precision: 0.8350 - recall: 0.6993 - f1_score: 0.7612 - val_loss: 0.5464 - val_accuracy: 0.8513 - val_precision: 0.2314 - val_recall: 0.2876 - val_f1_score: 0.2565
# Epoch 14/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1320 - accuracy: 0.9470 - precision: 0.8363 - recall: 0.7010 - f1_score: 0.7627 - val_loss: 0.5578 - val_accuracy: 0.8419 - val_precision: 0.2122 - val_recall: 0.2850 - val_f1_score: 0.2432
# Epoch 15/30
# 671/671 [==============================] - 162s 241ms/step - loss: 0.1320 - accuracy: 0.9469 - precision: 0.8311 - recall: 0.7072 - f1_score: 0.7641 - val_loss: 0.5404 - val_accuracy: 0.8391 - val_precision: 0.2117 - val_recall: 0.2955 - val_f1_score: 0.2467
# Epoch 16/30
# 671/671 [==============================] - 162s 242ms/step - loss: 0.1298 - accuracy: 0.9476 - precision: 0.8357 - recall: 0.7079 - f1_score: 0.7665 - val_loss: 0.5257 - val_accuracy: 0.8485 - val_precision: 0.2151 - val_recall: 0.2639 - val_f1_score: 0.2370
# Epoch 17/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1273 - accuracy: 0.9483 - precision: 0.8361 - recall: 0.7154 - f1_score: 0.7710 - val_loss: 0.5468 - val_accuracy: 0.8440 - val_precision: 0.2227 - val_recall: 0.3008 - val_f1_score: 0.2559
# Epoch 18/30
# 671/671 [==============================] - 161s 241ms/step - loss: 0.1311 - accuracy: 0.9475 - precision: 0.8333 - recall: 0.7106 - f1_score: 0.7671 - val_loss: 0.5396 - val_accuracy: 0.8443 - val_precision: 0.2153 - val_recall: 0.2823 - val_f1_score: 0.2443
# Epoch 19/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1287 - accuracy: 0.9484 - precision: 0.8380 - recall: 0.7137 - f1_score: 0.7709 - val_loss: 0.5566 - val_accuracy: 0.8452 - val_precision: 0.2170 - val_recall: 0.2823 - val_f1_score: 0.2454
# Epoch 20/30
# 671/671 [==============================] - 156s 233ms/step - loss: 0.1282 - accuracy: 0.9485 - precision: 0.8365 - recall: 0.7169 - f1_score: 0.7721 - val_loss: 0.5660 - val_accuracy: 0.8487 - val_precision: 0.2203 - val_recall: 0.2744 - val_f1_score: 0.2444
# Epoch 21/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1279 - accuracy: 0.9485 - precision: 0.8350 - recall: 0.7189 - f1_score: 0.7726 - val_loss: 0.5577 - val_accuracy: 0.8447 - val_precision: 0.2091 - val_recall: 0.2665 - val_f1_score: 0.2343
# Epoch 22/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1234 - accuracy: 0.9494 - precision: 0.8347 - recall: 0.7284 - f1_score: 0.7779 - val_loss: 0.6025 - val_accuracy: 0.8370 - val_precision: 0.1946 - val_recall: 0.2639 - val_f1_score: 0.2240
# Epoch 23/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1259 - accuracy: 0.9492 - precision: 0.8369 - recall: 0.7236 - f1_score: 0.7762 - val_loss: 0.5867 - val_accuracy: 0.8386 - val_precision: 0.1996 - val_recall: 0.2691 - val_f1_score: 0.2292
# Epoch 24/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1257 - accuracy: 0.9489 - precision: 0.8356 - recall: 0.7215 - f1_score: 0.7744 - val_loss: 0.5758 - val_accuracy: 0.8396 - val_precision: 0.2012 - val_recall: 0.2691 - val_f1_score: 0.2302
# Epoch 25/30
# 671/671 [==============================] - 158s 235ms/step - loss: 0.1213 - accuracy: 0.9507 - precision: 0.8428 - recall: 0.7307 - f1_score: 0.7828 - val_loss: 0.5874 - val_accuracy: 0.8454 - val_precision: 0.2004 - val_recall: 0.2454 - val_f1_score: 0.2206
# Epoch 26/30
# 671/671 [==============================] - 164s 245ms/step - loss: 0.1204 - accuracy: 0.9509 - precision: 0.8404 - recall: 0.7355 - f1_score: 0.7845 - val_loss: 0.5606 - val_accuracy: 0.8539 - val_precision: 0.2005 - val_recall: 0.2137 - val_f1_score: 0.2069
# Epoch 27/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1229 - accuracy: 0.9495 - precision: 0.8355 - recall: 0.7282 - f1_score: 0.7782 - val_loss: 0.5725 - val_accuracy: 0.8426 - val_precision: 0.1992 - val_recall: 0.2533 - val_f1_score: 0.2230
# Epoch 28/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1199 - accuracy: 0.9512 - precision: 0.8444 - recall: 0.7344 - f1_score: 0.7856 - val_loss: 0.5780 - val_accuracy: 0.8464 - val_precision: 0.2085 - val_recall: 0.2586 - val_f1_score: 0.2309
# Epoch 29/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1231 - accuracy: 0.9504 - precision: 0.8388 - recall: 0.7328 - f1_score: 0.7822 - val_loss: 0.5680 - val_accuracy: 0.8363 - val_precision: 0.1898 - val_recall: 0.2559 - val_f1_score: 0.2180
# Epoch 30/30
# 671/671 [==============================] - 161s 240ms/step - loss: 0.1183 - accuracy: 0.9524 - precision: 0.8474 - recall: 0.7419 - f1_score: 0.7911 - val_loss: 0.5580 - val_accuracy: 0.8546 - val_precision: 0.2078 - val_recall: 0.2243 - val_f1_score: 0.2157

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 90 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 6s 65ms/step
# 671/671 [==============================] - 45s 67ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7892260644554222
# Train accuracy: 0.9353793810589113

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8186309103740297
# Train accuracy: 0.9570749440715883

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8358033403904963
# Train accuracy: 0.9688898210290827

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8546224417784051
# Train accuracy: 0.977069351230425

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_vars_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights('./fine_models/model_vars_ri_f1.h5')

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 4s 49ms/step
# 671/671 [==============================] - 33s 50ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7786403199247236
# Train accuracy: 0.9137770320656227

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8087508821453776
# Train accuracy: 0.9401099925428784

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8278052223006351
# Train accuracy: 0.9540221849366145

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.851329099035521
# Train accuracy: 0.9653010812826249
