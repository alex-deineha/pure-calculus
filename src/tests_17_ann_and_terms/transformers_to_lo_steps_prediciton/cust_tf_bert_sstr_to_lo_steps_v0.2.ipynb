# %% [markdown]
# # import the dependencies

# %%
import sys
from collections import Counter

import numpy as np
import pandas as pd

from tqdm import tqdm

import tensorflow as tf
from transformers import RobertaTokenizerFast


from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
from matplotlib import rcParams

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Prepare data

# %%
all_data = pd.read_csv("../lstm_lo_steps_prediction/data/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)

# filter out steps_lo that are more than 30
all_data = all_data[[steps_lo < 31 for steps_lo in all_data['steps_num_lo']]]

print(f"max steps count: {max(all_data['steps_num_lo'])}")
print(f"min steps count: {min(all_data['steps_num_lo'])}")

# make test/train split
x_train, x_test, y_train_, y_test_ = train_test_split(all_data["simple_terms"].tolist(),
                                                      all_data["steps_num_lo"].tolist(),
                                                      test_size=0.2, random_state=42)

print(f"Count training samples: {len(y_train_)}")
print(f"Count testing samples: {len(y_test_)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# max steps count: 30
# min steps count: 0
# Count training samples: 2952
# Count testing samples: 739

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("./fine_models", max_len=512)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y") for x_ in x_train]
x_test = [x_.replace("@x.", "y") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "steps_lo": y_train_})
test_df = pd.DataFrame({"term_str": x_test, "steps_lo": y_test_})

label_encoder = {key_: [0.0] * 31 for key_ in range(31)}
for key_ in label_encoder.keys():
    label_encoder[key_][key_] = 1.0

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=512, return_tensors="tf")
    labels = tf.convert_to_tensor([label_encoder[key_] for key_ in example["steps_lo"]])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
batch_size = 3

train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Configure the model

# %%
from transformers import BertConfig

config = BertConfig(
    vocab_size=10,
    hidden_size=69,
    num_hidden_layers=1,
    num_attention_heads=3,
    intermediate_size=32,
    max_position_embeddings=512,
    num_labels=31
)

# vocab_size=30522,
# hidden_size=768,
# num_hidden_layers=12,
# num_attention_heads=12,
# intermediate_size=3072,
# hidden_act="gelu",
# hidden_dropout_prob=0.1,
# attention_probs_dropout_prob=0.1,
# max_position_embeddings=512,
# type_vocab_size=2,
# initializer_range=0.02,
# layer_norm_eps=1e-12,
# pad_token_id=0,
# position_embedding_type="absolute",
# use_cache=True,
# classifier_dropout=None,

# %%
from transformers import TFBertForSequenceClassification

model = TFBertForSequenceClassification(config=config)

# %%
model.build()
model.get_layer("bert").trainable = True
model.get_layer("classifier").trainable = True
model.compile(optimizer="adam", loss="mean_squared_error", metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  65237
#
#  dropout_4 (Dropout)         multiple                  0
#
#  classifier (Dense)          multiple                  2170
#
# =================================================================
# Total params: 67,407
# Trainable params: 67,407
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train a language model

# %%
epochs = 100
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs)
# Out:
# Epoch 1/100
# 984/984 [==============================] - 23s 18ms/step - loss: 0.0298 - accuracy: 0.1260 - val_loss: 0.0294 - val_accuracy: 0.1380
# Epoch 2/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0292 - accuracy: 0.1419 - val_loss: 0.0294 - val_accuracy: 0.1204
# Epoch 3/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0290 - accuracy: 0.1535 - val_loss: 0.0291 - val_accuracy: 0.1421
# Epoch 4/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0288 - accuracy: 0.1589 - val_loss: 0.0288 - val_accuracy: 0.1664
# Epoch 5/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0288 - accuracy: 0.1653 - val_loss: 0.0288 - val_accuracy: 0.1610
# Epoch 6/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0288 - accuracy: 0.1667 - val_loss: 0.0290 - val_accuracy: 0.1475
# Epoch 7/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0287 - accuracy: 0.1738 - val_loss: 0.0288 - val_accuracy: 0.1678
# Epoch 8/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0286 - accuracy: 0.1663 - val_loss: 0.0288 - val_accuracy: 0.1759
# Epoch 9/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0285 - accuracy: 0.1673 - val_loss: 0.0287 - val_accuracy: 0.1732
# Epoch 10/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0286 - accuracy: 0.1728 - val_loss: 0.0289 - val_accuracy: 0.1610
# Epoch 11/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0287 - accuracy: 0.1748 - val_loss: 0.0286 - val_accuracy: 0.1827
# Epoch 12/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0284 - accuracy: 0.1775 - val_loss: 0.0288 - val_accuracy: 0.1529
# Epoch 13/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0285 - accuracy: 0.1660 - val_loss: 0.0290 - val_accuracy: 0.1705
# Epoch 14/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0285 - accuracy: 0.1670 - val_loss: 0.0288 - val_accuracy: 0.1610
# Epoch 15/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0284 - accuracy: 0.1734 - val_loss: 0.0287 - val_accuracy: 0.1746
# Epoch 16/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0284 - accuracy: 0.1704 - val_loss: 0.0287 - val_accuracy: 0.1583
# Epoch 17/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0283 - accuracy: 0.1768 - val_loss: 0.0290 - val_accuracy: 0.1556
# Epoch 18/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0284 - accuracy: 0.1812 - val_loss: 0.0288 - val_accuracy: 0.1678
# Epoch 19/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0283 - accuracy: 0.1772 - val_loss: 0.0289 - val_accuracy: 0.1746
# Epoch 20/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0282 - accuracy: 0.1806 - val_loss: 0.0289 - val_accuracy: 0.1773
# Epoch 21/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0283 - accuracy: 0.1880 - val_loss: 0.0289 - val_accuracy: 0.1719
# Epoch 22/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0282 - accuracy: 0.1843 - val_loss: 0.0288 - val_accuracy: 0.1691
# Epoch 23/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0282 - accuracy: 0.1826 - val_loss: 0.0289 - val_accuracy: 0.1583
# Epoch 24/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0281 - accuracy: 0.1934 - val_loss: 0.0287 - val_accuracy: 0.1610
# Epoch 25/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0282 - accuracy: 0.1897 - val_loss: 0.0290 - val_accuracy: 0.1502
# Epoch 26/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0282 - accuracy: 0.1789 - val_loss: 0.0287 - val_accuracy: 0.1759
# Epoch 27/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0281 - accuracy: 0.1850 - val_loss: 0.0289 - val_accuracy: 0.1651
# Epoch 28/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1914 - val_loss: 0.0288 - val_accuracy: 0.1651
# Epoch 29/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1914 - val_loss: 0.0290 - val_accuracy: 0.1624
# Epoch 30/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1978 - val_loss: 0.0289 - val_accuracy: 0.1854
# Epoch 31/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1992 - val_loss: 0.0288 - val_accuracy: 0.1597
# Epoch 32/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1968 - val_loss: 0.0287 - val_accuracy: 0.1678
# Epoch 33/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0280 - accuracy: 0.1961 - val_loss: 0.0288 - val_accuracy: 0.1597
# Epoch 34/100
# 984/984 [==============================] - 17s 18ms/step - loss: 0.0278 - accuracy: 0.2100 - val_loss: 0.0288 - val_accuracy: 0.1705
# Epoch 35/100
# 984/984 [==============================] - 17s 18ms/step - loss: 0.0279 - accuracy: 0.1958 - val_loss: 0.0287 - val_accuracy: 0.1529
# Epoch 36/100
# 984/984 [==============================] - 17s 18ms/step - loss: 0.0281 - accuracy: 0.2016 - val_loss: 0.0288 - val_accuracy: 0.1529
# Epoch 37/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2043 - val_loss: 0.0288 - val_accuracy: 0.1583
# Epoch 38/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.1999 - val_loss: 0.0287 - val_accuracy: 0.1556
# Epoch 39/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0278 - accuracy: 0.2009 - val_loss: 0.0287 - val_accuracy: 0.1529
# Epoch 40/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2026 - val_loss: 0.0287 - val_accuracy: 0.1502
# Epoch 41/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2093 - val_loss: 0.0287 - val_accuracy: 0.1556
# Epoch 42/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2046 - val_loss: 0.0287 - val_accuracy: 0.1637
# Epoch 43/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2026 - val_loss: 0.0287 - val_accuracy: 0.1610
# Epoch 44/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2043 - val_loss: 0.0287 - val_accuracy: 0.1556
# Epoch 45/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0278 - accuracy: 0.2148 - val_loss: 0.0287 - val_accuracy: 0.1583
# Epoch 46/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0279 - accuracy: 0.2026 - val_loss: 0.0286 - val_accuracy: 0.1624
# Epoch 47/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0277 - accuracy: 0.2185 - val_loss: 0.0288 - val_accuracy: 0.1651
# Epoch 48/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0278 - accuracy: 0.2090 - val_loss: 0.0287 - val_accuracy: 0.1597
# Epoch 49/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2202 - val_loss: 0.0287 - val_accuracy: 0.1624
# Epoch 50/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0277 - accuracy: 0.2141 - val_loss: 0.0286 - val_accuracy: 0.1597
# Epoch 51/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0277 - accuracy: 0.2222 - val_loss: 0.0286 - val_accuracy: 0.1705
# Epoch 52/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0277 - accuracy: 0.2161 - val_loss: 0.0287 - val_accuracy: 0.1570
# Epoch 53/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0277 - accuracy: 0.2195 - val_loss: 0.0289 - val_accuracy: 0.1597
# Epoch 54/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2188 - val_loss: 0.0288 - val_accuracy: 0.1624
# Epoch 55/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2229 - val_loss: 0.0288 - val_accuracy: 0.1516
# Epoch 56/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2263 - val_loss: 0.0288 - val_accuracy: 0.1651
# Epoch 57/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2273 - val_loss: 0.0288 - val_accuracy: 0.1610
# Epoch 58/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2219 - val_loss: 0.0289 - val_accuracy: 0.1570
# Epoch 59/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2219 - val_loss: 0.0290 - val_accuracy: 0.1719
# Epoch 60/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2293 - val_loss: 0.0290 - val_accuracy: 0.1691
# Epoch 61/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2249 - val_loss: 0.0289 - val_accuracy: 0.1773
# Epoch 62/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2287 - val_loss: 0.0288 - val_accuracy: 0.1651
# Epoch 63/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2259 - val_loss: 0.0289 - val_accuracy: 0.1827
# Epoch 64/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2270 - val_loss: 0.0289 - val_accuracy: 0.1637
# Epoch 65/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2287 - val_loss: 0.0289 - val_accuracy: 0.1773
# Epoch 66/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2202 - val_loss: 0.0289 - val_accuracy: 0.1502
# Epoch 67/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2097 - val_loss: 0.0288 - val_accuracy: 0.1583
# Epoch 68/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2368 - val_loss: 0.0291 - val_accuracy: 0.1678
# Epoch 69/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2327 - val_loss: 0.0288 - val_accuracy: 0.1705
# Epoch 70/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2361 - val_loss: 0.0290 - val_accuracy: 0.1637
# Epoch 71/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2263 - val_loss: 0.0287 - val_accuracy: 0.1475
# Epoch 72/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2320 - val_loss: 0.0290 - val_accuracy: 0.1664
# Epoch 73/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2327 - val_loss: 0.0289 - val_accuracy: 0.1475
# Epoch 74/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2293 - val_loss: 0.0289 - val_accuracy: 0.1570
# Epoch 75/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2324 - val_loss: 0.0289 - val_accuracy: 0.1597
# Epoch 76/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2378 - val_loss: 0.0288 - val_accuracy: 0.1624
# Epoch 77/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0273 - accuracy: 0.2324 - val_loss: 0.0291 - val_accuracy: 0.1502
# Epoch 78/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2270 - val_loss: 0.0292 - val_accuracy: 0.1529
# Epoch 79/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0272 - accuracy: 0.2371 - val_loss: 0.0290 - val_accuracy: 0.1813
# Epoch 80/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0273 - accuracy: 0.2337 - val_loss: 0.0289 - val_accuracy: 0.1637
# Epoch 81/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2263 - val_loss: 0.0289 - val_accuracy: 0.1651
# Epoch 82/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2361 - val_loss: 0.0290 - val_accuracy: 0.1583
# Epoch 83/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0272 - accuracy: 0.2392 - val_loss: 0.0291 - val_accuracy: 0.1691
# Epoch 84/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2381 - val_loss: 0.0291 - val_accuracy: 0.1624
# Epoch 85/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2446 - val_loss: 0.0290 - val_accuracy: 0.1529
# Epoch 86/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2449 - val_loss: 0.0289 - val_accuracy: 0.1773
# Epoch 87/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2354 - val_loss: 0.0290 - val_accuracy: 0.1773
# Epoch 88/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2524 - val_loss: 0.0290 - val_accuracy: 0.1759
# Epoch 89/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2456 - val_loss: 0.0290 - val_accuracy: 0.1705
# Epoch 90/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0272 - accuracy: 0.2466 - val_loss: 0.0290 - val_accuracy: 0.1624
# Epoch 91/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2493 - val_loss: 0.0291 - val_accuracy: 0.1705
# Epoch 92/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2436 - val_loss: 0.0289 - val_accuracy: 0.1746
# Epoch 93/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0270 - accuracy: 0.2530 - val_loss: 0.0291 - val_accuracy: 0.1678
# Epoch 94/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2364 - val_loss: 0.0291 - val_accuracy: 0.1800
# Epoch 95/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0270 - accuracy: 0.2415 - val_loss: 0.0290 - val_accuracy: 0.1610
# Epoch 96/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0270 - accuracy: 0.2541 - val_loss: 0.0290 - val_accuracy: 0.1840
# Epoch 97/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2419 - val_loss: 0.0290 - val_accuracy: 0.1705
# Epoch 98/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0270 - accuracy: 0.2470 - val_loss: 0.0290 - val_accuracy: 0.1624
# Epoch 99/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0269 - accuracy: 0.2534 - val_loss: 0.0289 - val_accuracy: 0.1759
# Epoch 100/100
# 984/984 [==============================] - 16s 17ms/step - loss: 0.0271 - accuracy: 0.2483 - val_loss: 0.0289 - val_accuracy: 0.1664

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("accuracy")

plt.legend()
plt.show()

# %%
train_preds = model.predict(train_dataset)
test_preds = model.predict(test_dataset)
# Out:
# 984/984 [==============================] - 7s 6ms/step
# 247/247 [==============================] - 2s 7ms/step

# %%
train_preds_nums = [np.argmax(x_) for x_ in train_preds.logits]
test_preds_nums = [np.argmax(x_) for x_ in test_preds.logits]
train_true_nums = y_train_
test_true_nums = y_test_

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


def draw_pred_lines(y_pred, y_real):
    drawing_df = pd.DataFrame({"Pred": y_pred, "Real": y_real})
    drawing_df = drawing_df.sort_values("Real").reset_index(drop=True)

    for key_, val_ in drawing_df.items():
        plt.plot(range(len(val_)), val_, label=key_)

    plt.xlabel("No")
    plt.ylabel("Redexes count")
    plt.title("Pred vs Real Step Time")
    plt.legend()
    plt.show()

# %%
def draw_pred_scatter(y_pred, y_real):
    plt.scatter(y_real, y_pred, s=3)
    plt.plot([0, 30], [0, 30], color='gray', linestyle='--')

    plt.xlabel("Real reduction time")
    plt.ylabel("Predicted time")
    plt.title("Pred vs Real Reduction time")
    plt.show()

# %%
draw_pred_scatter(train_preds_nums, train_true_nums)
draw_pred_scatter(test_preds_nums, test_true_nums)

# %%
print("Train accuracy:", calculate_accuracy(train_true_nums, train_preds_nums))
draw_pred_lines(train_preds_nums, train_true_nums)
# Out:
# Train accuracy: 0.23915989159891599

# %%
print("Test accuracy:", calculate_accuracy(test_true_nums, test_preds_nums))
draw_pred_lines(test_preds_nums, test_true_nums)
# Out:
# Test accuracy: 0.16644113667117727

# %%
epochs = 100
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs)
# Out:
# Epoch 1/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2480 - val_loss: 0.0290 - val_accuracy: 0.1651
# Epoch 2/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0271 - accuracy: 0.2520 - val_loss: 0.0294 - val_accuracy: 0.1583
# Epoch 3/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0271 - accuracy: 0.2446 - val_loss: 0.0293 - val_accuracy: 0.1502
# Epoch 4/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0269 - accuracy: 0.2544 - val_loss: 0.0295 - val_accuracy: 0.1664
# Epoch 5/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0269 - accuracy: 0.2470 - val_loss: 0.0293 - val_accuracy: 0.1732
# Epoch 6/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0269 - accuracy: 0.2453 - val_loss: 0.0296 - val_accuracy: 0.1543
# Epoch 7/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0269 - accuracy: 0.2524 - val_loss: 0.0294 - val_accuracy: 0.1651
# Epoch 8/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0269 - accuracy: 0.2510 - val_loss: 0.0291 - val_accuracy: 0.1583
# Epoch 9/100
# 984/984 [==============================] - 22s 23ms/step - loss: 0.0269 - accuracy: 0.2520 - val_loss: 0.0293 - val_accuracy: 0.1475
# Epoch 10/100
# 984/984 [==============================] - 21s 21ms/step - loss: 0.0269 - accuracy: 0.2507 - val_loss: 0.0294 - val_accuracy: 0.1434
# Epoch 11/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0268 - accuracy: 0.2558 - val_loss: 0.0294 - val_accuracy: 0.1434
# Epoch 12/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0269 - accuracy: 0.2530 - val_loss: 0.0291 - val_accuracy: 0.1637
# Epoch 13/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0271 - accuracy: 0.2409 - val_loss: 0.0293 - val_accuracy: 0.1502
# Epoch 14/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0269 - accuracy: 0.2564 - val_loss: 0.0293 - val_accuracy: 0.1651
# Epoch 15/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0268 - accuracy: 0.2622 - val_loss: 0.0298 - val_accuracy: 0.1759
# Epoch 16/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0268 - accuracy: 0.2561 - val_loss: 0.0293 - val_accuracy: 0.1624
# Epoch 17/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0268 - accuracy: 0.2507 - val_loss: 0.0294 - val_accuracy: 0.1597
# Epoch 18/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0267 - accuracy: 0.2561 - val_loss: 0.0292 - val_accuracy: 0.1475
# Epoch 19/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0267 - accuracy: 0.2547 - val_loss: 0.0296 - val_accuracy: 0.1556
# Epoch 20/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0267 - accuracy: 0.2629 - val_loss: 0.0292 - val_accuracy: 0.1786
# Epoch 21/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0268 - accuracy: 0.2615 - val_loss: 0.0295 - val_accuracy: 0.1475
# Epoch 22/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0268 - accuracy: 0.2497 - val_loss: 0.0300 - val_accuracy: 0.1529
# Epoch 23/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0267 - accuracy: 0.2530 - val_loss: 0.0293 - val_accuracy: 0.1610
# Epoch 24/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0269 - accuracy: 0.2530 - val_loss: 0.0294 - val_accuracy: 0.1488
# Epoch 25/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0269 - accuracy: 0.2442 - val_loss: 0.0293 - val_accuracy: 0.1583
# Epoch 26/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0267 - accuracy: 0.2605 - val_loss: 0.0294 - val_accuracy: 0.1678
# Epoch 27/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0266 - accuracy: 0.2591 - val_loss: 0.0294 - val_accuracy: 0.1597
# Epoch 28/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0266 - accuracy: 0.2581 - val_loss: 0.0296 - val_accuracy: 0.1516
# Epoch 29/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0267 - accuracy: 0.2591 - val_loss: 0.0294 - val_accuracy: 0.1394
# Epoch 30/100
# 984/984 [==============================] - 21s 21ms/step - loss: 0.0267 - accuracy: 0.2558 - val_loss: 0.0299 - val_accuracy: 0.1407
# Epoch 31/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0267 - accuracy: 0.2558 - val_loss: 0.0297 - val_accuracy: 0.1475
# Epoch 32/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0266 - accuracy: 0.2517 - val_loss: 0.0299 - val_accuracy: 0.1502
# Epoch 33/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0266 - accuracy: 0.2619 - val_loss: 0.0294 - val_accuracy: 0.1543
# Epoch 34/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0266 - accuracy: 0.2547 - val_loss: 0.0293 - val_accuracy: 0.1583
# Epoch 35/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0267 - accuracy: 0.2581 - val_loss: 0.0293 - val_accuracy: 0.1624
# Epoch 36/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0263 - accuracy: 0.2727 - val_loss: 0.0298 - val_accuracy: 0.1516
# Epoch 37/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0266 - accuracy: 0.2608 - val_loss: 0.0298 - val_accuracy: 0.1448
# Epoch 38/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0265 - accuracy: 0.2747 - val_loss: 0.0295 - val_accuracy: 0.1570
# Epoch 39/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0266 - accuracy: 0.2683 - val_loss: 0.0300 - val_accuracy: 0.1502
# Epoch 40/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0264 - accuracy: 0.2683 - val_loss: 0.0297 - val_accuracy: 0.1434
# Epoch 41/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0266 - accuracy: 0.2636 - val_loss: 0.0295 - val_accuracy: 0.1502
# Epoch 42/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0267 - accuracy: 0.2636 - val_loss: 0.0301 - val_accuracy: 0.1610
# Epoch 43/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0264 - accuracy: 0.2656 - val_loss: 0.0295 - val_accuracy: 0.1664
# Epoch 44/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0265 - accuracy: 0.2619 - val_loss: 0.0294 - val_accuracy: 0.1583
# Epoch 45/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0265 - accuracy: 0.2629 - val_loss: 0.0300 - val_accuracy: 0.1516
# Epoch 46/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0267 - accuracy: 0.2619 - val_loss: 0.0300 - val_accuracy: 0.1475
# Epoch 47/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0265 - accuracy: 0.2652 - val_loss: 0.0298 - val_accuracy: 0.1394
# Epoch 48/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2744 - val_loss: 0.0301 - val_accuracy: 0.1488
# Epoch 49/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0266 - accuracy: 0.2595 - val_loss: 0.0298 - val_accuracy: 0.1583
# Epoch 50/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0265 - accuracy: 0.2551 - val_loss: 0.0294 - val_accuracy: 0.1556
# Epoch 51/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0266 - accuracy: 0.2690 - val_loss: 0.0299 - val_accuracy: 0.1394
# Epoch 52/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0265 - accuracy: 0.2558 - val_loss: 0.0299 - val_accuracy: 0.1407
# Epoch 53/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2646 - val_loss: 0.0300 - val_accuracy: 0.1367
# Epoch 54/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2673 - val_loss: 0.0298 - val_accuracy: 0.1529
# Epoch 55/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2724 - val_loss: 0.0295 - val_accuracy: 0.1529
# Epoch 56/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2605 - val_loss: 0.0294 - val_accuracy: 0.1570
# Epoch 57/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2730 - val_loss: 0.0302 - val_accuracy: 0.1488
# Epoch 58/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2724 - val_loss: 0.0296 - val_accuracy: 0.1502
# Epoch 59/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2690 - val_loss: 0.0302 - val_accuracy: 0.1421
# Epoch 60/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0265 - accuracy: 0.2636 - val_loss: 0.0305 - val_accuracy: 0.1597
# Epoch 61/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2602 - val_loss: 0.0297 - val_accuracy: 0.1461
# Epoch 62/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0264 - accuracy: 0.2700 - val_loss: 0.0297 - val_accuracy: 0.1516
# Epoch 63/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2713 - val_loss: 0.0298 - val_accuracy: 0.1502
# Epoch 64/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0263 - accuracy: 0.2713 - val_loss: 0.0297 - val_accuracy: 0.1570
# Epoch 65/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0265 - accuracy: 0.2795 - val_loss: 0.0295 - val_accuracy: 0.1570
# Epoch 66/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0263 - accuracy: 0.2727 - val_loss: 0.0295 - val_accuracy: 0.1502
# Epoch 67/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2737 - val_loss: 0.0297 - val_accuracy: 0.1570
# Epoch 68/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2663 - val_loss: 0.0298 - val_accuracy: 0.1543
# Epoch 69/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2734 - val_loss: 0.0300 - val_accuracy: 0.1570
# Epoch 70/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2730 - val_loss: 0.0299 - val_accuracy: 0.1475
# Epoch 71/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0262 - accuracy: 0.2781 - val_loss: 0.0299 - val_accuracy: 0.1610
# Epoch 72/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0262 - accuracy: 0.2680 - val_loss: 0.0300 - val_accuracy: 0.1583
# Epoch 73/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0261 - accuracy: 0.2791 - val_loss: 0.0298 - val_accuracy: 0.1556
# Epoch 74/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0263 - accuracy: 0.2710 - val_loss: 0.0296 - val_accuracy: 0.1705
# Epoch 75/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0264 - accuracy: 0.2676 - val_loss: 0.0301 - val_accuracy: 0.1529
# Epoch 76/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0263 - accuracy: 0.2690 - val_loss: 0.0298 - val_accuracy: 0.1651
# Epoch 77/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0265 - accuracy: 0.2696 - val_loss: 0.0295 - val_accuracy: 0.1543
# Epoch 78/100
# 984/984 [==============================] - 21s 21ms/step - loss: 0.0263 - accuracy: 0.2669 - val_loss: 0.0295 - val_accuracy: 0.1502
# Epoch 79/100
# 984/984 [==============================] - 21s 21ms/step - loss: 0.0262 - accuracy: 0.2785 - val_loss: 0.0299 - val_accuracy: 0.1637
# Epoch 80/100
# 984/984 [==============================] - 21s 21ms/step - loss: 0.0262 - accuracy: 0.2781 - val_loss: 0.0300 - val_accuracy: 0.1786
# Epoch 81/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2605 - val_loss: 0.0298 - val_accuracy: 0.1678
# Epoch 82/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0262 - accuracy: 0.2801 - val_loss: 0.0294 - val_accuracy: 0.1664
# Epoch 83/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0264 - accuracy: 0.2663 - val_loss: 0.0297 - val_accuracy: 0.1516
# Epoch 84/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0263 - accuracy: 0.2680 - val_loss: 0.0304 - val_accuracy: 0.1516
# Epoch 85/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0263 - accuracy: 0.2744 - val_loss: 0.0296 - val_accuracy: 0.1624
# Epoch 86/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0265 - accuracy: 0.2588 - val_loss: 0.0292 - val_accuracy: 0.1434
# Epoch 87/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0261 - accuracy: 0.2734 - val_loss: 0.0294 - val_accuracy: 0.1610
# Epoch 88/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0263 - accuracy: 0.2703 - val_loss: 0.0296 - val_accuracy: 0.1461
# Epoch 89/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0263 - accuracy: 0.2693 - val_loss: 0.0296 - val_accuracy: 0.1516
# Epoch 90/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0261 - accuracy: 0.2730 - val_loss: 0.0298 - val_accuracy: 0.1394
# Epoch 91/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0261 - accuracy: 0.2822 - val_loss: 0.0292 - val_accuracy: 0.1678
# Epoch 92/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0261 - accuracy: 0.2724 - val_loss: 0.0298 - val_accuracy: 0.1380
# Epoch 93/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0260 - accuracy: 0.2737 - val_loss: 0.0294 - val_accuracy: 0.1488
# Epoch 94/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0262 - accuracy: 0.2724 - val_loss: 0.0298 - val_accuracy: 0.1434
# Epoch 95/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0260 - accuracy: 0.2856 - val_loss: 0.0295 - val_accuracy: 0.1529
# Epoch 96/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0263 - accuracy: 0.2700 - val_loss: 0.0298 - val_accuracy: 0.1394
# Epoch 97/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0263 - accuracy: 0.2686 - val_loss: 0.0294 - val_accuracy: 0.1624
# Epoch 98/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0262 - accuracy: 0.2788 - val_loss: 0.0291 - val_accuracy: 0.1448
# Epoch 99/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0262 - accuracy: 0.2805 - val_loss: 0.0294 - val_accuracy: 0.1624
# Epoch 100/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0262 - accuracy: 0.2676 - val_loss: 0.0296 - val_accuracy: 0.1394

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()


plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("accuracy")

plt.legend()
plt.show()

# %%
train_preds = model.predict(train_dataset)
test_preds = model.predict(test_dataset)
train_preds_nums = [np.argmax(x_) for x_ in train_preds.logits]
test_preds_nums = [np.argmax(x_) for x_ in test_preds.logits]
train_true_nums = y_train_
test_true_nums = y_test_


def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


def draw_pred_lines(y_pred, y_real):
    drawing_df = pd.DataFrame({"Pred": y_pred, "Real": y_real})
    drawing_df = drawing_df.sort_values("Real").reset_index(drop=True)

    for key_, val_ in drawing_df.items():
        plt.plot(range(len(val_)), val_, label=key_)

    plt.xlabel("No")
    plt.ylabel("Redexes count")
    plt.title("Pred vs Real Step Time")
    plt.legend()
    plt.show()


print("Train accuracy:", calculate_accuracy(train_true_nums, train_preds_nums))
draw_pred_lines(train_preds_nums, train_true_nums)
print("Test accuracy:", calculate_accuracy(test_true_nums, test_preds_nums))
draw_pred_lines(test_preds_nums, test_true_nums)
# Out:
# 984/984 [==============================] - 7s 8ms/step
# 247/247 [==============================] - 2s 8ms/step
# Train accuracy: 0.2540650406504065
# Test accuracy: 0.13937753721244925
