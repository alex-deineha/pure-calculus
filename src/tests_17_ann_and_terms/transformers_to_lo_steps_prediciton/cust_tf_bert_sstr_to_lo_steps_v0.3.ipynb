# %% [markdown]
# # import the dependencies

# %%
import sys
from collections import Counter

import numpy as np
import pandas as pd

from tqdm import tqdm

import tensorflow as tf
from transformers import RobertaTokenizerFast


from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
from matplotlib import rcParams

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Prepare data

# %%
all_data = pd.read_csv("../lstm_lo_steps_prediction/data/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)

# filter out steps_lo that are more than 30
all_data = all_data[[steps_lo < 31 for steps_lo in all_data['steps_num_lo']]]

print(f"max steps count: {max(all_data['steps_num_lo'])}")
print(f"min steps count: {min(all_data['steps_num_lo'])}")

# make test/train split
x_train, x_test, y_train_, y_test_ = train_test_split(all_data["simple_terms"].tolist(),
                                                      all_data["steps_num_lo"].tolist(),
                                                      test_size=0.2, random_state=42)

print(f"Count training samples: {len(y_train_)}")
print(f"Count testing samples: {len(y_test_)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# max steps count: 30
# min steps count: 0
# Count training samples: 2952
# Count testing samples: 739

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("./fine_models", max_len=512)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "steps_lo": y_train_})
test_df = pd.DataFrame({"term_str": x_test, "steps_lo": y_test_})

label_encoder = {key_: [0.0] * 31 for key_ in range(31)}
for key_ in label_encoder.keys():
    label_encoder[key_][key_] = 1.0

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=512, return_tensors="tf")
    labels = tf.convert_to_tensor([label_encoder[key_] for key_ in example["steps_lo"]])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
batch_size = 3

train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Configure the model

# %%
from transformers import BertConfig

config = BertConfig(
    vocab_size=10,
    hidden_size=69,
    num_hidden_layers=1,
    num_attention_heads=3,
    intermediate_size=32,
    max_position_embeddings=512,
    num_labels=31
)

# vocab_size=30522,
# hidden_size=768,
# num_hidden_layers=12,
# num_attention_heads=12,
# intermediate_size=3072,
# hidden_act="gelu",
# hidden_dropout_prob=0.1,
# attention_probs_dropout_prob=0.1,
# max_position_embeddings=512,
# type_vocab_size=2,
# initializer_range=0.02,
# layer_norm_eps=1e-12,
# pad_token_id=0,
# position_embedding_type="absolute",
# use_cache=True,
# classifier_dropout=None,

# %%
from transformers import TFBertForSequenceClassification

model = TFBertForSequenceClassification(config=config)

# %%
model.build()
model.get_layer("bert").trainable = True
model.get_layer("classifier").trainable = True
model.compile(optimizer="adam", loss="mean_squared_error", metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  65237
#
#  dropout_4 (Dropout)         multiple                  0
#
#  classifier (Dense)          multiple                  2170
#
# =================================================================
# Total params: 67,407
# Trainable params: 67,407
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train a language model

# %%
epochs = 100
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs)
# Out:
# Epoch 1/100
# 984/984 [==============================] - 26s 20ms/step - loss: 0.0299 - accuracy: 0.1253 - val_loss: 0.0292 - val_accuracy: 0.1367
# Epoch 2/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0293 - accuracy: 0.1430 - val_loss: 0.0292 - val_accuracy: 0.1516
# Epoch 3/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0290 - accuracy: 0.1507 - val_loss: 0.0289 - val_accuracy: 0.1461
# Epoch 4/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0289 - accuracy: 0.1545 - val_loss: 0.0289 - val_accuracy: 0.1488
# Epoch 5/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0289 - accuracy: 0.1646 - val_loss: 0.0287 - val_accuracy: 0.1691
# Epoch 6/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0288 - accuracy: 0.1646 - val_loss: 0.0287 - val_accuracy: 0.1678
# Epoch 7/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0288 - accuracy: 0.1582 - val_loss: 0.0288 - val_accuracy: 0.1651
# Epoch 8/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0286 - accuracy: 0.1711 - val_loss: 0.0288 - val_accuracy: 0.1691
# Epoch 9/100
# 984/984 [==============================] - 20s 20ms/step - loss: 0.0286 - accuracy: 0.1677 - val_loss: 0.0287 - val_accuracy: 0.1759
# Epoch 10/100
# 984/984 [==============================] - 20s 21ms/step - loss: 0.0285 - accuracy: 0.1728 - val_loss: 0.0286 - val_accuracy: 0.1691
# Epoch 11/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0285 - accuracy: 0.1728 - val_loss: 0.0290 - val_accuracy: 0.1367
# Epoch 12/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0285 - accuracy: 0.1731 - val_loss: 0.0288 - val_accuracy: 0.1664
# Epoch 13/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0284 - accuracy: 0.1728 - val_loss: 0.0288 - val_accuracy: 0.1719
# Epoch 14/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0284 - accuracy: 0.1762 - val_loss: 0.0287 - val_accuracy: 0.1543
# Epoch 15/100
# 984/984 [==============================] - 19s 20ms/step - loss: 0.0284 - accuracy: 0.1799 - val_loss: 0.0291 - val_accuracy: 0.1719
# Epoch 16/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.
100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0277 - accuracy: 0.2134 - val_loss: 0.0289 - val_accuracy: 0.1583
# Epoch 48/100
# 984/984 [==============================] - 19s 19ms/step - loss: 0.0276 - accuracy: 0.2229 - val_loss: 0.0289 - val_accuracy: 0.1543
# Epoch 49/100
# 984/984 [==============================] - 17s 18ms/step - loss: 0.0276 - accuracy: 0.2158 - val_loss: 0.0290 - val_accuracy: 0.1570
# Epoch 50/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0277 - accuracy: 0.2131 - val_loss: 0.0290 - val_accuracy: 0.1488
# Epoch 51/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2144 - val_loss: 0.0290 - val_accuracy: 0.1502
# Epoch 52/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2175 - val_loss: 0.0290 - val_accuracy: 0.1543
# Epoch 53/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0277 - accuracy: 0.2080 - val_loss: 0.0289 - val_accuracy: 0.1610
# Epoch 54/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2236 - val_loss: 0.0291 - val_accuracy: 0.1421
# Epoch 55/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2232 - val_loss: 0.0289 - val_accuracy: 0.1556
# Epoch 56/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0276 - accuracy: 0.2165 - val_loss: 0.0290 - val_accuracy: 0.1340
# Epoch 57/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2199 - val_loss: 0.0290 - val_accuracy: 0.1353
# Epoch 58/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2229 - val_loss: 0.0289 - val_accuracy: 0.1353
# Epoch 59/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0275 - accuracy: 0.2263 - val_loss: 0.0287 - val_accuracy: 0.1637
# Epoch 60/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2253 - val_loss: 0.0290 - val_accuracy: 0.1434
# Epoch 61/100
# 984/984 [==============================] - 17s 18ms/step - loss: 0.0275 - accuracy: 0.2270 - val_loss: 0.0290 - val_accuracy: 0.1461
# Epoch 62/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2229 - val_loss: 0.0291 - val_accuracy: 0.1407
# Epoch 63/100
# 984/984 [==============================] - 17s 17ms/step - loss: 0.0274 - accuracy: 0.2266 - val_loss: 0.0289 - val_accuracy: 0.1407
# Epoch 64/100
# 984/984 [==============================] - 18s 19ms/step - loss: 0.0275 - accuracy: 0.2178 - val_loss: 0.0290 - val_accuracy: 0.1461
# Epoch 65/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0274 - accuracy: 0.2249 - val_loss: 0.0288 - val_accuracy: 0.1691
# Epoch 66/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0275 - accuracy: 0.2229 - val_loss: 0.0287 - val_accuracy: 0.1583
# Epoch 67/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0274 - accuracy: 0.2293 - val_loss: 0.0291 - val_accuracy: 0.1394
# Epoch 68/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0274 - accuracy: 0.2263 - val_loss: 0.0290 - val_accuracy: 0.1488
# Epoch 69/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2283 - val_loss: 0.0290 - val_accuracy: 0.1597
# Epoch 70/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0274 - accuracy: 0.2165 - val_loss: 0.0288 - val_accuracy: 0.1637
# Epoch 71/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2270 - val_loss: 0.0288 - val_accuracy: 0.1624
# Epoch 72/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2392 - val_loss: 0.0289 - val_accuracy: 0.1529
# Epoch 73/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2361 - val_loss: 0.0293 - val_accuracy: 0.1516
# Epoch 74/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0274 - accuracy: 0.2297 - val_loss: 0.0293 - val_accuracy: 0.1502
# Epoch 75/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2263 - val_loss: 0.0289 - val_accuracy: 0.1448
# Epoch 76/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2263 - val_loss: 0.0290 - val_accuracy: 0.1543
# Epoch 77/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0273 - accuracy: 0.2293 - val_loss: 0.0290 - val_accuracy: 0.1583
# Epoch 78/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2263 - val_loss: 0.0291 - val_accuracy: 0.1529
# Epoch 79/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2293 - val_loss: 0.0289 - val_accuracy: 0.1353
# Epoch 80/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2331 - val_loss: 0.0291 - val_accuracy: 0.1394
# Epoch 81/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2310 - val_loss: 0.0292 - val_accuracy: 0.1380
# Epoch 82/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2259 - val_loss: 0.0291 - val_accuracy: 0.1488
# Epoch 83/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2470 - val_loss: 0.0290 - val_accuracy: 0.1434
# Epoch 84/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2283 - val_loss: 0.0292 - val_accuracy: 0.1461
# Epoch 85/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2459 - val_loss: 0.0292 - val_accuracy: 0.1353
# Epoch 86/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2358 - val_loss: 0.0290 - val_accuracy: 0.1313
# Epoch 87/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2398 - val_loss: 0.0292 - val_accuracy: 0.1421
# Epoch 88/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0272 - accuracy: 0.2364 - val_loss: 0.0293 - val_accuracy: 0.1394
# Epoch 89/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2398 - val_loss: 0.0291 - val_accuracy: 0.1461
# Epoch 90/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2442 - val_loss: 0.0290 - val_accuracy: 0.1502
# Epoch 91/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2331 - val_loss: 0.0292 - val_accuracy: 0.1448
# Epoch 92/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2317 - val_loss: 0.0291 - val_accuracy: 0.1475
# Epoch 93/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2378 - val_loss: 0.0293 - val_accuracy: 0.1394
# Epoch 94/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2324 - val_loss: 0.0291 - val_accuracy: 0.1421
# Epoch 95/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2381 - val_loss: 0.0291 - val_accuracy: 0.1516
# Epoch 96/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2358 - val_loss: 0.0294 - val_accuracy: 0.1516
# Epoch 97/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2446 - val_loss: 0.0291 - val_accuracy: 0.1543
# Epoch 98/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2429 - val_loss: 0.0293 - val_accuracy: 0.1543
# Epoch 99/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0271 - accuracy: 0.2337 - val_loss: 0.0293 - val_accuracy: 0.1461
# Epoch 100/100
# 984/984 [==============================] - 18s 18ms/step - loss: 0.0270 - accuracy: 0.2422 - val_loss: 0.0295 - val_accuracy: 0.1394

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("accuracy")

plt.legend()
plt.show()

# %%
train_preds = model.predict(train_dataset)
test_preds = model.predict(test_dataset)
# Out:
# 984/984 [==============================] - 8s 7ms/step
# 247/247 [==============================] - 2s 7ms/step

# %%
train_preds_nums = [np.argmax(x_) for x_ in train_preds.logits]
test_preds_nums = [np.argmax(x_) for x_ in test_preds.logits]
train_true_nums = y_train_
test_true_nums = y_test_

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


def draw_pred_lines(y_pred, y_real):
    drawing_df = pd.DataFrame({"Pred": y_pred, "Real": y_real})
    drawing_df = drawing_df.sort_values("Real").reset_index(drop=True)

    for key_, val_ in drawing_df.items():
        plt.plot(range(len(val_)), val_, label=key_)

    plt.xlabel("No")
    plt.ylabel("Redexes count")
    plt.title("Pred vs Real Step Time")
    plt.legend()
    plt.show()

# %%
print("Train accuracy:", calculate_accuracy(train_true_nums, train_preds_nums))
draw_pred_lines(train_preds_nums, train_true_nums)
# Out:
# Train accuracy: 0.2279810298102981

# %%
print("Test accuracy:", calculate_accuracy(test_true_nums, test_preds_nums))
draw_pred_lines(test_preds_nums, test_true_nums)
# Out:
# Test accuracy: 0.13937753721244925

# %%
def draw_pred_scatter(y_pred, y_real):
    plt.scatter(y_real, y_pred, s=3)
    plt.plot([0, 30], [0, 30], color='gray', linestyle='--')

    plt.xlabel("Real reduction time")
    plt.ylabel("Predicted time")
    plt.title("Pred vs Real Reduction time")
    plt.show()

# %%
draw_pred_scatter(train_preds_nums, train_true_nums)
draw_pred_scatter(test_preds_nums, test_true_nums)
