# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 160

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# max RI steps count: 1000
# max LO steps count: 219
# Count TESTING samples: 4251

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# max RI steps count: 1000
# max LO steps count: 1000
# Count TRAINING samples: 44568

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "is_ri_best": y_train})
test_df = pd.DataFrame({"term_str": x_test, "is_ri_best": y_test})

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define the model

# %%
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_structure = model.to_json()
with open("./fine_models/model_ri.json", 'w') as json_file:
    json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_ri_best_f1.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_ri.h5', save_weights_only=True, period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1, callbacks=[f1_callback, step_callback])
# Out:
# Epoch 1/160
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 697/697 [==============================] - 160s 222ms/step - loss: 0.3522 - accuracy: 0.8800 - precision: 0.1935 - recall: 0.0069 - f1_score: 0.0133 - val_loss: 0.2882 - val_accuracy: 0.9108 - val_precision: 0.5000 - val_recall: 0.0026 - val_f1_score: 0.0052
# Epoch 2/160
# 697/697 [==============================] - 153s 220ms/step - loss: 0.3305 - accuracy: 0.8829 - precision: 0.5596 - recall: 0.0117 - f1_score: 0.0228 - val_loss: 0.2738 - val_accuracy: 0.9108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/160
# 697/697 [==============================] - 147s 211ms/step - loss: 0.3241 - accuracy: 0.8847 - precision: 0.7363 - recall: 0.0283 - f1_score: 0.0545 - val_loss: 0.2742 - val_accuracy: 0.9108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 4/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.3213 - accuracy: 0.8855 - precision: 0.7232 - recall: 0.0399 - f1_score: 0.0757 - val_loss: 0.2738 - val_accuracy: 0.9108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 5/160
# 697/697 [==============================] - 153s 219ms/step - loss: 0.3192 - accuracy: 0.8864 - precision: 0.7609 - recall: 0.0468 - f1_score: 0.0882 - val_loss: 0.2764 - val_accuracy: 0.9108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 6/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.3174 - accuracy: 0.8870 - precision: 0.7647 - recall: 0.0547 - f1_score: 0.1020 - val_loss: 0.2732 - val_accuracy: 0.9108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 7/160
# 697/697 [==============================] - 154s 222ms/step - loss: 0.3157 - accuracy: 0.8876 - precision: 0.7439 - recall: 0.0644 - f1_score: 0.1186 - val_loss: 0.2712 - val_accuracy: 0.9106 - val_precision: 0.3333 - val_recall: 0.0026 - val_f1_score: 0.0052
# Epoch 8/160
# 697/697 [==============================] - 155s 223ms/step - loss: 0.3125 - accuracy: 0.8878 - precision: 0.7269 - recall: 0.0707 - f1_score: 0.1289 - val_loss: 0.2774 - val_accuracy: 0.9080 - val_precision: 0.1667 - val_recall: 0.0079 - val_f1_score: 0.0151
# Epoch 9/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.3108 - accuracy: 0.8880 - precision: 0.7029 - recall: 0.0791 - f1_score: 0.1422 - val_loss: 0.2713 - val_accuracy: 0.9101 - val_precision: 0.2000 - val_recall: 0.0026 - val_f1_score: 0.0052
# Epoch 10/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.3086 - accuracy: 0.8890 - precision: 0.7250 - recall: 0.0872 - f1_score: 0.1556 - val_loss: 0.2700 - val_accuracy: 0.9087 - val_precision: 0.2000 - val_recall: 0.0079 - val_f1_score: 0.0152
# Epoch 11/160
# 697/697 [==============================] - 157s 226ms/step - loss: 0.3065 - accuracy: 0.8891 - precision: 0.7162 - recall: 0.0921 - f1_score: 0.1633 - val_loss: 0.2698 - val_accuracy: 0.9104 - val_precision: 0.3333 - val_recall: 0.0053 - val_f1_score: 0.0104
# Epoch 12/160
# 697/697 [==============================] - 155s 223ms/step - loss: 0.3036 - accuracy: 0.8899 - precision: 0.7152 - recall: 0.1032 - f1_score: 0.1804 - val_loss: 0.2699 - val_accuracy: 0.9104 - val_precision: 0.3333 - val_recall: 0.0053 - val_f1_score: 0.0104
# Epoch 13/160
# 697/697 [==============================] - 154s 220ms/step - loss: 0.3018 - accuracy: 0.8896 - precision: 0.7076 - recall: 0.1013 - f1_score: 0.1772 - val_loss: 0.2700 - val_accuracy: 0.9099 - val_precision: 0.3000 - val_recall: 0.0079 - val_f1_score: 0.0154
# Epoch 14/160
# 697/697 [==============================] - 156s 223ms/step - loss: 0.3003 - accuracy: 0.8902 - precision: 0.7128 - recall: 0.1082 - f1_score: 0.1879 - val_loss: 0.2720 - val_accuracy: 0.9090 - val_precision: 0.2143 - val_recall: 0.0079 - val_f1_score: 0.0153
# Epoch 15/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.2988 - accuracy: 0.8903 - precision: 0.6969 - recall: 0.1160 - f1_score: 0.1989 - val_loss: 0.2683 - val_accuracy: 0.9104 - val_precision: 0.3750 - val_recall: 0.0079 - val_f1_score: 0.0155
# Epoch 16/160
# 697/697 [==============================] - 147s 210ms/step - loss: 0.2977 - accuracy: 0.8906 - precision: 0.7015 - recall: 0.1181 - f1_score: 0.2022 - val_loss: 0.2705 - val_accuracy: 0.9078 - val_precision: 0.2174 - val_recall: 0.0132 - val_f1_score: 0.0249
# Epoch 17/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.2969 - accuracy: 0.8903 - precision: 0.6933 - recall: 0.1179 - f1_score: 0.2016 - val_loss: 0.2666 - val_accuracy: 0.9101 - val_precision: 0.3333 - val_recall: 0.0079 - val_f1_score: 0.0155
# Epoch 18/160
# 697/697 [==============================] - 147s 211ms/step - loss: 0.2951 - accuracy: 0.8910 - precision: 0.6952 - recall: 0.1273 - f1_score: 0.2152 - val_loss: 0.2671 - val_accuracy: 0.9097 - val_precision: 0.2222 - val_recall: 0.0053 - val_f1_score: 0.0103
# Epoch 19/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.2931 - accuracy: 0.8914 - precision: 0.7016 - recall: 0.1304 - f1_score: 0.2199 - val_loss: 0.2691 - val_accuracy: 0.9080 - val_precision: 0.1667 - val_recall: 0.0079 - val_f1_score: 0.0151
# Epoch 20/160
# 697/697 [==============================] - 144s 207ms/step - loss: 0.2917 - accuracy: 0.8911 - precision: 0.6789 - recall: 0.1374 - f1_score: 0.2286 - val_loss: 0.2647 - val_accuracy: 0.9087 - val_precision: 0.2000 - val_recall: 0.0079 - val_f1_score: 0.0152
# Epoch 21/160
# 697/697 [==============================] - 146s 209ms/step - loss: 0.2898 - accuracy: 0.8919 - precision: 0.6943 - recall: 0.1407 - f1_score: 0.2339 - val_loss: 0.2681 - val_accuracy: 0.9108 - val_precision: 0.5000 - val_recall: 0.0053 - val_f1_score: 0.0104
# Epoch 22/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.2888 - accuracy: 0.8923 - precision: 0.7026 - recall: 0.1432 - f1_score: 0.2379 - val_loss: 0.2714 - val_accuracy: 0.9097 - val_precision: 0.2222 - val_recall: 0.0053 - val_f1_score: 0.0103
# Epoch 23/160
# 697/697 [==============================] - 152s 219ms/step - loss: 0.2864 - accuracy: 0.8932 - precision: 0.7091 - recall: 0.1533 - f1_score: 0.2521 - val_loss: 0.2688 - val_accuracy: 0.9097 - val_precision: 0.2727 - val_recall: 0.0079 - val_f1_score: 0.0154
# Epoch 24/160
# 697/697 [==============================] - 145s 208ms/step - loss: 0.2858 - accuracy: 0.8936 - precision: 0.7061 - recall: 0.1598 - f1_score: 0.2606 - val_loss: 0.2725 - val_accuracy: 0.9092 - val_precision: 0.2941 - val_recall: 0.0132 - val_f1_score: 0.0253
# Epoch 25/160
# 697/697 [==============================] - 143s 206ms/step - loss: 0.2835 - accuracy: 0.8941 - precision: 0.7058 - recall: 0.1678 - f1_score: 0.2712 - val_loss: 0.2723 - val_accuracy: 0.9071 - val_precision: 0.1667 - val_recall: 0.0106 - val_f1_score: 0.0199
# Epoch 26/160
# 697/697 [==============================] - 152s 219ms/step - loss: 0.2822 - accuracy: 0.8941 - precision: 0.7059 - recall: 0.1684 - f1_score: 0.2719 - val_loss: 0.2681 - val_accuracy: 0.9071 - val_precision: 0.2333 - val_recall: 0.0185 - val_f1_score: 0.0342
# Epoch 27/160
# 697/697 [==============================] - 155s 223ms/step - loss: 0.2810 - accuracy: 0.8945 - precision: 0.7015 - recall: 0.1756 - f1_score: 0.2810 - val_loss: 0.2788 - val_accuracy: 0.9071 - val_precision: 0.2647 - val_recall: 0.0237 - val_f1_score: 0.0436
# Epoch 28/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.2801 - accuracy: 0.8954 - precision: 0.7143 - recall: 0.1816 - f1_score: 0.2895 - val_loss: 0.2747 - val_accuracy: 0.9076 - val_precision: 0.3056 - val_recall: 0.0290 - val_f1_score: 0.0530
# Epoch 29/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.2779 - accuracy: 0.8967 - precision: 0.7242 - recall: 0.1942 - f1_score: 0.3063 - val_loss: 0.2718 - val_accuracy: 0.9085 - val_precision: 0.3529 - val_recall: 0.0317 - val_f1_score: 0.0581
# Epoch 30/160
# 697/697 [==============================] - 154s 222ms/step - loss: 0.2795 - accuracy: 0.8948 - precision: 0.7021 - recall: 0.1806 - f1_score: 0.2873 - val_loss: 0.2740 - val_accuracy: 0.9057 - val_precision: 0.1944 - val_recall: 0.0185 - val_f1_score: 0.0337
# Epoch 31/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.2759 - accuracy: 0.8975 - precision: 0.7283 - recall: 0.2018 - f1_score: 0.3161 - val_loss: 0.2811 - val_accuracy: 0.9047 - val_precision: 0.2500 - val_recall: 0.0343 - val_f1_score: 0.0603
# Epoch 32/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.2739 - accuracy: 0.8966 - precision: 0.7089 - recall: 0.2020 - f1_score: 0.3144 - val_loss: 0.2795 - val_accuracy: 0.9087 - val_precision: 0.3043 - val_recall: 0.0185 - val_f1_score: 0.0348
# Epoch 33/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.2735 - accuracy: 0.8967 - precision: 0.7061 - recall: 0.2053 - f1_score: 0.3181 - val_loss: 0.2798 - val_accuracy: 0.9061 - val_precision: 0.2368 - val_recall: 0.0237 - val_f1_score: 0.0432
# Epoch 34/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.2718 - accuracy: 0.8982 - precision: 0.7253 - recall: 0.2135 - f1_score: 0.3299 - val_loss: 0.2842 - val_accuracy: 0.9040 - val_precision: 0.2157 - val_recall: 0.0290 - val_f1_score: 0.0512
# Epoch 35/160
# 697/697 [==============================] - 149s 215ms/step - loss: 0.2710 - accuracy: 0.8980 - precision: 0.7160 - recall: 0.2173 - f1_score: 0.3334 - val_loss: 0.2794 - val_accuracy: 0.9061 - val_precision: 0.3148 - val_recall: 0.0449 - val_f1_score: 0.0785
# Epoch 36/160
# 697/697 [==============================] - 145s 208ms/step - loss: 0.2686 - accuracy: 0.8987 - precision: 0.7208 - recall: 0.2240 - f1_score: 0.3418 - val_loss: 0.2876 - val_accuracy: 0.9061 - val_precision: 0.2619 - val_recall: 0.0290 - val_f1_score: 0.0523
# Epoch 37/160
# 697/697 [==============================] - 139s 200ms/step - loss: 0.2676 - accuracy: 0.8986 - precision: 0.7188 - recall: 0.2242 - f1_score: 0.3418 - val_loss: 0.2806 - val_accuracy: 0.9054 - val_precision: 0.2745 - val_recall: 0.0369 - val_f1_score: 0.0651
# Epoch 38/160
# 697/697 [==============================] - 146s 209ms/step - loss: 0.2648 - accuracy: 0.8997 - precision: 0.7229 - recall: 0.2368 - f1_score: 0.3568 - val_loss: 0.2880 - val_accuracy: 0.9045 - val_precision: 0.2985 - val_recall: 0.0528 - val_f1_score: 0.0897
# Epoch 39/160
# 697/697 [==============================] - 148s 213ms/step - loss: 0.2649 - accuracy: 0.8993 - precision: 0.7125 - recall: 0.2387 - f1_score: 0.3576 - val_loss: 0.2882 - val_accuracy: 0.9040 - val_precision: 0.2542 - val_recall: 0.0396 - val_f1_score: 0.0685
# Epoch 40/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.2627 - accuracy: 0.9004 - precision: 0.7173 - recall: 0.2508 - f1_score: 0.3716 - val_loss: 0.2872 - val_accuracy: 0.9066 - val_precision: 0.3333 - val_recall: 0.0475 - val_f1_score: 0.0831
# Epoch 41/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.2613 - accuracy: 0.9012 - precision: 0.7191 - recall: 0.2603 - f1_score: 0.3823 - val_loss: 0.2784 - val_accuracy: 0.9083 - val_precision: 0.3962 - val_recall: 0.0554 - val_f1_score: 0.0972
# Epoch 42/160
# 697/697 [==============================] - 153s 219ms/step - loss: 0.2599 - accuracy: 0.9004 - precision: 0.7130 - recall: 0.2540 - f1_score: 0.3746 - val_loss: 0.2880 - val_accuracy: 0.9040 - val_precision: 0.2769 - val_recall: 0.0475 - val_f1_score: 0.0811
# Epoch 43/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.2603 - accuracy: 0.8997 - precision: 0.7051 - recall: 0.2504 - f1_score: 0.3695 - val_loss: 0.2803 - val_accuracy: 0.9052 - val_precision: 0.3378 - val_recall: 0.0660 - val_f1_score: 0.1104
# Epoch 44/160
# 697/697 [==============================] - 152s 217ms/step - loss: 0.2583 - accuracy: 0.9022 - precision: 0.7273 - recall: 0.2676 - f1_score: 0.3912 - val_loss: 0.2834 - val_accuracy: 0.9024 - val_precision: 0.2632 - val_recall: 0.0528 - val_f1_score: 0.0879
# Epoch 45/160
# 697/697 [==============================] - 141s 203ms/step - loss: 0.2569 - accuracy: 0.9013 - precision: 0.7144 - recall: 0.2659 - f1_score: 0.3875 - val_loss: 0.2804 - val_accuracy: 0.9019 - val_precision: 0.2841 - val_recall: 0.0660 - val_f1_score: 0.1071
# Epoch 46/160
# 697/697 [==============================] - 150s 216ms/step - loss: 0.2558 - accuracy: 0.9018 - precision: 0.7139 - recall: 0.2733 - f1_score: 0.3953 - val_loss: 0.2886 - val_accuracy: 0.9017 - val_precision: 0.2532 - val_recall: 0.0528 - val_f1_score: 0.0873
# Epoch 47/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.2535 - accuracy: 0.9030 - precision: 0.7221 - recall: 0.2821 - f1_score: 0.4057 - val_loss: 0.2905 - val_accuracy: 0.9003 - val_precision: 0.2078 - val_recall: 0.0422 - val_f1_score: 0.0702
# Epoch 48/160
# 697/697 [==============================] - 146s 209ms/step - loss: 0.2517 - accuracy: 0.9042 - precision: 0.7309 - recall: 0.2913 - f1_score: 0.4166 - val_loss: 0.2861 - val_accuracy: 0.9052 - val_precision: 0.3605 - val_recall: 0.0818 - val_f1_score: 0.1333
# Epoch 49/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.2497 - accuracy: 0.9048 - precision: 0.7315 - recall: 0.2984 - f1_score: 0.4238 - val_loss: 0.2995 - val_accuracy: 0.9024 - val_precision: 0.2692 - val_recall: 0.0554 - val_f1_score: 0.0919
# Epoch 50/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.2489 - accuracy: 0.9043 - precision: 0.7210 - recall: 0.3008 - f1_score: 0.4245 - val_loss: 0.3047 - val_accuracy: 0.9038 - val_precision: 0.3171 - val_recall: 0.0686 - val_f1_score: 0.1128
# Epoch 51/160
# 697/697 [==============================] - 140s 202ms/step - loss: 0.2498 - accuracy: 0.9046 - precision: 0.7227 - recall: 0.3039 - f1_score: 0.4279 - val_loss: 0.2882 - val_accuracy: 0.8981 - val_precision: 0.2128 - val_recall: 0.0528 - val_f1_score: 0.0846
# Epoch 52/160
# 697/697 [==============================] - 144s 206ms/step - loss: 0.2461 - accuracy: 0.9057 - precision: 0.7298 - recall: 0.3123 - f1_score: 0.4374 - val_loss: 0.2964 - val_accuracy: 0.9028 - val_precision: 0.2571 - val_recall: 0.0475 - val_f1_score: 0.0802
# Epoch 53/160
# 697/697 [==============================] - 147s 211ms/step - loss: 0.2463 - accuracy: 0.9053 - precision: 0.7256 - recall: 0.3114 - f1_score: 0.4357 - val_loss: 0.2909 - val_accuracy: 0.9033 - val_precision: 0.2647 - val_recall: 0.0475 - val_f1_score: 0.0805
# Epoch 54/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.2436 - accuracy: 0.9065 - precision: 0.7361 - recall: 0.3173 - f1_score: 0.4434 - val_loss: 0.3007 - val_accuracy: 0.9003 - val_precision: 0.2353 - val_recall: 0.0528 - val_f1_score: 0.0862
# Epoch 55/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.2412 - accuracy: 0.9055 - precision: 0.7193 - recall: 0.3194 - f1_score: 0.4424 - val_loss: 0.3049 - val_accuracy: 0.9043 - val_precision: 0.3205 - val_recall: 0.0660 - val_f1_score: 0.1094
# Epoch 56/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.2385 - accuracy: 0.9080 - precision: 0.7350 - recall: 0.3377 - f1_score: 0.4628 - val_loss: 0.3007 - val_accuracy: 0.8988 - val_precision: 0.2069 - val_recall: 0.0475 - val_f1_score: 0.0773
# Epoch 57/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.2393 - accuracy: 0.9075 - precision: 0.7301 - recall: 0.3360 - f1_score: 0.4602 - val_loss: 0.3012 - val_accuracy: 0.8986 - val_precision: 0.2797 - val_recall: 0.0871 - val_f1_score: 0.1328
# Epoch 58/160
# 697/697 [==============================] - 153s 219ms/step - loss: 0.2383 - accuracy: 0.9085 - precision: 0.7371 - recall: 0.3425 - f1_score: 0.4677 - val_loss: 0.3057 - val_accuracy: 0.9007 - val_precision: 0.2828 - val_recall: 0.0739 - val_f1_score: 0.1172
# Epoch 59/160
# 697/697 [==============================] - 148s 213ms/step - loss: 0.2373 - accuracy: 0.9079 - precision: 0.7310 - recall: 0.3412 - f1_score: 0.4652 - val_loss: 0.3028 - val_accuracy: 0.9043 - val_precision: 0.3000 - val_recall: 0.0554 - val_f1_score: 0.0935
# Epoch 60/160
# 697/697 [==============================] - 153s 220ms/step - loss: 0.2361 - accuracy: 0.9090 - precision: 0.7362 - recall: 0.3509 - f1_score: 0.4753 - val_loss: 0.3005 - val_accuracy: 0.8965 - val_precision: 0.2479 - val_recall: 0.0792 - val_f1_score: 0.1200
# Epoch 61/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.2336 - accuracy: 0.9089 - precision: 0.7314 - recall: 0.3540 - f1_score: 0.4771 - val_loss: 0.3091 - val_accuracy: 0.8991 - val_precision: 0.2685 - val_recall: 0.0765 - val_f1_score: 0.1191
# Epoch 62/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.2333 - accuracy: 0.9092 - precision: 0.7315 - recall: 0.3582 - f1_score: 0.4809 - val_loss: 0.3047 - val_accuracy: 0.8967 - val_precision: 0.2170 - val_recall: 0.0607 - val_f1_score: 0.0948
# Epoch 63/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.2315 - accuracy: 0.9108 - precision: 0.7435 - recall: 0.3668 - f1_score: 0.4912 - val_loss: 0.3127 - val_accuracy: 0.8963 - val_precision: 0.2615 - val_recall: 0.0897 - val_f1_score: 0.1336
# Epoch 64/160
# 697/697 [==============================] - 153s 220ms/step - loss: 0.2341 - accuracy: 0.9099 - precision: 0.7390 - recall: 0.3593 - f1_score: 0.4835 - val_loss: 0.3013 - val_accuracy: 0.8974 - val_precision: 0.2857 - val_recall: 0.1003 - val_f1_score: 0.1484
# Epoch 65/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.2279 - accuracy: 0.9114 - precision: 0.7425 - recall: 0.3760 - f1_score: 0.4992 - val_loss: 0.3124 - val_accuracy: 0.8956 - val_precision: 0.2269 - val_recall: 0.0712 - val_f1_score: 0.1084
# Epoch 66/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.2279 - accuracy: 0.9112 - precision: 0.7400 - recall: 0.3754 - f1_score: 0.4981 - val_loss: 0.3059 - val_accuracy: 0.8974 - val_precision: 0.2683 - val_recall: 0.0871 - val_f1_score: 0.1315
# Epoch 67/160
# 697/697 [==============================] - 140s 200ms/step - loss: 0.2257 - accuracy: 0.9127 - precision: 0.7527 - recall: 0.3817 - f1_score: 0.5065 - val_loss: 0.3049 - val_accuracy: 0.8977 - val_precision: 0.2544 - val_recall: 0.0765 - val_f1_score: 0.1176
# Epoch 68/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.2258 - accuracy: 0.9132 - precision: 0.7539 - recall: 0.3870 - f1_score: 0.5115 - val_loss: 0.3117 - val_accuracy: 0.9005 - val_precision: 0.2925 - val_recall: 0.0818 - val_f1_score: 0.1278
# Epoch 69/160
# 697/697 [==============================] - 140s 201ms/step - loss: 0.2249 - accuracy: 0.9120 - precision: 0.7417 - recall: 0.3836 - f1_score: 0.5057 - val_loss: 0.3163 - val_accuracy: 0.8996 - val_precision: 0.2500 - val_recall: 0.0633 - val_f1_score: 0.1011
# Epoch 70/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.2209 - accuracy: 0.9138 - precision: 0.7524 - recall: 0.3966 - f1_score: 0.5194 - val_loss: 0.3235 - val_accuracy: 0.8960 - val_precision: 0.2595 - val_recall: 0.0897 - val_f1_score: 0.1333
# Epoch 71/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.2204 - accuracy: 0.9141 - precision: 0.7480 - recall: 0.4050 - f1_score: 0.5255 - val_loss: 0.3225 - val_accuracy: 0.8960 - val_precision: 0.2397 - val_recall: 0.0765 - val_f1_score: 0.1160
# Epoch 72/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.2207 - accuracy: 0.9148 - precision: 0.7577 - recall: 0.4035 - f1_score: 0.5266 - val_loss: 0.3152 - val_accuracy: 0.8998 - val_precision: 0.3233 - val_recall: 0.1135 - val_f1_score: 0.1680
# Epoch 73/160
# 697/697 [==============================] - 141s 203ms/step - loss: 0.2194 - accuracy: 0.9148 - precision: 0.7541 - recall: 0.4073 - f1_score: 0.5289 - val_loss: 0.3147 - val_accuracy: 0.8958 - val_precision: 0.2681 - val_recall: 0.0976 - val_f1_score: 0.1431
# Epoch 74/160
# 697/697 [==============================] - 142s 203ms/step - loss: 0.2169 - accuracy: 0.9146 - precision: 0.7484 - recall: 0.4111 - f1_score: 0.5307 - val_loss: 0.3294 - val_accuracy: 0.9026 - val_precision: 0.3267 - val_recall: 0.0871 - val_f1_score: 0.1375
# Epoch 75/160
# 697/697 [==============================] - 142s 203ms/step - loss: 0.2161 - accuracy: 0.9169 - precision: 0.7638 - recall: 0.4234 - f1_score: 0.5448 - val_loss: 0.3193 - val_accuracy: 0.8946 - val_precision: 0.2653 - val_recall: 0.1029 - val_f1_score: 0.1483
# Epoch 76/160
# 697/697 [==============================] - 141s 203ms/step - loss: 0.2121 - accuracy: 0.9181 - precision: 0.7663 - recall: 0.4348 - f1_score: 0.5548 - val_loss: 0.3147 - val_accuracy: 0.8904 - val_precision: 0.2542 - val_recall: 0.1187 - val_f1_score: 0.1619
# Epoch 77/160
# 697/697 [==============================] - 142s 203ms/step - loss: 0.2115 - accuracy: 0.9179 - precision: 0.7653 - recall: 0.4337 - f1_score: 0.5536 - val_loss: 0.3321 - val_accuracy: 0.8937 - val_precision: 0.2483 - val_recall: 0.0950 - val_f1_score: 0.1374
# Epoch 78/160
# 697/697 [==============================] - 142s 204ms/step - loss: 0.2116 - accuracy: 0.9179 - precision: 0.7617 - recall: 0.4381 - f1_score: 0.5562 - val_loss: 0.3373 - val_accuracy: 0.8916 - val_precision: 0.2153 - val_recall: 0.0818 - val_f1_score: 0.1185
# Epoch 79/160
# 697/697 [==============================] - 142s 204ms/step - loss: 0.2110 - accuracy: 0.9190 - precision: 0.7737 - recall: 0.4379 - f1_score: 0.5593 - val_loss: 0.3298 - val_accuracy: 0.8960 - val_precision: 0.2520 - val_recall: 0.0844 - val_f1_score: 0.1265
# Epoch 80/160
# 697/697 [==============================] - 142s 204ms/step - loss: 0.2091 - accuracy: 0.9183 - precision: 0.7611 - recall: 0.4438 - f1_score: 0.5607 - val_loss: 0.3406 - val_accuracy: 0.8965 - val_precision: 0.2479 - val_recall: 0.0792 - val_f1_score: 0.1200
# Epoch 81/160
# 697/697 [==============================] - 145s 208ms/step - loss: 0.2111 - accuracy: 0.9180 - precision: 0.7577 - recall: 0.4434 - f1_score: 0.5594 - val_loss: 0.3337 - val_accuracy: 0.8948 - val_precision: 0.2639 - val_recall: 0.1003 - val_f1_score: 0.1453
# Epoch 82/160
# 697/697 [==============================] - 139s 199ms/step - loss: 0.2071 - accuracy: 0.9198 - precision: 0.7684 - recall: 0.4534 - f1_score: 0.5703 - val_loss: 0.3408 - val_accuracy: 0.8904 - val_precision: 0.2119 - val_recall: 0.0844 - val_f1_score: 0.1208
# Epoch 83/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.2059 - accuracy: 0.9197 - precision: 0.7658 - recall: 0.4557 - f1_score: 0.5714 - val_loss: 0.3464 - val_accuracy: 0.8951 - val_precision: 0.2443 - val_recall: 0.0844 - val_f1_score: 0.1255
# Epoch 84/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.2048 - accuracy: 0.9210 - precision: 0.7702 - recall: 0.4656 - f1_score: 0.5803 - val_loss: 0.3591 - val_accuracy: 0.8923 - val_precision: 0.2384 - val_recall: 0.0950 - val_f1_score: 0.1358
# Epoch 85/160
# 697/697 [==============================] - 138s 197ms/step - loss: 0.2047 - accuracy: 0.9205 - precision: 0.7687 - recall: 0.4618 - f1_score: 0.5770 - val_loss: 0.3383 - val_accuracy: 0.8944 - val_precision: 0.2667 - val_recall: 0.1055 - val_f1_score: 0.1512
# Epoch 86/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.2028 - accuracy: 0.9202 - precision: 0.7654 - recall: 0.4620 - f1_score: 0.5762 - val_loss: 0.3377 - val_accuracy: 0.8913 - val_precision: 0.2422 - val_recall: 0.1029 - val_f1_score: 0.1444
# Epoch 87/160
# 697/697 [==============================] - 137s 196ms/step - loss: 0.2024 - accuracy: 0.9215 - precision: 0.7734 - recall: 0.4690 - f1_score: 0.5839 - val_loss: 0.3308 - val_accuracy: 0.8911 - val_precision: 0.2692 - val_recall: 0.1293 - val_f1_score: 0.1747
# Epoch 88/160
# 697/697 [==============================] - 137s 196ms/step - loss: 0.1994 - accuracy: 0.9211 - precision: 0.7658 - recall: 0.4725 - f1_score: 0.5844 - val_loss: 0.3402 - val_accuracy: 0.8920 - val_precision: 0.2701 - val_recall: 0.1240 - val_f1_score: 0.1700
# Epoch 89/160
# 697/697 [==============================] - 137s 196ms/step - loss: 0.2021 - accuracy: 0.9210 - precision: 0.7670 - recall: 0.4700 - f1_score: 0.5828 - val_loss: 0.3423 - val_accuracy: 0.8953 - val_precision: 0.2676 - val_recall: 0.1003 - val_f1_score: 0.1459
# Epoch 90/160
# 697/697 [==============================] - 137s 196ms/step - loss: 0.1987 - accuracy: 0.9226 - precision: 0.7710 - recall: 0.4845 - f1_score: 0.5951 - val_loss: 0.3496 - val_accuracy: 0.8913 - val_precision: 0.2655 - val_recall: 0.1240 - val_f1_score: 0.1691
# Epoch 91/160
# 697/697 [==============================] - 137s 196ms/step - loss: 0.1986 - accuracy: 0.9220 - precision: 0.7687 - recall: 0.4801 - f1_score: 0.5911 - val_loss: 0.3678 - val_accuracy: 0.8866 - val_precision: 0.2304 - val_recall: 0.1161 - val_f1_score: 0.1544
# Epoch 92/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1984 - accuracy: 0.9227 - precision: 0.7762 - recall: 0.4799 - f1_score: 0.5931 - val_loss: 0.3563 - val_accuracy: 0.8974 - val_precision: 0.2720 - val_recall: 0.0897 - val_f1_score: 0.1349
# Epoch 93/160
# 697/697 [==============================] - 154s 220ms/step - loss: 0.1972 - accuracy: 0.9225 - precision: 0.7705 - recall: 0.4838 - f1_score: 0.5943 - val_loss: 0.3500 - val_accuracy: 0.8939 - val_precision: 0.2600 - val_recall: 0.1029 - val_f1_score: 0.1474
# Epoch 94/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.1967 - accuracy: 0.9225 - precision: 0.7657 - recall: 0.4897 - f1_score: 0.5973 - val_loss: 0.3394 - val_accuracy: 0.8920 - val_precision: 0.2727 - val_recall: 0.1266 - val_f1_score: 0.1730
# Epoch 95/160
# 697/697 [==============================] - 150s 216ms/step - loss: 0.1942 - accuracy: 0.9236 - precision: 0.7740 - recall: 0.4935 - f1_score: 0.6027 - val_loss: 0.3434 - val_accuracy: 0.8854 - val_precision: 0.2477 - val_recall: 0.1398 - val_f1_score: 0.1788
# Epoch 96/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.1912 - accuracy: 0.9245 - precision: 0.7747 - recall: 0.5034 - f1_score: 0.6103 - val_loss: 0.3435 - val_accuracy: 0.8953 - val_precision: 0.3125 - val_recall: 0.1451 - val_f1_score: 0.1982
# Epoch 97/160
# 697/697 [==============================] - 151s 216ms/step - loss: 0.1961 - accuracy: 0.9224 - precision: 0.7635 - recall: 0.4906 - f1_score: 0.5974 - val_loss: 0.3470 - val_accuracy: 0.8925 - val_precision: 0.2706 - val_recall: 0.1214 - val_f1_score: 0.1676
# Epoch 98/160
# 697/697 [==============================] - 152s 219ms/step - loss: 0.1913 - accuracy: 0.9238 - precision: 0.7713 - recall: 0.4990 - f1_score: 0.6060 - val_loss: 0.3427 - val_accuracy: 0.8932 - val_precision: 0.3037 - val_recall: 0.1530 - val_f1_score: 0.2035
# Epoch 99/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1904 - accuracy: 0.9252 - precision: 0.7815 - recall: 0.5038 - f1_score: 0.6127 - val_loss: 0.3367 - val_accuracy: 0.8937 - val_precision: 0.2761 - val_recall: 0.1187 - val_f1_score: 0.1661
# Epoch 100/160
# 697/697 [==============================] - 147s 211ms/step - loss: 0.1884 - accuracy: 0.9246 - precision: 0.7680 - recall: 0.5124 - f1_score: 0.6147 - val_loss: 0.3566 - val_accuracy: 0.8908 - val_precision: 0.2485 - val_recall: 0.1108 - val_f1_score: 0.1533
# Epoch 101/160
# 697/697 [==============================] - 119s 171ms/step - loss: 0.1906 - accuracy: 0.9254 - precision: 0.7759 - recall: 0.5128 - f1_score: 0.6175 - val_loss: 0.3658 - val_accuracy: 0.8906 - val_precision: 0.2278 - val_recall: 0.0950 - val_f1_score: 0.1341
# Epoch 102/160
# 697/697 [==============================] - 115s 165ms/step - loss: 0.1915 - accuracy: 0.9238 - precision: 0.7694 - recall: 0.5013 - f1_score: 0.6071 - val_loss: 0.3665 - val_accuracy: 0.8894 - val_precision: 0.2429 - val_recall: 0.1135 - val_f1_score: 0.1547
# Epoch 103/160
# 697/697 [==============================] - 116s 167ms/step - loss: 0.1871 - accuracy: 0.9259 - precision: 0.7783 - recall: 0.5161 - f1_score: 0.6206 - val_loss: 0.3843 - val_accuracy: 0.8948 - val_precision: 0.2639 - val_recall: 0.1003 - val_f1_score: 0.1453
# Epoch 104/160
# 697/697 [==============================] - 134s 193ms/step - loss: 0.1894 - accuracy: 0.9250 - precision: 0.7777 - recall: 0.5055 - f1_score: 0.6128 - val_loss: 0.3796 - val_accuracy: 0.8876 - val_precision: 0.2295 - val_recall: 0.1108 - val_f1_score: 0.1495
# Epoch 105/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.1845 - accuracy: 0.9277 - precision: 0.7850 - recall: 0.5291 - f1_score: 0.6321 - val_loss: 0.3650 - val_accuracy: 0.8941 - val_precision: 0.2446 - val_recall: 0.0897 - val_f1_score: 0.1313
# Epoch 106/160
# 697/697 [==============================] - 156s 224ms/step - loss: 0.1845 - accuracy: 0.9286 - precision: 0.7911 - recall: 0.5329 - f1_score: 0.6368 - val_loss: 0.3739 - val_accuracy: 0.8880 - val_precision: 0.2563 - val_recall: 0.1346 - val_f1_score: 0.1765
# Epoch 107/160
# 697/697 [==============================] - 150s 216ms/step - loss: 0.1849 - accuracy: 0.9275 - precision: 0.7806 - recall: 0.5319 - f1_score: 0.6327 - val_loss: 0.3696 - val_accuracy: 0.8880 - val_precision: 0.2657 - val_recall: 0.1451 - val_f1_score: 0.1877
# Epoch 108/160
# 697/697 [==============================] - 140s 201ms/step - loss: 0.1855 - accuracy: 0.9271 - precision: 0.7796 - recall: 0.5279 - f1_score: 0.6295 - val_loss: 0.3511 - val_accuracy: 0.8948 - val_precision: 0.2213 - val_recall: 0.0712 - val_f1_score: 0.1078
# Epoch 109/160
# 697/697 [==============================] - 142s 203ms/step - loss: 0.1844 - accuracy: 0.9266 - precision: 0.7809 - recall: 0.5205 - f1_score: 0.6246 - val_loss: 0.3786 - val_accuracy: 0.8850 - val_precision: 0.2430 - val_recall: 0.1372 - val_f1_score: 0.1754
# Epoch 110/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1814 - accuracy: 0.9281 - precision: 0.7814 - recall: 0.5384 - f1_score: 0.6375 - val_loss: 0.3585 - val_accuracy: 0.8974 - val_precision: 0.3185 - val_recall: 0.1319 - val_f1_score: 0.1866
# Epoch 111/160
# 697/697 [==============================] - 140s 201ms/step - loss: 0.1794 - accuracy: 0.9299 - precision: 0.7891 - recall: 0.5501 - f1_score: 0.6483 - val_loss: 0.3748 - val_accuracy: 0.8887 - val_precision: 0.2626 - val_recall: 0.1372 - val_f1_score: 0.1802
# Epoch 112/160
# 697/697 [==============================] - 140s 202ms/step - loss: 0.1812 - accuracy: 0.9292 - precision: 0.7897 - recall: 0.5413 - f1_score: 0.6423 - val_loss: 0.3674 - val_accuracy: 0.8892 - val_precision: 0.2629 - val_recall: 0.1346 - val_f1_score: 0.1780
# Epoch 113/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1789 - accuracy: 0.9306 - precision: 0.7931 - recall: 0.5526 - f1_score: 0.6513 - val_loss: 0.3715 - val_accuracy: 0.8873 - val_precision: 0.2525 - val_recall: 0.1346 - val_f1_score: 0.1756
# Epoch 114/160
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1807 - accuracy: 0.9296 - precision: 0.7905 - recall: 0.5445 - f1_score: 0.6449 - val_loss: 0.3754 - val_accuracy: 0.8930 - val_precision: 0.2564 - val_recall: 0.1055 - val_f1_score: 0.1495
# Epoch 115/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1763 - accuracy: 0.9314 - precision: 0.7914 - recall: 0.5642 - f1_score: 0.6588 - val_loss: 0.3765 - val_accuracy: 0.8930 - val_precision: 0.2532 - val_recall: 0.1029 - val_f1_score: 0.1463
# Epoch 116/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.1758 - accuracy: 0.9304 - precision: 0.7877 - recall: 0.5568 - f1_score: 0.6524 - val_loss: 0.3843 - val_accuracy: 0.8892 - val_precision: 0.2356 - val_recall: 0.1082 - val_f1_score: 0.1483
# Epoch 117/160
# 697/697 [==============================] - 144s 207ms/step - loss: 0.1789 - accuracy: 0.9292 - precision: 0.7830 - recall: 0.5495 - f1_score: 0.6458 - val_loss: 0.3872 - val_accuracy: 0.8854 - val_precision: 0.2158 - val_recall: 0.1082 - val_f1_score: 0.1441
# Epoch 118/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1741 - accuracy: 0.9314 - precision: 0.7910 - recall: 0.5650 - f1_score: 0.6592 - val_loss: 0.3766 - val_accuracy: 0.8916 - val_precision: 0.2560 - val_recall: 0.1135 - val_f1_score: 0.1572
# Epoch 119/160
# 697/697 [==============================] - 151s 216ms/step - loss: 0.1737 - accuracy: 0.9307 - precision: 0.7879 - recall: 0.5608 - f1_score: 0.6552 - val_loss: 0.3958 - val_accuracy: 0.8941 - val_precision: 0.2649 - val_recall: 0.1055 - val_f1_score: 0.1509
# Epoch 120/160
# 697/697 [==============================] - 148s 213ms/step - loss: 0.1730 - accuracy: 0.9316 - precision: 0.7923 - recall: 0.5659 - f1_score: 0.6603 - val_loss: 0.3984 - val_accuracy: 0.8883 - val_precision: 0.2143 - val_recall: 0.0950 - val_f1_score: 0.1316
# Epoch 121/160
# 697/697 [==============================] - 153s 219ms/step - loss: 0.1737 - accuracy: 0.9311 - precision: 0.7892 - recall: 0.5640 - f1_score: 0.6579 - val_loss: 0.3780 - val_accuracy: 0.8908 - val_precision: 0.2626 - val_recall: 0.1240 - val_f1_score: 0.1685
# Epoch 122/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1725 - accuracy: 0.9317 - precision: 0.7902 - recall: 0.5694 - f1_score: 0.6619 - val_loss: 0.3919 - val_accuracy: 0.8838 - val_precision: 0.2167 - val_recall: 0.1161 - val_f1_score: 0.1512
# Epoch 123/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1705 - accuracy: 0.9331 - precision: 0.7986 - recall: 0.5753 - f1_score: 0.6688 - val_loss: 0.3955 - val_accuracy: 0.8784 - val_precision: 0.2149 - val_recall: 0.1372 - val_f1_score: 0.1675
# Epoch 124/160
# 697/697 [==============================] - 155s 223ms/step - loss: 0.1721 - accuracy: 0.9317 - precision: 0.7907 - recall: 0.5684 - f1_score: 0.6614 - val_loss: 0.4134 - val_accuracy: 0.8840 - val_precision: 0.2311 - val_recall: 0.1293 - val_f1_score: 0.1658
# Epoch 125/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.1706 - accuracy: 0.9330 - precision: 0.7946 - recall: 0.5789 - f1_score: 0.6698 - val_loss: 0.3979 - val_accuracy: 0.8861 - val_precision: 0.2308 - val_recall: 0.1187 - val_f1_score: 0.1568
# Epoch 126/160
# 697/697 [==============================] - 146s 210ms/step - loss: 0.1699 - accuracy: 0.9337 - precision: 0.8002 - recall: 0.5801 - f1_score: 0.6726 - val_loss: 0.4043 - val_accuracy: 0.8791 - val_precision: 0.2078 - val_recall: 0.1266 - val_f1_score: 0.1574
# Epoch 127/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.1666 - accuracy: 0.9345 - precision: 0.8049 - recall: 0.5835 - f1_score: 0.6766 - val_loss: 0.4130 - val_accuracy: 0.8852 - val_precision: 0.2534 - val_recall: 0.1478 - val_f1_score: 0.1867
# Epoch 128/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.1681 - accuracy: 0.9339 - precision: 0.7985 - recall: 0.5849 - f1_score: 0.6752 - val_loss: 0.4117 - val_accuracy: 0.8833 - val_precision: 0.1937 - val_recall: 0.0976 - val_f1_score: 0.1298
# Epoch 129/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.1667 - accuracy: 0.9346 - precision: 0.8031 - recall: 0.5864 - f1_score: 0.6779 - val_loss: 0.4040 - val_accuracy: 0.8878 - val_precision: 0.2337 - val_recall: 0.1135 - val_f1_score: 0.1528
# Epoch 130/160
# 697/697 [==============================] - 138s 198ms/step - loss: 0.1681 - accuracy: 0.9331 - precision: 0.7925 - recall: 0.5826 - f1_score: 0.6715 - val_loss: 0.4146 - val_accuracy: 0.8833 - val_precision: 0.2227 - val_recall: 0.1240 - val_f1_score: 0.1593
# Epoch 131/160
# 697/697 [==============================] - 139s 199ms/step - loss: 0.1660 - accuracy: 0.9341 - precision: 0.7998 - recall: 0.5856 - f1_score: 0.6762 - val_loss: 0.4133 - val_accuracy: 0.8843 - val_precision: 0.1979 - val_recall: 0.0976 - val_f1_score: 0.1307
# Epoch 132/160
# 697/697 [==============================] - 137s 197ms/step - loss: 0.1671 - accuracy: 0.9331 - precision: 0.7938 - recall: 0.5807 - f1_score: 0.6707 - val_loss: 0.4177 - val_accuracy: 0.8885 - val_precision: 0.2460 - val_recall: 0.1214 - val_f1_score: 0.1625
# Epoch 133/160
# 697/697 [==============================] - 139s 199ms/step - loss: 0.1644 - accuracy: 0.9347 - precision: 0.8002 - recall: 0.5916 - f1_score: 0.6802 - val_loss: 0.4016 - val_accuracy: 0.8819 - val_precision: 0.2361 - val_recall: 0.1451 - val_f1_score: 0.1797
# Epoch 134/160
# 697/697 [==============================] - 137s 197ms/step - loss: 0.1642 - accuracy: 0.9342 - precision: 0.7960 - recall: 0.5914 - f1_score: 0.6786 - val_loss: 0.3941 - val_accuracy: 0.8878 - val_precision: 0.2550 - val_recall: 0.1346 - val_f1_score: 0.1762
# Epoch 135/160
# 697/697 [==============================] - 139s 199ms/step - loss: 0.1654 - accuracy: 0.9336 - precision: 0.7927 - recall: 0.5885 - f1_score: 0.6755 - val_loss: 0.4007 - val_accuracy: 0.8805 - val_precision: 0.2000 - val_recall: 0.1135 - val_f1_score: 0.1448
# Epoch 136/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.1601 - accuracy: 0.9368 - precision: 0.8037 - recall: 0.6105 - f1_score: 0.6939 - val_loss: 0.4119 - val_accuracy: 0.8857 - val_precision: 0.2256 - val_recall: 0.1161 - val_f1_score: 0.1533
# Epoch 137/160
# 697/697 [==============================] - 144s 207ms/step - loss: 0.1600 - accuracy: 0.9360 - precision: 0.8003 - recall: 0.6057 - f1_score: 0.6895 - val_loss: 0.4178 - val_accuracy: 0.8779 - val_precision: 0.2131 - val_recall: 0.1372 - val_f1_score: 0.1669
# Epoch 138/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1642 - accuracy: 0.9353 - precision: 0.7976 - recall: 0.6017 - f1_score: 0.6859 - val_loss: 0.3978 - val_accuracy: 0.8829 - val_precision: 0.2207 - val_recall: 0.1240 - val_f1_score: 0.1588
# Epoch 139/160
# 697/697 [==============================] - 154s 220ms/step - loss: 0.1614 - accuracy: 0.9373 - precision: 0.8101 - recall: 0.6084 - f1_score: 0.6949 - val_loss: 0.4001 - val_accuracy: 0.8781 - val_precision: 0.2275 - val_recall: 0.1530 - val_f1_score: 0.1830
# Epoch 140/160
# 697/697 [==============================] - 166s 239ms/step - loss: 0.1619 - accuracy: 0.9350 - precision: 0.7950 - recall: 0.6019 - f1_score: 0.6851 - val_loss: 0.4178 - val_accuracy: 0.8838 - val_precision: 0.2195 - val_recall: 0.1187 - val_f1_score: 0.1541
# Epoch 141/160
# 697/697 [==============================] - 154s 221ms/step - loss: 0.1567 - accuracy: 0.9386 - precision: 0.8128 - recall: 0.6200 - f1_score: 0.7035 - val_loss: 0.4261 - val_accuracy: 0.8859 - val_precision: 0.2088 - val_recall: 0.1003 - val_f1_score: 0.1355
# Epoch 142/160
# 697/697 [==============================] - 147s 211ms/step - loss: 0.1588 - accuracy: 0.9385 - precision: 0.8130 - recall: 0.6183 - f1_score: 0.7024 - val_loss: 0.4068 - val_accuracy: 0.8927 - val_precision: 0.2609 - val_recall: 0.1108 - val_f1_score: 0.1556
# Epoch 143/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1591 - accuracy: 0.9372 - precision: 0.8059 - recall: 0.6126 - f1_score: 0.6961 - val_loss: 0.3986 - val_accuracy: 0.8803 - val_precision: 0.2400 - val_recall: 0.1583 - val_f1_score: 0.1908
# Epoch 144/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.1576 - accuracy: 0.9367 - precision: 0.8042 - recall: 0.6093 - f1_score: 0.6933 - val_loss: 0.4038 - val_accuracy: 0.8843 - val_precision: 0.2396 - val_recall: 0.1372 - val_f1_score: 0.1745
# Epoch 145/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1552 - accuracy: 0.9382 - precision: 0.8066 - recall: 0.6225 - f1_score: 0.7027 - val_loss: 0.4051 - val_accuracy: 0.8810 - val_precision: 0.2298 - val_recall: 0.1425 - val_f1_score: 0.1759
# Epoch 146/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.1549 - accuracy: 0.9380 - precision: 0.8076 - recall: 0.6200 - f1_score: 0.7015 - val_loss: 0.4329 - val_accuracy: 0.8833 - val_precision: 0.2090 - val_recall: 0.1108 - val_f1_score: 0.1448
# Epoch 147/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1538 - accuracy: 0.9390 - precision: 0.8113 - recall: 0.6263 - f1_score: 0.7069 - val_loss: 0.4226 - val_accuracy: 0.8878 - val_precision: 0.2308 - val_recall: 0.1108 - val_f1_score: 0.1497
# Epoch 148/160
# 697/697 [==============================] - 144s 207ms/step - loss: 0.1558 - accuracy: 0.9371 - precision: 0.7988 - recall: 0.6208 - f1_score: 0.6986 - val_loss: 0.4290 - val_accuracy: 0.8814 - val_precision: 0.2197 - val_recall: 0.1293 - val_f1_score: 0.1628
# Epoch 149/160
# 697/697 [==============================] - 151s 217ms/step - loss: 0.1546 - accuracy: 0.9392 - precision: 0.8099 - recall: 0.6296 - f1_score: 0.7085 - val_loss: 0.4337 - val_accuracy: 0.8831 - val_precision: 0.2342 - val_recall: 0.1372 - val_f1_score: 0.1730
# Epoch 150/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1517 - accuracy: 0.9397 - precision: 0.8137 - recall: 0.6309 - f1_score: 0.7107 - val_loss: 0.4267 - val_accuracy: 0.8885 - val_precision: 0.2404 - val_recall: 0.1161 - val_f1_score: 0.1566
# Epoch 151/160
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1538 - accuracy: 0.9387 - precision: 0.8048 - recall: 0.6305 - f1_score: 0.7071 - val_loss: 0.4412 - val_accuracy: 0.8876 - val_precision: 0.2408 - val_recall: 0.1214 - val_f1_score: 0.1614
# Epoch 152/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1519 - accuracy: 0.9399 - precision: 0.8138 - recall: 0.6332 - f1_score: 0.7122 - val_loss: 0.4363 - val_accuracy: 0.8817 - val_precision: 0.1931 - val_recall: 0.1029 - val_f1_score: 0.1343
# Epoch 153/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.1542 - accuracy: 0.9388 - precision: 0.8088 - recall: 0.6273 - f1_score: 0.7066 - val_loss: 0.4350 - val_accuracy: 0.8833 - val_precision: 0.2227 - val_recall: 0.1240 - val_f1_score: 0.1593
# Epoch 154/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.1514 - accuracy: 0.9396 - precision: 0.8137 - recall: 0.6296 - f1_score: 0.7099 - val_loss: 0.4267 - val_accuracy: 0.8871 - val_precision: 0.2328 - val_recall: 0.1161 - val_f1_score: 0.1549
# Epoch 155/160
# 697/697 [==============================] - 155s 222ms/step - loss: 0.1525 - accuracy: 0.9399 - precision: 0.8131 - recall: 0.6336 - f1_score: 0.7122 - val_loss: 0.4079 - val_accuracy: 0.8864 - val_precision: 0.2636 - val_recall: 0.1530 - val_f1_score: 0.1937
# Epoch 156/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.1534 - accuracy: 0.9395 - precision: 0.8105 - recall: 0.6326 - f1_score: 0.7106 - val_loss: 0.4238 - val_accuracy: 0.8803 - val_precision: 0.2379 - val_recall: 0.1557 - val_f1_score: 0.1882
# Epoch 157/160
# 697/697 [==============================] - 152s 218ms/step - loss: 0.1500 - accuracy: 0.9400 - precision: 0.8114 - recall: 0.6374 - f1_score: 0.7140 - val_loss: 0.4365 - val_accuracy: 0.8845 - val_precision: 0.2358 - val_recall: 0.1319 - val_f1_score: 0.1692
# Epoch 158/160
# 697/697 [==============================] - 148s 213ms/step - loss: 0.1510 - accuracy: 0.9394 - precision: 0.8086 - recall: 0.6340 - f1_score: 0.7107 - val_loss: 0.4333 - val_accuracy: 0.8803 - val_precision: 0.2379 - val_recall: 0.1557 - val_f1_score: 0.1882
# Epoch 159/160
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1490 - accuracy: 0.9406 - precision: 0.8131 - recall: 0.6412 - f1_score: 0.7170 - val_loss: 0.4438 - val_accuracy: 0.8831 - val_precision: 0.2108 - val_recall: 0.1135 - val_f1_score: 0.1475
# Epoch 160/160
# 697/697 [==============================] - 148s 212ms/step - loss: 0.1476 - accuracy: 0.9415 - precision: 0.8170 - recall: 0.6460 - f1_score: 0.7215 - val_loss: 0.4446 - val_accuracy: 0.8824 - val_precision: 0.2186 - val_recall: 0.1240 - val_f1_score: 0.1582

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")
plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['f1_score'], label="F1-score")
plt.plot(range(1, epochs + 1), history.history['val_f1_score'], label="val F1-score")
plt.xlabel("epochs")
plt.title("total F1-score")

plt.legend()
plt.show()

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 160 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 5s 70ms/step
# 697/697 [==============================] - 49s 70ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8209832980475182
# Train accuracy: 0.9438386286124574

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8543872030110562
# Train accuracy: 0.9599712798420391

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8670900964478946
# Train accuracy: 0.9649075569915635

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8823806163255704
# Train accuracy: 0.9636286124573685

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights("./fine_models/model_ri_best_f1.h5")

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 6s 69ms/step
# 697/697 [==============================] - 48s 69ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8153375676311456
# Train accuracy: 0.9087013103572069

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8534462479416608
# Train accuracy: 0.9333602584814217

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.874852975770407
# Train accuracy: 0.9413704900376952

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.893201599623618
# Train accuracy: 0.9404505474780112
