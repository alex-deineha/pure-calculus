# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *
# Out:
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 30

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_test = all_data["LO_steps_num"].tolist()
y_lo_test = all_data["RI_steps_num"].tolist()

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# number samples: 4251
# number samples only reducable: 4220
#
# max RI steps count: 386
# max LO steps count: 219
# Count TESTING samples: 4220

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_train = all_data["LO_steps_num"].tolist()
y_lo_train = all_data["RI_steps_num"].tolist()

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# number samples: 44568
# number samples only reducable: 42469
#
# max RI steps count: 400
# max LO steps count: 308
# Count TRAINING samples: 42469

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_sample_weight(ri_steps, lo_steps):
    if ri_steps > lo_steps:
        return (abs(ri_steps - lo_steps) / (max(ri_steps, lo_steps))) + 0.5
    else:
        return 0.001


x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({
    "term_str": x_train, "is_ri_best": y_train,
    "lo_steps": y_lo_train, "ri_steps": y_ri_train,
    "sample_weights": [get_sample_weight(ri_, lo_) for ri_, lo_ in zip(y_ri_train, y_lo_train)],
})
test_df = pd.DataFrame({
    "term_str": x_test, "is_ri_best": y_test,
    "lo_steps": y_lo_test, "ri_steps": y_ri_test,
    "sample_weights": [get_sample_weight(ri_, lo_)  for ri_, lo_ in zip(y_ri_test, y_lo_test)],
})

# %%
train_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y((x(y((x(y((x((x((xx)(y(((xx)(((yx)(x((yx)...           0         3
# 1  ((((((((y(y(yx)))(y(yx)))(((yx)(y(y((x(y(y(y(y...           0       187
# 2  (y(y(x(((((y(yx))(yx))((y(y(yx)))(y(y(xx)))))(...           0         8
# 3  (y(((x((xx)(x(x(xx)))))((x((x(yx))(xx)))((y(x(...           1         4
# 4  (y((x(y((((x(x(y(y(x((xx)x))))))(x(((y(x((x((y...           0         2
# 5  (y(y(((((((x(x(y(yx))))(x(x(y(x(x(y(yx))))))))...           0        78
# 6  ((y(y(y((y(y((yx)x)))(x(((yx)(yx))((((y(yx))(y...           0         8
# 7  ((y((((y(xx))(y((yx)(y(x(y(yx)))))))(y((y(x((y...           0        31
# 8  (y(((y(yx))(y(y(x((y(x((y(yx))(y(y(y(xx)))))))...           0        16
# 9                 (y(y(y(((y((yx)x))(yx))(y(yx))))))           0         3
#
#    ri_steps  sample_weights
# 0         3        0.001000
# 1        60        0.001000
# 2         5        0.001000
# 3         7        0.928571
# 4         2        0.001000
# 5        20        0.001000
# 6         3        0.001000
# 7        11        0.001000
# 8        10        0.001000
# 9         3        0.001000

# %%
test_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y(x(y((x(x(((x(y((xx)(x(y(yx))))))x)(y(y(xx...           0         0
# 1  (((((((y(y(yx)))(y(y(xx))))((y(((y(y(yx)))(y(y...           0        47
# 2  (y(y(y(((x(yx))(yx))((x(y((yx)(y(x((((yx)(((xx...           0         2
# 3  (y((((((((y(y(x(xx))))(y(y(y(y(xx))))))(((y(y(...           0        75
# 4  (y(y(((xx)(y(y(y((x((((yx)(yx))(((yx)(yx))(((y...           0         8
# 5  ((((yx)(y((y(y((xx)(y((yx)x)))))((yx)(y((yx)(x...           0        23
# 6  (y(x(y(y(y(y(x((y(y((yx)(y(y(xx))))))(y(y(((y(...           0         5
# 7  (((((((((yx)(y(xx)))(yx))(((yx)(y(xx)))(yx)))(...           0        91
# 8  (y(((x(yx))(y((xx)((x((((x(xx))(xx))x)(y(y((xx...           0         1
# 9                 (y(y(y(y(y(x(y((y(y(xx)))x))))))))           0         1
#
#    ri_steps  sample_weights
# 0         0           0.001
# 1        28           0.001
# 2         1           0.001
# 3        58           0.001
# 4         8           0.001
# 5        10           0.001
# 6         4           0.001
# 7        84           0.001
# 8         1           0.001
# 9         1           0.001

# %%
def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    sample_weights = tf.convert_to_tensor(example["sample_weights"])
    return tokenized_texts, labels, sample_weights


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1], tokenized_train_data[2])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define & Train the Model

# %%
# Define the model
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model_structure = model.to_json()
# with open("./fine_models/model_ri.json", 'w') as json_file:
#     json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_ri_best_f1_red_weighted_v2.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_ri_red_weighted_v2.h5', save_weights_only=True, save_freq=1)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="ri_best_logs/id_2", histogram_freq=1)

# %%
def draw_training_statistic(history_):
    plt.plot(range(1, epochs + 1), history_.history['loss'], label="loss")
    plt.plot(range(1, epochs + 1), history_.history['val_loss'], label="val_loss")
    plt.xlabel("epochs")
    plt.title("total loss")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['accuracy'], label="accuracy")
    plt.plot(range(1, epochs + 1), history_.history['val_accuracy'], label="val_accuracy")
    plt.xlabel("epochs")
    plt.title("total accuracy")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['precision'], label="precision")
    plt.plot(range(1, epochs + 1), history_.history['val_precision'], label="val_precision")
    plt.xlabel("epochs")
    plt.title("total precision")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['recall'], label="recall")
    plt.plot(range(1, epochs + 1), history_.history['val_recall'], label="val_recall")
    plt.xlabel("epochs")
    plt.title("total recall")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['f1_score'], label="F1-score")
    plt.plot(range(1, epochs + 1), history_.history['val_f1_score'], label="val F1-score")
    plt.xlabel("epochs")
    plt.title("total F1-score")
    plt.legend()
    plt.show()

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 664/664 [==============================] - 158s 231ms/step - loss: 0.0051 - accuracy: 0.1231 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2190 - val_loss: 4.4378 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 2/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0048 - accuracy: 0.1229 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 4.0838 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 3/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0047 - accuracy: 0.1229 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 4.0684 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 4/30
# 664/664 [==============================] - 157s 236ms/step - loss: 0.0047 - accuracy: 0.1229 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 4.0043 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 5/30
# 664/664 [==============================] - 154s 231ms/step - loss: 0.0046 - accuracy: 0.1229 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 3.9748 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 6/30
# 664/664 [==============================] - 152s 228ms/step - loss: 0.0046 - accuracy: 0.1229 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 4.0825 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 7/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0046 - accuracy: 0.1230 - precision: 0.1229 - recall: 1.0000 - f1_score: 0.2189 - val_loss: 3.9795 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 8/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0046 - accuracy: 0.1238 - precision: 0.1230 - recall: 1.0000 - f1_score: 0.2191 - val_loss: 4.0388 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 9/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0046 - accuracy: 0.1233 - precision: 0.1230 - recall: 1.0000 - f1_score: 0.2190 - val_loss: 3.8702 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 10/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0045 - accuracy: 0.1255 - precision: 0.1232 - recall: 1.0000 - f1_score: 0.2194 - val_loss: 3.8723 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 11/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0045 - accuracy: 0.1252 - precision: 0.1232 - recall: 1.0000 - f1_score: 0.2194 - val_loss: 3.9075 - val_accuracy: 0.0900 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1649
# Epoch 12/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0045 - accuracy: 0.1270 - precision: 0.1234 - recall: 1.0000 - f1_score: 0.2197 - val_loss: 3.9291 - val_accuracy: 0.0898 - val_precision: 0.0898 - val_recall: 1.0000 - val_f1_score: 0.1648
# Epoch 13/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0045 - accuracy: 0.1292 - precision: 0.1237 - recall: 1.0000 - f1_score: 0.2202 - val_loss: 3.6894 - val_accuracy: 0.1009 - val_precision: 0.0908 - val_recall: 1.0000 - val_f1_score: 0.1665
# Epoch 14/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0045 - accuracy: 0.1322 - precision: 0.1241 - recall: 1.0000 - f1_score: 0.2207 - val_loss: 3.7327 - val_accuracy: 0.0929 - val_precision: 0.0901 - val_recall: 1.0000 - val_f1_score: 0.1653
# Epoch 15/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0044 - accuracy: 0.1293 - precision: 0.1237 - recall: 0.9998 - f1_score: 0.2201 - val_loss: 3.7574 - val_accuracy: 0.1024 - val_precision: 0.0910 - val_recall: 1.0000 - val_f1_score: 0.1667
# Epoch 16/30
# 664/664 [==============================] - 151s 228ms/step - loss: 0.0044 - accuracy: 0.1308 - precision: 0.1239 - recall: 1.0000 - f1_score: 0.2205 - val_loss: 3.6893 - val_accuracy: 0.1014 - val_precision: 0.0909 - val_recall: 1.0000 - val_f1_score: 0.1666
# Epoch 17/30
# 664/664 [==============================] - 152s 228ms/step - loss: 0.0044 - accuracy: 0.1327 - precision: 0.1241 - recall: 1.0000 - f1_score: 0.2208 - val_loss: 3.7612 - val_accuracy: 0.0995 - val_precision: 0.0907 - val_recall: 1.0000 - val_f1_score: 0.1663
# Epoch 18/30
# 664/664 [==============================] - 152s 228ms/step - loss: 0.0044 - accuracy: 0.1410 - precision: 0.1252 - recall: 1.0000 - f1_score: 0.2225 - val_loss: 3.6052 - val_accuracy: 0.1227 - val_precision: 0.0929 - val_recall: 1.0000 - val_f1_score: 0.1700
# Epoch 19/30
# 664/664 [==============================] - 151s 228ms/step - loss: 0.0044 - accuracy: 0.1363 - precision: 0.1246 - recall: 1.0000 - f1_score: 0.2216 - val_loss: 3.6190 - val_accuracy: 0.1341 - val_precision: 0.0940 - val_recall: 1.0000 - val_f1_score: 0.1718
# Epoch 20/30
# 664/664 [==============================] - 151s 228ms/step - loss: 0.0044 - accuracy: 0.1406 - precision: 0.1251 - recall: 1.0000 - f1_score: 0.2224 - val_loss: 3.8041 - val_accuracy: 0.1303 - val_precision: 0.0936 - val_recall: 1.0000 - val_f1_score: 0.1712
# Epoch 21/30
# 664/664 [==============================] - 159s 239ms/step - loss: 0.0044 - accuracy: 0.1387 - precision: 0.1249 - recall: 1.0000 - f1_score: 0.2220 - val_loss: 3.6562 - val_accuracy: 0.1185 - val_precision: 0.0925 - val_recall: 1.0000 - val_f1_score: 0.1693
# Epoch 22/30
# 664/664 [==============================] - 159s 239ms/step - loss: 0.0044 - accuracy: 0.1399 - precision: 0.1250 - recall: 1.0000 - f1_score: 0.2223 - val_loss: 3.5535 - val_accuracy: 0.1220 - val_precision: 0.0928 - val_recall: 1.0000 - val_f1_score: 0.1698
# Epoch 23/30
# 664/664 [==============================] - 155s 233ms/step - loss: 0.0044 - accuracy: 0.1419 - precision: 0.1253 - recall: 0.9998 - f1_score: 0.2226 - val_loss: 3.7480 - val_accuracy: 0.1062 - val_precision: 0.0913 - val_recall: 1.0000 - val_f1_score: 0.1673
# Epoch 24/30
# 664/664 [==============================] - 154s 231ms/step - loss: 0.0044 - accuracy: 0.1411 - precision: 0.1252 - recall: 1.0000 - f1_score: 0.2225 - val_loss: 3.6181 - val_accuracy: 0.1185 - val_precision: 0.0925 - val_recall: 1.0000 - val_f1_score: 0.1693
# Epoch 25/30
# 664/664 [==============================] - 158s 238ms/step - loss: 0.0043 - accuracy: 0.1573 - precision: 0.1273 - recall: 1.0000 - f1_score: 0.2258 - val_loss: 3.6798 - val_accuracy: 0.1441 - val_precision: 0.0948 - val_recall: 0.9974 - val_f1_score: 0.1731
# Epoch 26/30
# 664/664 [==============================] - 135s 203ms/step - loss: 0.0045 - accuracy: 0.1516 - precision: 0.1265 - recall: 0.9998 - f1_score: 0.2246 - val_loss: 3.6297 - val_accuracy: 0.1263 - val_precision: 0.0932 - val_recall: 1.0000 - val_f1_score: 0.1705
# Epoch 27/30
# 664/664 [==============================] - 179s 270ms/step - loss: 0.0044 - accuracy: 0.1462 - precision: 0.1258 - recall: 1.0000 - f1_score: 0.2235 - val_loss: 3.6607 - val_accuracy: 0.1327 - val_precision: 0.0936 - val_recall: 0.9974 - val_f1_score: 0.1712
# Epoch 28/30
# 664/664 [==============================] - 152s 228ms/step - loss: 0.0043 - accuracy: 0.1569 - precision: 0.1272 - recall: 1.0000 - f1_score: 0.2258 - val_loss: 3.6124 - val_accuracy: 0.1443 - val_precision: 0.0948 - val_recall: 0.9974 - val_f1_score: 0.1731
# Epoch 29/30
# 664/664 [==============================] - 154s 232ms/step - loss: 0.0043 - accuracy: 0.1626 - precision: 0.1280 - recall: 0.9998 - f1_score: 0.2269 - val_loss: 3.7019 - val_accuracy: 0.1152 - val_precision: 0.0921 - val_recall: 1.0000 - val_f1_score: 0.1687
# Epoch 30/30
# 664/664 [==============================] - 155s 233ms/step - loss: 0.0043 - accuracy: 0.1595 - precision: 0.1276 - recall: 1.0000 - f1_score: 0.2263 - val_loss: 3.5227 - val_accuracy: 0.1462 - val_precision: 0.0950 - val_recall: 0.9974 - val_f1_score: 0.1734

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 163s 245ms/step - loss: 0.0043 - accuracy: 0.1727 - precision: 0.1294 - recall: 1.0000 - f1_score: 0.2291 - val_loss: 3.5788 - val_accuracy: 0.1491 - val_precision: 0.0953 - val_recall: 0.9974 - val_f1_score: 0.1739
# Epoch 2/30
# 664/664 [==============================] - 163s 246ms/step - loss: 0.0043 - accuracy: 0.1644 - precision: 0.1282 - recall: 1.0000 - f1_score: 0.2273 - val_loss: 3.6318 - val_accuracy: 0.1408 - val_precision: 0.0946 - val_recall: 1.0000 - val_f1_score: 0.1729
# Epoch 3/30
# 664/664 [==============================] - 159s 239ms/step - loss: 0.0043 - accuracy: 0.1701 - precision: 0.1290 - recall: 0.9998 - f1_score: 0.2285 - val_loss: 3.5293 - val_accuracy: 0.1476 - val_precision: 0.0949 - val_recall: 0.9947 - val_f1_score: 0.1733
# Epoch 4/30
# 664/664 [==============================] - 159s 240ms/step - loss: 0.0042 - accuracy: 0.1794 - precision: 0.1303 - recall: 1.0000 - f1_score: 0.2305 - val_loss: 3.6000 - val_accuracy: 0.1545 - val_precision: 0.0960 - val_recall: 1.0000 - val_f1_score: 0.1752
# Epoch 5/30
# 664/664 [==============================] - 156s 235ms/step - loss: 0.0044 - accuracy: 0.1620 - precision: 0.1279 - recall: 0.9998 - f1_score: 0.2268 - val_loss: 3.5915 - val_accuracy: 0.1398 - val_precision: 0.0945 - val_recall: 1.0000 - val_f1_score: 0.1727
# Epoch 6/30
# 664/664 [==============================] - 155s 234ms/step - loss: 0.0043 - accuracy: 0.1614 - precision: 0.1278 - recall: 0.9998 - f1_score: 0.2267 - val_loss: 3.5461 - val_accuracy: 0.1509 - val_precision: 0.0955 - val_recall: 0.9974 - val_f1_score: 0.1742
# Epoch 7/30
# 664/664 [==============================] - 153s 231ms/step - loss: 0.0044 - accuracy: 0.1439 - precision: 0.1255 - recall: 0.9998 - f1_score: 0.2231 - val_loss: 3.6289 - val_accuracy: 0.1235 - val_precision: 0.0929 - val_recall: 1.0000 - val_f1_score: 0.1701
# Epoch 8/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1672 - precision: 0.1286 - recall: 1.0000 - f1_score: 0.2279 - val_loss: 3.6134 - val_accuracy: 0.1448 - val_precision: 0.0950 - val_recall: 1.0000 - val_f1_score: 0.1736
# Epoch 9/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0042 - accuracy: 0.1743 - precision: 0.1296 - recall: 0.9998 - f1_score: 0.2294 - val_loss: 3.9067 - val_accuracy: 0.1218 - val_precision: 0.0928 - val_recall: 1.0000 - val_f1_score: 0.1698
# Epoch 10/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1725 - precision: 0.1293 - recall: 1.0000 - f1_score: 0.2290 - val_loss: 3.4858 - val_accuracy: 0.1476 - val_precision: 0.0951 - val_recall: 0.9974 - val_f1_score: 0.1737
# Epoch 11/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1827 - precision: 0.1307 - recall: 1.0000 - f1_score: 0.2312 - val_loss: 3.4354 - val_accuracy: 0.1500 - val_precision: 0.0956 - val_recall: 1.0000 - val_f1_score: 0.1745
# Epoch 12/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1890 - precision: 0.1316 - recall: 1.0000 - f1_score: 0.2326 - val_loss: 3.5137 - val_accuracy: 0.1495 - val_precision: 0.0955 - val_recall: 1.0000 - val_f1_score: 0.1744
# Epoch 13/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0042 - accuracy: 0.1852 - precision: 0.1311 - recall: 1.0000 - f1_score: 0.2318 - val_loss: 3.4345 - val_accuracy: 0.1597 - val_precision: 0.0966 - val_recall: 1.0000 - val_f1_score: 0.1761
# Epoch 14/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1959 - precision: 0.1326 - recall: 1.0000 - f1_score: 0.2341 - val_loss: 3.5888 - val_accuracy: 0.1559 - val_precision: 0.0962 - val_recall: 1.0000 - val_f1_score: 0.1755
# Epoch 15/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0042 - accuracy: 0.1827 - precision: 0.1307 - recall: 0.9998 - f1_score: 0.2312 - val_loss: 3.5053 - val_accuracy: 0.1656 - val_precision: 0.0970 - val_recall: 0.9974 - val_f1_score: 0.1768
# Epoch 16/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0042 - accuracy: 0.1935 - precision: 0.1322 - recall: 1.0000 - f1_score: 0.2336 - val_loss: 3.3603 - val_accuracy: 0.1927 - val_precision: 0.0997 - val_recall: 0.9947 - val_f1_score: 0.1812
# Epoch 17/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0042 - accuracy: 0.1946 - precision: 0.1324 - recall: 1.0000 - f1_score: 0.2338 - val_loss: 3.5604 - val_accuracy: 0.1557 - val_precision: 0.0959 - val_recall: 0.9974 - val_f1_score: 0.1750
# Epoch 18/30
# 664/664 [==============================] - 173s 260ms/step - loss: 0.0042 - accuracy: 0.1795 - precision: 0.1303 - recall: 1.0000 - f1_score: 0.2305 - val_loss: 3.7123 - val_accuracy: 0.1545 - val_precision: 0.0960 - val_recall: 1.0000 - val_f1_score: 0.1752
# Epoch 19/30
# 664/664 [==============================] - 183s 276ms/step - loss: 0.0042 - accuracy: 0.1876 - precision: 0.1314 - recall: 1.0000 - f1_score: 0.2323 - val_loss: 3.4708 - val_accuracy: 0.1836 - val_precision: 0.0989 - val_recall: 0.9974 - val_f1_score: 0.1800
# Epoch 20/30
# 664/664 [==============================] - 171s 257ms/step - loss: 0.0043 - accuracy: 0.1706 - precision: 0.1290 - recall: 0.9996 - f1_score: 0.2286 - val_loss: 3.6585 - val_accuracy: 0.1351 - val_precision: 0.0939 - val_recall: 0.9974 - val_f1_score: 0.1716
# Epoch 21/30
# 664/664 [==============================] - 172s 259ms/step - loss: 0.0042 - accuracy: 0.1815 - precision: 0.1306 - recall: 1.0000 - f1_score: 0.2310 - val_loss: 3.6669 - val_accuracy: 0.1557 - val_precision: 0.0959 - val_recall: 0.9974 - val_f1_score: 0.1750
# Epoch 22/30
# 664/664 [==============================] - 158s 238ms/step - loss: 0.0042 - accuracy: 0.1918 - precision: 0.1320 - recall: 1.0000 - f1_score: 0.2332 - val_loss: 3.7011 - val_accuracy: 0.1462 - val_precision: 0.0952 - val_recall: 1.0000 - val_f1_score: 0.1738
# Epoch 23/30
# 664/664 [==============================] - 170s 256ms/step - loss: 0.0042 - accuracy: 0.1846 - precision: 0.1310 - recall: 0.9998 - f1_score: 0.2316 - val_loss: 3.8389 - val_accuracy: 0.1424 - val_precision: 0.0948 - val_recall: 1.0000 - val_f1_score: 0.1732
# Epoch 24/30
# 664/664 [==============================] - 162s 243ms/step - loss: 0.0042 - accuracy: 0.1882 - precision: 0.1315 - recall: 1.0000 - f1_score: 0.2324 - val_loss: 3.5376 - val_accuracy: 0.1626 - val_precision: 0.0967 - val_recall: 0.9974 - val_f1_score: 0.1762
# Epoch 25/30
# 664/664 [==============================] - 160s 241ms/step - loss: 0.0041 - accuracy: 0.2030 - precision: 0.1336 - recall: 1.0000 - f1_score: 0.2357 - val_loss: 3.5543 - val_accuracy: 0.1626 - val_precision: 0.0967 - val_recall: 0.9974 - val_f1_score: 0.1762
# Epoch 26/30
# 664/664 [==============================] - 159s 239ms/step - loss: 0.0041 - accuracy: 0.2069 - precision: 0.1342 - recall: 1.0000 - f1_score: 0.2366 - val_loss: 3.8904 - val_accuracy: 0.1716 - val_precision: 0.0978 - val_recall: 1.0000 - val_f1_score: 0.1782
# Epoch 27/30
# 664/664 [==============================] - 164s 248ms/step - loss: 0.0042 - accuracy: 0.1959 - precision: 0.1326 - recall: 0.9996 - f1_score: 0.2341 - val_loss: 3.7437 - val_accuracy: 0.1296 - val_precision: 0.0935 - val_recall: 1.0000 - val_f1_score: 0.1711
# Epoch 28/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.0041 - accuracy: 0.1929 - precision: 0.1322 - recall: 1.0000 - f1_score: 0.2335 - val_loss: 3.4892 - val_accuracy: 0.1718 - val_precision: 0.0974 - val_recall: 0.9947 - val_f1_score: 0.1775
# Epoch 29/30
# 664/664 [==============================] - 163s 245ms/step - loss: 0.0041 - accuracy: 0.2113 - precision: 0.1348 - recall: 1.0000 - f1_score: 0.2376 - val_loss: 3.3412 - val_accuracy: 0.2026 - val_precision: 0.1008 - val_recall: 0.9947 - val_f1_score: 0.1831
# Epoch 30/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.0041 - accuracy: 0.2052 - precision: 0.1339 - recall: 0.9998 - f1_score: 0.2362 - val_loss: 3.6001 - val_accuracy: 0.1789 - val_precision: 0.0982 - val_recall: 0.9947 - val_f1_score: 0.1787

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 161s 242ms/step - loss: 0.0041 - accuracy: 0.2212 - precision: 0.1363 - recall: 1.0000 - f1_score: 0.2399 - val_loss: 3.5646 - val_accuracy: 0.1848 - val_precision: 0.0988 - val_recall: 0.9947 - val_f1_score: 0.1798
# Epoch 2/30
# 664/664 [==============================] - 165s 249ms/step - loss: 0.0041 - accuracy: 0.2137 - precision: 0.1352 - recall: 1.0000 - f1_score: 0.2382 - val_loss: 3.6914 - val_accuracy: 0.1590 - val_precision: 0.0963 - val_recall: 0.9974 - val_f1_score: 0.1756
# Epoch 3/30
# 664/664 [==============================] - 161s 243ms/step - loss: 0.0041 - accuracy: 0.2030 - precision: 0.1336 - recall: 1.0000 - f1_score: 0.2357 - val_loss: 3.4969 - val_accuracy: 0.2017 - val_precision: 0.1007 - val_recall: 0.9947 - val_f1_score: 0.1829
# Epoch 4/30
# 664/664 [==============================] - 174s 262ms/step - loss: 0.0042 - accuracy: 0.2064 - precision: 0.1341 - recall: 0.9998 - f1_score: 0.2365 - val_loss: 3.5091 - val_accuracy: 0.1611 - val_precision: 0.0967 - val_recall: 1.0000 - val_f1_score: 0.1764
# Epoch 5/30
# 664/664 [==============================] - 168s 252ms/step - loss: 0.0041 - accuracy: 0.2058 - precision: 0.1340 - recall: 1.0000 - f1_score: 0.2364 - val_loss: 3.3677 - val_accuracy: 0.2005 - val_precision: 0.1006 - val_recall: 0.9947 - val_f1_score: 0.1827
# Epoch 6/30
# 664/664 [==============================] - 168s 254ms/step - loss: 0.0041 - accuracy: 0.2190 - precision: 0.1360 - recall: 0.9998 - f1_score: 0.2394 - val_loss: 3.5190 - val_accuracy: 0.1720 - val_precision: 0.0979 - val_recall: 1.0000 - val_f1_score: 0.1783
# Epoch 7/30
# 664/664 [==============================] - 167s 252ms/step - loss: 0.0042 - accuracy: 0.1906 - precision: 0.1318 - recall: 0.9996 - f1_score: 0.2329 - val_loss: 3.3987 - val_accuracy: 0.1860 - val_precision: 0.0992 - val_recall: 0.9974 - val_f1_score: 0.1804
# Epoch 8/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0042 - accuracy: 0.2055 - precision: 0.1340 - recall: 0.9998 - f1_score: 0.2363 - val_loss: 3.4001 - val_accuracy: 0.1434 - val_precision: 0.0947 - val_recall: 0.9974 - val_f1_score: 0.1730
# Epoch 9/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.0040 - accuracy: 0.2136 - precision: 0.1352 - recall: 1.0000 - f1_score: 0.2382 - val_loss: 3.5207 - val_accuracy: 0.1941 - val_precision: 0.0998 - val_recall: 0.9947 - val_f1_score: 0.1815
# Epoch 10/30
# 664/664 [==============================] - 177s 267ms/step - loss: 0.0040 - accuracy: 0.2227 - precision: 0.1365 - recall: 1.0000 - f1_score: 0.2403 - val_loss: 3.4236 - val_accuracy: 0.1898 - val_precision: 0.0996 - val_recall: 0.9974 - val_f1_score: 0.1811
# Epoch 11/30
# 664/664 [==============================] - 188s 283ms/step - loss: 0.0041 - accuracy: 0.2152 - precision: 0.1354 - recall: 0.9998 - f1_score: 0.2385 - val_loss: 3.2962 - val_accuracy: 0.1948 - val_precision: 0.1001 - val_recall: 0.9974 - val_f1_score: 0.1820
# Epoch 12/30
# 664/664 [==============================] - 191s 288ms/step - loss: 0.0041 - accuracy: 0.2141 - precision: 0.1352 - recall: 1.0000 - f1_score: 0.2383 - val_loss: 3.3576 - val_accuracy: 0.2052 - val_precision: 0.1011 - val_recall: 0.9947 - val_f1_score: 0.1835
# Epoch 13/30
# 664/664 [==============================] - 191s 287ms/step - loss: 0.0041 - accuracy: 0.2219 - precision: 0.1364 - recall: 1.0000 - f1_score: 0.2401 - val_loss: 3.4313 - val_accuracy: 0.1979 - val_precision: 0.1003 - val_recall: 0.9947 - val_f1_score: 0.1822
# Epoch 14/30
# 664/664 [==============================] - 191s 288ms/step - loss: 0.0041 - accuracy: 0.2075 - precision: 0.1343 - recall: 1.0000 - f1_score: 0.2368 - val_loss: 3.2756 - val_accuracy: 0.1991 - val_precision: 0.1006 - val_recall: 0.9974 - val_f1_score: 0.1828
# Epoch 15/30
# 664/664 [==============================] - 191s 288ms/step - loss: 0.0041 - accuracy: 0.2118 - precision: 0.1349 - recall: 1.0000 - f1_score: 0.2377 - val_loss: 3.2315 - val_accuracy: 0.1934 - val_precision: 0.1000 - val_recall: 0.9974 - val_f1_score: 0.1817
# Epoch 16/30
# 664/664 [==============================] - 186s 280ms/step - loss: 0.0040 - accuracy: 0.2285 - precision: 0.1374 - recall: 0.9998 - f1_score: 0.2416 - val_loss: 3.3210 - val_accuracy: 0.2159 - val_precision: 0.1026 - val_recall: 0.9974 - val_f1_score: 0.1860
# Epoch 17/30
# 664/664 [==============================] - 173s 261ms/step - loss: 0.0041 - accuracy: 0.2093 - precision: 0.1345 - recall: 1.0000 - f1_score: 0.2372 - val_loss: 3.3347 - val_accuracy: 0.2083 - val_precision: 0.1015 - val_recall: 0.9947 - val_f1_score: 0.1841
# Epoch 18/30
# 664/664 [==============================] - 184s 277ms/step - loss: 0.0041 - accuracy: 0.2160 - precision: 0.1355 - recall: 0.9998 - f1_score: 0.2387 - val_loss: 3.3532 - val_accuracy: 0.1799 - val_precision: 0.0983 - val_recall: 0.9947 - val_f1_score: 0.1789
# Epoch 19/30
# 664/664 [==============================] - 184s 277ms/step - loss: 0.0041 - accuracy: 0.2119 - precision: 0.1349 - recall: 1.0000 - f1_score: 0.2378 - val_loss: 3.4913 - val_accuracy: 0.1770 - val_precision: 0.0982 - val_recall: 0.9974 - val_f1_score: 0.1788
# Epoch 20/30
# 664/664 [==============================] - 165s 249ms/step - loss: 0.0041 - accuracy: 0.2126 - precision: 0.1350 - recall: 0.9998 - f1_score: 0.2379 - val_loss: 3.5419 - val_accuracy: 0.1832 - val_precision: 0.0986 - val_recall: 0.9947 - val_f1_score: 0.1795
# Epoch 21/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0040 - accuracy: 0.2252 - precision: 0.1369 - recall: 1.0000 - f1_score: 0.2409 - val_loss: 3.6055 - val_accuracy: 0.1448 - val_precision: 0.0950 - val_recall: 1.0000 - val_f1_score: 0.1736
# Epoch 22/30
# 664/664 [==============================] - 133s 200ms/step - loss: 0.0040 - accuracy: 0.2145 - precision: 0.1353 - recall: 0.9998 - f1_score: 0.2383 - val_loss: 3.5143 - val_accuracy: 0.1820 - val_precision: 0.0987 - val_recall: 0.9974 - val_f1_score: 0.1797
# Epoch 23/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.0040 - accuracy: 0.2378 - precision: 0.1389 - recall: 0.9998 - f1_score: 0.2438 - val_loss: 3.6862 - val_accuracy: 0.1377 - val_precision: 0.0943 - val_recall: 1.0000 - val_f1_score: 0.1724
# Epoch 24/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.0041 - accuracy: 0.1968 - precision: 0.1327 - recall: 0.9998 - f1_score: 0.2343 - val_loss: 3.2491 - val_accuracy: 0.1955 - val_precision: 0.1002 - val_recall: 0.9974 - val_f1_score: 0.1821
# Epoch 25/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.0041 - accuracy: 0.2180 - precision: 0.1358 - recall: 0.9998 - f1_score: 0.2391 - val_loss: 3.4633 - val_accuracy: 0.1953 - val_precision: 0.1000 - val_recall: 0.9947 - val_f1_score: 0.1817
# Epoch 26/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.0040 - accuracy: 0.2313 - precision: 0.1379 - recall: 1.0000 - f1_score: 0.2423 - val_loss: 3.3116 - val_accuracy: 0.2284 - val_precision: 0.1040 - val_recall: 0.9974 - val_f1_score: 0.1884
# Epoch 27/30
# 664/664 [==============================] - 138s 208ms/step - loss: 0.0040 - accuracy: 0.2255 - precision: 0.1369 - recall: 0.9996 - f1_score: 0.2409 - val_loss: 3.2196 - val_accuracy: 0.2187 - val_precision: 0.1027 - val_recall: 0.9947 - val_f1_score: 0.1861
# Epoch 28/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.0040 - accuracy: 0.2314 - precision: 0.1379 - recall: 1.0000 - f1_score: 0.2423 - val_loss: 3.2175 - val_accuracy: 0.2398 - val_precision: 0.1052 - val_recall: 0.9947 - val_f1_score: 0.1903
# Epoch 29/30
# 664/664 [==============================] - 132s 198ms/step - loss: 0.0041 - accuracy: 0.2225 - precision: 0.1365 - recall: 0.9996 - f1_score: 0.2401 - val_loss: 3.4443 - val_accuracy: 0.1900 - val_precision: 0.0998 - val_recall: 1.0000 - val_f1_score: 0.1815
# Epoch 30/30
# 664/664 [==============================] - 157s 236ms/step - loss: 0.0040 - accuracy: 0.2234 - precision: 0.1366 - recall: 0.9998 - f1_score: 0.2404 - val_loss: 3.7085 - val_accuracy: 0.1239 - val_precision: 0.0930 - val_recall: 1.0000 - val_f1_score: 0.1701

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 90 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 5s 56ms/step
# 664/664 [==============================] - 43s 64ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.10260663507109005
# Train accuracy: 0.13235536508983023

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.10853080568720379
# Train accuracy: 0.13616991217123078

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.11587677725118484
# Train accuracy: 0.13946643434034237

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.12393364928909953
# Train accuracy: 0.1452824413101321

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights('./fine_models/model_ri_best_f1_red_weighted_v2.h5')

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
