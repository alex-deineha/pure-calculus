# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *
# Out:
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 30

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_test = all_data["RI_steps_num"].tolist()
y_lo_test = all_data["LO_steps_num"].tolist()

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# number samples: 4251
# number samples only reducable: 4220
#
# max RI steps count: 386
# max LO steps count: 219
# Count TESTING samples: 4220

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_train = all_data["RI_steps_num"].tolist()
y_lo_train = all_data["LO_steps_num"].tolist()

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# number samples: 44568
# number samples only reducable: 42469
#
# max RI steps count: 400
# max LO steps count: 308
# Count TRAINING samples: 42469

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

# %%
def get_sample_weight(arr_1, arr_2):
    arr_1, arr_2 = np.array(arr_1), np.array(arr_2)
    abs_diff = np.abs(arr_1 - arr_2)
    abs_diff += 2
    return np.log(abs_diff) - 0.6


train_df = pd.DataFrame({
    "term_str": x_train, "is_ri_best": y_train,
    "lo_steps": y_lo_train, "ri_steps": y_ri_train,

    "sample_weights": get_sample_weight(y_ri_train, y_lo_train),
})
test_df = pd.DataFrame({
    "term_str": x_test, "is_ri_best": y_test,
    "lo_steps": y_lo_test, "ri_steps": y_ri_test,
    "sample_weights": get_sample_weight(y_ri_test, y_lo_test),
})

# %%
train_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y((x(y((x(y((x((x((xx)(y(((xx)(((yx)(x((yx)...           0         3
# 1  ((((((((y(y(yx)))(y(yx)))(((yx)(y(y((x(y(y(y(y...           0        60
# 2  (y(y(x(((((y(yx))(yx))((y(y(yx)))(y(y(xx)))))(...           0         5
# 3  (y(((x((xx)(x(x(xx)))))((x((x(yx))(xx)))((y(x(...           1         7
# 4  (y((x(y((((x(x(y(y(x((xx)x))))))(x(((y(x((x((y...           0         2
# 5  (y(y(((((((x(x(y(yx))))(x(x(y(x(x(y(yx))))))))...           0        20
# 6  ((y(y(y((y(y((yx)x)))(x(((yx)(yx))((((y(yx))(y...           0         3
# 7  ((y((((y(xx))(y((yx)(y(x(y(yx)))))))(y((y(x((y...           0        11
# 8  (y(((y(yx))(y(y(x((y(x((y(yx))(y(y(y(xx)))))))...           0        10
# 9                 (y(y(y(((y((yx)x))(yx))(y(yx))))))           0         3
#
#    ri_steps  sample_weights
# 0         3        0.093147
# 1       187        4.259812
# 2         8        1.009438
# 3         4        1.009438
# 4         2        0.093147
# 5        78        3.494345
# 6         8        1.345910
# 7        31        2.491042
# 8        16        1.479442
# 9         3        0.093147

# %%
test_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y(x(y((x(x(((x(y((xx)(x(y(yx))))))x)(y(y(xx...           0         0
# 1  (((((((y(y(yx)))(y(y(xx))))((y(((y(y(yx)))(y(y...           0        28
# 2  (y(y(y(((x(yx))(yx))((x(y((yx)(y(x((((yx)(((xx...           0         1
# 3  (y((((((((y(y(x(xx))))(y(y(y(y(xx))))))(((y(y(...           0        58
# 4  (y(y(((xx)(y(y(y((x((((yx)(yx))(((yx)(yx))(((y...           0         8
# 5  ((((yx)(y((y(y((xx)(y((yx)x)))))((yx)(y((yx)(x...           0        10
# 6  (y(x(y(y(y(y(x((y(y((yx)(y(y(xx))))))(y(y(((y(...           0         4
# 7  (((((((((yx)(y(xx)))(yx))(((yx)(y(xx)))(yx)))(...           0        84
# 8  (y(((x(yx))(y((xx)((x((((x(xx))(xx))x)(y(y((xx...           0         1
# 9                 (y(y(y(y(y(x(y((y(y(xx)))x))))))))           0         1
#
#    ri_steps  sample_weights
# 0         0        0.093147
# 1        47        2.444522
# 2         2        0.498612
# 3        75        2.344439
# 4         8        0.093147
# 5        23        2.108050
# 6         5        0.498612
# 7        91        1.597225
# 8         1        0.093147
# 9         1        0.093147

# %%
def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    sample_weights = tf.convert_to_tensor(example["sample_weights"])
    return tokenized_texts, labels, sample_weights


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1], tokenized_train_data[2])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define & Train the Model

# %%
# Define the model
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model_structure = model.to_json()
# with open("./fine_models/model_ri.json", 'w') as json_file:
#     json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_ri_best_f1_red_weighted_v4.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_ri_red_weighted_v4.h5', save_weights_only=True, save_freq=1)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="ri_best_logs/id_5", histogram_freq=1)

# %%
def draw_training_statistic(history_):
    plt.plot(range(1, epochs + 1), history_.history['loss'], label="loss")
    plt.plot(range(1, epochs + 1), history_.history['val_loss'], label="val_loss")
    plt.xlabel("epochs")
    plt.title("total loss")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['accuracy'], label="accuracy")
    plt.plot(range(1, epochs + 1), history_.history['val_accuracy'], label="val_accuracy")
    plt.xlabel("epochs")
    plt.title("total accuracy")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['precision'], label="precision")
    plt.plot(range(1, epochs + 1), history_.history['val_precision'], label="val_precision")
    plt.xlabel("epochs")
    plt.title("total precision")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['recall'], label="recall")
    plt.plot(range(1, epochs + 1), history_.history['val_recall'], label="val_recall")
    plt.xlabel("epochs")
    plt.title("total recall")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['f1_score'], label="F1-score")
    plt.plot(range(1, epochs + 1), history_.history['val_f1_score'], label="val F1-score")
    plt.xlabel("epochs")
    plt.title("total F1-score")
    plt.legend()
    plt.show()

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 664/664 [==============================] - 136s 196ms/step - loss: 0.5669 - accuracy: 0.8714 - precision: 0.2947 - recall: 0.0331 - f1_score: 0.0596 - val_loss: 0.3572 - val_accuracy: 0.9069 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.5210 - accuracy: 0.8745 - precision: 0.4453 - recall: 0.0858 - f1_score: 0.1439 - val_loss: 0.3000 - val_accuracy: 0.9085 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/30
# 664/664 [==============================] - 132s 199ms/step - loss: 0.5050 - accuracy: 0.8747 - precision: 0.4606 - recall: 0.1153 - f1_score: 0.1845 - val_loss: 0.3072 - val_accuracy: 0.9081 - val_precision: 0.2000 - val_recall: 0.0079 - val_f1_score: 0.0152
# Epoch 4/30
# 664/664 [==============================] - 131s 197ms/step - loss: 0.4971 - accuracy: 0.8745 - precision: 0.4642 - recall: 0.1352 - f1_score: 0.2095 - val_loss: 0.3038 - val_accuracy: 0.9047 - val_precision: 0.1714 - val_recall: 0.0158 - val_f1_score: 0.0290
# Epoch 5/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.4913 - accuracy: 0.8734 - precision: 0.4537 - recall: 0.1464 - f1_score: 0.2213 - val_loss: 0.3089 - val_accuracy: 0.9028 - val_precision: 0.1026 - val_recall: 0.0106 - val_f1_score: 0.0191
# Epoch 6/30
# 664/664 [==============================] - 128s 192ms/step - loss: 0.4843 - accuracy: 0.8742 - precision: 0.4654 - recall: 0.1561 - f1_score: 0.2338 - val_loss: 0.3016 - val_accuracy: 0.9017 - val_precision: 0.1400 - val_recall: 0.0185 - val_f1_score: 0.0326
# Epoch 7/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.4789 - accuracy: 0.8743 - precision: 0.4669 - recall: 0.1619 - f1_score: 0.2404 - val_loss: 0.2998 - val_accuracy: 0.9028 - val_precision: 0.1702 - val_recall: 0.0211 - val_f1_score: 0.0376
# Epoch 8/30
# 664/664 [==============================] - 129s 195ms/step - loss: 0.4723 - accuracy: 0.8739 - precision: 0.4650 - recall: 0.1730 - f1_score: 0.2522 - val_loss: 0.3005 - val_accuracy: 0.8941 - val_precision: 0.1667 - val_recall: 0.0449 - val_f1_score: 0.0707
# Epoch 9/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.4653 - accuracy: 0.8744 - precision: 0.4721 - recall: 0.1833 - f1_score: 0.2641 - val_loss: 0.2998 - val_accuracy: 0.9012 - val_precision: 0.2031 - val_recall: 0.0343 - val_f1_score: 0.0587
# Epoch 10/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.4622 - accuracy: 0.8744 - precision: 0.4734 - recall: 0.1906 - f1_score: 0.2718 - val_loss: 0.2949 - val_accuracy: 0.8967 - val_precision: 0.1566 - val_recall: 0.0343 - val_f1_score: 0.0563
# Epoch 11/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.4553 - accuracy: 0.8757 - precision: 0.4863 - recall: 0.2033 - f1_score: 0.2867 - val_loss: 0.3070 - val_accuracy: 0.8908 - val_precision: 0.1273 - val_recall: 0.0369 - val_f1_score: 0.0573
# Epoch 12/30
# 664/664 [==============================] - 126s 189ms/step - loss: 0.4523 - accuracy: 0.8765 - precision: 0.4949 - recall: 0.2132 - f1_score: 0.2980 - val_loss: 0.3033 - val_accuracy: 0.8917 - val_precision: 0.1176 - val_recall: 0.0317 - val_f1_score: 0.0499
# Epoch 13/30
# 664/664 [==============================] - 125s 188ms/step - loss: 0.4434 - accuracy: 0.8753 - precision: 0.4843 - recall: 0.2251 - f1_score: 0.3074 - val_loss: 0.3066 - val_accuracy: 0.8931 - val_precision: 0.1471 - val_recall: 0.0396 - val_f1_score: 0.0624
# Epoch 14/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.4355 - accuracy: 0.8769 - precision: 0.4986 - recall: 0.2400 - f1_score: 0.3241 - val_loss: 0.3102 - val_accuracy: 0.8829 - val_precision: 0.1557 - val_recall: 0.0686 - val_f1_score: 0.0952
# Epoch 15/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.4331 - accuracy: 0.8785 - precision: 0.5115 - recall: 0.2471 - f1_score: 0.3332 - val_loss: 0.3110 - val_accuracy: 0.8803 - val_precision: 0.1576 - val_recall: 0.0765 - val_f1_score: 0.1030
# Epoch 16/30
# 664/664 [==============================] - 128s 192ms/step - loss: 0.4249 - accuracy: 0.8788 - precision: 0.5139 - recall: 0.2615 - f1_score: 0.3466 - val_loss: 0.3106 - val_accuracy: 0.8839 - val_precision: 0.1636 - val_recall: 0.0712 - val_f1_score: 0.0993
# Epoch 17/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.4204 - accuracy: 0.8803 - precision: 0.5248 - recall: 0.2782 - f1_score: 0.3636 - val_loss: 0.3087 - val_accuracy: 0.8912 - val_precision: 0.1825 - val_recall: 0.0607 - val_f1_score: 0.0911
# Epoch 18/30
# 664/664 [==============================] - 128s 192ms/step - loss: 0.4127 - accuracy: 0.8810 - precision: 0.5295 - recall: 0.2885 - f1_score: 0.3735 - val_loss: 0.3144 - val_accuracy: 0.8844 - val_precision: 0.1189 - val_recall: 0.0449 - val_f1_score: 0.0651
# Epoch 19/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.4109 - accuracy: 0.8809 - precision: 0.5274 - recall: 0.2990 - f1_score: 0.3817 - val_loss: 0.3192 - val_accuracy: 0.8898 - val_precision: 0.1475 - val_recall: 0.0475 - val_f1_score: 0.0719
# Epoch 20/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.4063 - accuracy: 0.8825 - precision: 0.5389 - recall: 0.3080 - f1_score: 0.3920 - val_loss: 0.3103 - val_accuracy: 0.8929 - val_precision: 0.2033 - val_recall: 0.0660 - val_f1_score: 0.0996
# Epoch 21/30
# 664/664 [==============================] - 128s 192ms/step - loss: 0.3998 - accuracy: 0.8832 - precision: 0.5427 - recall: 0.3140 - f1_score: 0.3978 - val_loss: 0.3215 - val_accuracy: 0.8839 - val_precision: 0.1899 - val_recall: 0.0897 - val_f1_score: 0.1219
# Epoch 22/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.3930 - accuracy: 0.8830 - precision: 0.5408 - recall: 0.3215 - f1_score: 0.4032 - val_loss: 0.3355 - val_accuracy: 0.8782 - val_precision: 0.1707 - val_recall: 0.0923 - val_f1_score: 0.1199
# Epoch 23/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.3917 - accuracy: 0.8825 - precision: 0.5366 - recall: 0.3255 - f1_score: 0.4052 - val_loss: 0.3233 - val_accuracy: 0.8836 - val_precision: 0.1267 - val_recall: 0.0501 - val_f1_score: 0.0718
# Epoch 24/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.3843 - accuracy: 0.8852 - precision: 0.5532 - recall: 0.3439 - f1_score: 0.4241 - val_loss: 0.3282 - val_accuracy: 0.8806 - val_precision: 0.1429 - val_recall: 0.0660 - val_f1_score: 0.0903
# Epoch 25/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3811 - accuracy: 0.8856 - precision: 0.5559 - recall: 0.3448 - f1_score: 0.4256 - val_loss: 0.3268 - val_accuracy: 0.8863 - val_precision: 0.2047 - val_recall: 0.0923 - val_f1_score: 0.1273
# Epoch 26/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3791 - accuracy: 0.8851 - precision: 0.5514 - recall: 0.3506 - f1_score: 0.4286 - val_loss: 0.3263 - val_accuracy: 0.8848 - val_precision: 0.1592 - val_recall: 0.0660 - val_f1_score: 0.0933
# Epoch 27/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3764 - accuracy: 0.8873 - precision: 0.5658 - recall: 0.3582 - f1_score: 0.4387 - val_loss: 0.3339 - val_accuracy: 0.8903 - val_precision: 0.1769 - val_recall: 0.0607 - val_f1_score: 0.0904
# Epoch 28/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.3682 - accuracy: 0.8870 - precision: 0.5612 - recall: 0.3705 - f1_score: 0.4463 - val_loss: 0.3322 - val_accuracy: 0.8867 - val_precision: 0.1847 - val_recall: 0.0765 - val_f1_score: 0.1082
# Epoch 29/30
# 664/664 [==============================] - 125s 189ms/step - loss: 0.3676 - accuracy: 0.8864 - precision: 0.5573 - recall: 0.3688 - f1_score: 0.4439 - val_loss: 0.3339 - val_accuracy: 0.8877 - val_precision: 0.1583 - val_recall: 0.0580 - val_f1_score: 0.0849
# Epoch 30/30
# 664/664 [==============================] - 133s 200ms/step - loss: 0.3650 - accuracy: 0.8874 - precision: 0.5632 - recall: 0.3738 - f1_score: 0.4493 - val_loss: 0.3349 - val_accuracy: 0.8867 - val_precision: 0.1806 - val_recall: 0.0739 - val_f1_score: 0.1049

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.3604 - accuracy: 0.8857 - precision: 0.5513 - recall: 0.3764 - f1_score: 0.4474 - val_loss: 0.3516 - val_accuracy: 0.8825 - val_precision: 0.1969 - val_recall: 0.1003 - val_f1_score: 0.1329
# Epoch 2/30
# 664/664 [==============================] - 134s 202ms/step - loss: 0.3541 - accuracy: 0.8883 - precision: 0.5669 - recall: 0.3856 - f1_score: 0.4590 - val_loss: 0.3424 - val_accuracy: 0.8884 - val_precision: 0.1933 - val_recall: 0.0765 - val_f1_score: 0.1096
# Epoch 3/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.3546 - accuracy: 0.8887 - precision: 0.5678 - recall: 0.3969 - f1_score: 0.4672 - val_loss: 0.3430 - val_accuracy: 0.8827 - val_precision: 0.1548 - val_recall: 0.0686 - val_f1_score: 0.0951
# Epoch 4/30
# 664/664 [==============================] - 135s 204ms/step - loss: 0.3538 - accuracy: 0.8898 - precision: 0.5747 - recall: 0.3973 - f1_score: 0.4698 - val_loss: 0.3488 - val_accuracy: 0.8879 - val_precision: 0.1544 - val_recall: 0.0554 - val_f1_score: 0.0816
# Epoch 5/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.3484 - accuracy: 0.8883 - precision: 0.5640 - recall: 0.4008 - f1_score: 0.4686 - val_loss: 0.3551 - val_accuracy: 0.8822 - val_precision: 0.1169 - val_recall: 0.0475 - val_f1_score: 0.0675
# Epoch 6/30
# 664/664 [==============================] - 127s 191ms/step - loss: 0.3438 - accuracy: 0.8911 - precision: 0.5808 - recall: 0.4102 - f1_score: 0.4808 - val_loss: 0.3512 - val_accuracy: 0.8844 - val_precision: 0.1342 - val_recall: 0.0528 - val_f1_score: 0.0758
# Epoch 7/30
# 664/664 [==============================] - 125s 189ms/step - loss: 0.3441 - accuracy: 0.8900 - precision: 0.5737 - recall: 0.4096 - f1_score: 0.4779 - val_loss: 0.3598 - val_accuracy: 0.8827 - val_precision: 0.1548 - val_recall: 0.0686 - val_f1_score: 0.0951
# Epoch 8/30
# 664/664 [==============================] - 132s 199ms/step - loss: 0.3396 - accuracy: 0.8919 - precision: 0.5863 - recall: 0.4080 - f1_score: 0.4812 - val_loss: 0.3563 - val_accuracy: 0.8770 - val_precision: 0.1635 - val_recall: 0.0897 - val_f1_score: 0.1158
# Epoch 9/30
# 664/664 [==============================] - 134s 201ms/step - loss: 0.3360 - accuracy: 0.8904 - precision: 0.5744 - recall: 0.4192 - f1_score: 0.4847 - val_loss: 0.3507 - val_accuracy: 0.8820 - val_precision: 0.1949 - val_recall: 0.1003 - val_f1_score: 0.1324
# Epoch 10/30
# 664/664 [==============================] - 141s 212ms/step - loss: 0.3326 - accuracy: 0.8923 - precision: 0.5845 - recall: 0.4266 - f1_score: 0.4932 - val_loss: 0.3580 - val_accuracy: 0.8791 - val_precision: 0.1709 - val_recall: 0.0897 - val_f1_score: 0.1176
# Epoch 11/30
# 664/664 [==============================] - 129s 195ms/step - loss: 0.3299 - accuracy: 0.8937 - precision: 0.5935 - recall: 0.4280 - f1_score: 0.4973 - val_loss: 0.3557 - val_accuracy: 0.8827 - val_precision: 0.2041 - val_recall: 0.1055 - val_f1_score: 0.1391
# Epoch 12/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3264 - accuracy: 0.8929 - precision: 0.5881 - recall: 0.4303 - f1_score: 0.4970 - val_loss: 0.3680 - val_accuracy: 0.8803 - val_precision: 0.2083 - val_recall: 0.1187 - val_f1_score: 0.1513
# Epoch 13/30
# 664/664 [==============================] - 133s 201ms/step - loss: 0.3260 - accuracy: 0.8912 - precision: 0.5750 - recall: 0.4397 - f1_score: 0.4983 - val_loss: 0.3532 - val_accuracy: 0.8834 - val_precision: 0.1844 - val_recall: 0.0871 - val_f1_score: 0.1183
# Epoch 14/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3240 - accuracy: 0.8941 - precision: 0.5934 - recall: 0.4389 - f1_score: 0.5046 - val_loss: 0.3623 - val_accuracy: 0.8829 - val_precision: 0.1637 - val_recall: 0.0739 - val_f1_score: 0.1018
# Epoch 15/30
# 664/664 [==============================] - 134s 201ms/step - loss: 0.3230 - accuracy: 0.8937 - precision: 0.5889 - recall: 0.4467 - f1_score: 0.5081 - val_loss: 0.3617 - val_accuracy: 0.8806 - val_precision: 0.2066 - val_recall: 0.1161 - val_f1_score: 0.1486
# Epoch 16/30
# 664/664 [==============================] - 135s 203ms/step - loss: 0.3193 - accuracy: 0.8926 - precision: 0.5826 - recall: 0.4460 - f1_score: 0.5052 - val_loss: 0.3669 - val_accuracy: 0.8768 - val_precision: 0.2050 - val_recall: 0.1293 - val_f1_score: 0.1586
# Epoch 17/30
# 664/664 [==============================] - 131s 198ms/step - loss: 0.3179 - accuracy: 0.8943 - precision: 0.5913 - recall: 0.4521 - f1_score: 0.5124 - val_loss: 0.3703 - val_accuracy: 0.8732 - val_precision: 0.1977 - val_recall: 0.1346 - val_f1_score: 0.1601
# Epoch 18/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.3135 - accuracy: 0.8962 - precision: 0.6019 - recall: 0.4590 - f1_score: 0.5208 - val_loss: 0.3622 - val_accuracy: 0.8818 - val_precision: 0.2297 - val_recall: 0.1346 - val_f1_score: 0.1697
# Epoch 19/30
# 664/664 [==============================] - 131s 198ms/step - loss: 0.3078 - accuracy: 0.8954 - precision: 0.5939 - recall: 0.4699 - f1_score: 0.5247 - val_loss: 0.3781 - val_accuracy: 0.8746 - val_precision: 0.1711 - val_recall: 0.1029 - val_f1_score: 0.1285
# Epoch 20/30
# 664/664 [==============================] - 137s 206ms/step - loss: 0.3100 - accuracy: 0.8944 - precision: 0.5897 - recall: 0.4636 - f1_score: 0.5191 - val_loss: 0.3826 - val_accuracy: 0.8773 - val_precision: 0.1643 - val_recall: 0.0897 - val_f1_score: 0.1160
# Epoch 21/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3090 - accuracy: 0.8936 - precision: 0.5847 - recall: 0.4649 - f1_score: 0.5180 - val_loss: 0.3702 - val_accuracy: 0.8796 - val_precision: 0.2081 - val_recall: 0.1214 - val_f1_score: 0.1533
# Epoch 22/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3059 - accuracy: 0.8958 - precision: 0.5949 - recall: 0.4766 - f1_score: 0.5292 - val_loss: 0.3755 - val_accuracy: 0.8865 - val_precision: 0.1988 - val_recall: 0.0871 - val_f1_score: 0.1211
# Epoch 23/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.3052 - accuracy: 0.8947 - precision: 0.5883 - recall: 0.4778 - f1_score: 0.5273 - val_loss: 0.3795 - val_accuracy: 0.8794 - val_precision: 0.1934 - val_recall: 0.1082 - val_f1_score: 0.1387
# Epoch 24/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.3037 - accuracy: 0.8961 - precision: 0.5970 - recall: 0.4751 - f1_score: 0.5291 - val_loss: 0.3984 - val_accuracy: 0.8720 - val_precision: 0.1962 - val_recall: 0.1372 - val_f1_score: 0.1615
# Epoch 25/30
# 664/664 [==============================] - 129s 195ms/step - loss: 0.2987 - accuracy: 0.8961 - precision: 0.5952 - recall: 0.4843 - f1_score: 0.5341 - val_loss: 0.3877 - val_accuracy: 0.8735 - val_precision: 0.1784 - val_recall: 0.1135 - val_f1_score: 0.1387
# Epoch 26/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.2979 - accuracy: 0.8962 - precision: 0.5948 - recall: 0.4870 - f1_score: 0.5355 - val_loss: 0.3869 - val_accuracy: 0.8770 - val_precision: 0.2200 - val_recall: 0.1451 - val_f1_score: 0.1749
# Epoch 27/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.3027 - accuracy: 0.8970 - precision: 0.6003 - recall: 0.4849 - f1_score: 0.5365 - val_loss: 0.3766 - val_accuracy: 0.8773 - val_precision: 0.2068 - val_recall: 0.1293 - val_f1_score: 0.1591
# Epoch 28/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.2969 - accuracy: 0.8955 - precision: 0.5916 - recall: 0.4839 - f1_score: 0.5323 - val_loss: 0.3909 - val_accuracy: 0.8723 - val_precision: 0.1899 - val_recall: 0.1293 - val_f1_score: 0.1538
# Epoch 29/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.2957 - accuracy: 0.8963 - precision: 0.5944 - recall: 0.4933 - f1_score: 0.5392 - val_loss: 0.3860 - val_accuracy: 0.8751 - val_precision: 0.2063 - val_recall: 0.1372 - val_f1_score: 0.1648
# Epoch 30/30
# 664/664 [==============================] - 129s 194ms/step - loss: 0.2908 - accuracy: 0.8986 - precision: 0.6063 - recall: 0.4998 - f1_score: 0.5479 - val_loss: 0.3924 - val_accuracy: 0.8742 - val_precision: 0.1935 - val_recall: 0.1266 - val_f1_score: 0.1531

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.2890 - accuracy: 0.8994 - precision: 0.6105 - recall: 0.5011 - f1_score: 0.5504 - val_loss: 0.3929 - val_accuracy: 0.8692 - val_precision: 0.1900 - val_recall: 0.1398 - val_f1_score: 0.1611
# Epoch 2/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.2922 - accuracy: 0.8988 - precision: 0.6095 - recall: 0.4925 - f1_score: 0.5448 - val_loss: 0.3902 - val_accuracy: 0.8758 - val_precision: 0.2179 - val_recall: 0.1478 - val_f1_score: 0.1761
# Epoch 3/30
# 664/664 [==============================] - 128s 193ms/step - loss: 0.2890 - accuracy: 0.8995 - precision: 0.6108 - recall: 0.5027 - f1_score: 0.5515 - val_loss: 0.3964 - val_accuracy: 0.8761 - val_precision: 0.2231 - val_recall: 0.1530 - val_f1_score: 0.1815
# Epoch 4/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.2877 - accuracy: 0.8994 - precision: 0.6102 - recall: 0.5019 - f1_score: 0.5508 - val_loss: 0.3950 - val_accuracy: 0.8855 - val_precision: 0.2079 - val_recall: 0.0976 - val_f1_score: 0.1329
# Epoch 5/30
# 664/664 [==============================] - 137s 206ms/step - loss: 0.2838 - accuracy: 0.9008 - precision: 0.6177 - recall: 0.5057 - f1_score: 0.5561 - val_loss: 0.3977 - val_accuracy: 0.8801 - val_precision: 0.2019 - val_recall: 0.1135 - val_f1_score: 0.1453
# Epoch 6/30
# 664/664 [==============================] - 136s 205ms/step - loss: 0.2825 - accuracy: 0.9009 - precision: 0.6174 - recall: 0.5103 - f1_score: 0.5588 - val_loss: 0.4083 - val_accuracy: 0.8718 - val_precision: 0.1932 - val_recall: 0.1346 - val_f1_score: 0.1586
# Epoch 7/30
# 664/664 [==============================] - 129s 195ms/step - loss: 0.2833 - accuracy: 0.9007 - precision: 0.6153 - recall: 0.5121 - f1_score: 0.5590 - val_loss: 0.3908 - val_accuracy: 0.8787 - val_precision: 0.2286 - val_recall: 0.1478 - val_f1_score: 0.1795
# Epoch 8/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.2801 - accuracy: 0.8993 - precision: 0.6077 - recall: 0.5109 - f1_score: 0.5551 - val_loss: 0.3736 - val_accuracy: 0.8877 - val_precision: 0.2705 - val_recall: 0.1478 - val_f1_score: 0.1911
# Epoch 9/30
# 664/664 [==============================] - 131s 198ms/step - loss: 0.2864 - accuracy: 0.8991 - precision: 0.6064 - recall: 0.5100 - f1_score: 0.5540 - val_loss: 0.3945 - val_accuracy: 0.8701 - val_precision: 0.1712 - val_recall: 0.1161 - val_f1_score: 0.1384
# Epoch 10/30
# 664/664 [==============================] - 133s 200ms/step - loss: 0.2772 - accuracy: 0.9006 - precision: 0.6129 - recall: 0.5199 - f1_score: 0.5626 - val_loss: 0.3814 - val_accuracy: 0.8822 - val_precision: 0.2318 - val_recall: 0.1346 - val_f1_score: 0.1703
# Epoch 11/30
# 664/664 [==============================] - 136s 205ms/step - loss: 0.2780 - accuracy: 0.9006 - precision: 0.6139 - recall: 0.5161 - f1_score: 0.5608 - val_loss: 0.3865 - val_accuracy: 0.8739 - val_precision: 0.2023 - val_recall: 0.1372 - val_f1_score: 0.1635
# Epoch 12/30
# 664/664 [==============================] - 130s 196ms/step - loss: 0.2715 - accuracy: 0.9022 - precision: 0.6166 - recall: 0.5398 - f1_score: 0.5757 - val_loss: 0.3977 - val_accuracy: 0.8789 - val_precision: 0.2273 - val_recall: 0.1451 - val_f1_score: 0.1771
# Epoch 13/30
# 664/664 [==============================] - 133s 200ms/step - loss: 0.2690 - accuracy: 0.9031 - precision: 0.6247 - recall: 0.5307 - f1_score: 0.5739 - val_loss: 0.3964 - val_accuracy: 0.8732 - val_precision: 0.2383 - val_recall: 0.1873 - val_f1_score: 0.2097
# Epoch 14/30
# 664/664 [==============================] - 134s 202ms/step - loss: 0.2759 - accuracy: 0.9002 - precision: 0.6080 - recall: 0.5284 - f1_score: 0.5654 - val_loss: 0.4020 - val_accuracy: 0.8810 - val_precision: 0.2217 - val_recall: 0.1293 - val_f1_score: 0.1633
# Epoch 15/30
# 664/664 [==============================] - 131s 198ms/step - loss: 0.2677 - accuracy: 0.9025 - precision: 0.6196 - recall: 0.5360 - f1_score: 0.5748 - val_loss: 0.4143 - val_accuracy: 0.8749 - val_precision: 0.2101 - val_recall: 0.1425 - val_f1_score: 0.1698
# Epoch 16/30
# 664/664 [==============================] - 130s 195ms/step - loss: 0.2693 - accuracy: 0.9018 - precision: 0.6154 - recall: 0.5352 - f1_score: 0.5725 - val_loss: 0.4251 - val_accuracy: 0.8718 - val_precision: 0.1978 - val_recall: 0.1398 - val_f1_score: 0.1638
# Epoch 17/30
# 664/664 [==============================] - 136s 204ms/step - loss: 0.2704 - accuracy: 0.9020 - precision: 0.6163 - recall: 0.5364 - f1_score: 0.5736 - val_loss: 0.4366 - val_accuracy: 0.8751 - val_precision: 0.1891 - val_recall: 0.1187 - val_f1_score: 0.1459
# Epoch 18/30
# 664/664 [==============================] - 137s 206ms/step - loss: 0.2664 - accuracy: 0.9022 - precision: 0.6164 - recall: 0.5416 - f1_score: 0.5766 - val_loss: 0.4097 - val_accuracy: 0.8706 - val_precision: 0.2028 - val_recall: 0.1504 - val_f1_score: 0.1727
# Epoch 19/30
# 664/664 [==============================] - 128s 192ms/step - loss: 0.2733 - accuracy: 0.9014 - precision: 0.6145 - recall: 0.5301 - f1_score: 0.5692 - val_loss: 0.3991 - val_accuracy: 0.8758 - val_precision: 0.2134 - val_recall: 0.1425 - val_f1_score: 0.1709
# Epoch 20/30
# 664/664 [==============================] - 133s 200ms/step - loss: 0.2629 - accuracy: 0.9052 - precision: 0.6326 - recall: 0.5450 - f1_score: 0.5856 - val_loss: 0.4068 - val_accuracy: 0.8789 - val_precision: 0.2105 - val_recall: 0.1266 - val_f1_score: 0.1582
# Epoch 21/30
# 664/664 [==============================] - 135s 203ms/step - loss: 0.2619 - accuracy: 0.9040 - precision: 0.6245 - recall: 0.5489 - f1_score: 0.5842 - val_loss: 0.3983 - val_accuracy: 0.8820 - val_precision: 0.2258 - val_recall: 0.1293 - val_f1_score: 0.1644
# Epoch 22/30
# 664/664 [==============================] - 135s 203ms/step - loss: 0.2649 - accuracy: 0.9029 - precision: 0.6197 - recall: 0.5439 - f1_score: 0.5793 - val_loss: 0.4113 - val_accuracy: 0.8806 - val_precision: 0.2172 - val_recall: 0.1266 - val_f1_score: 0.1600
# Epoch 23/30
# 664/664 [==============================] - 129s 195ms/step - loss: 0.2613 - accuracy: 0.9042 - precision: 0.6242 - recall: 0.5552 - f1_score: 0.5877 - val_loss: 0.4124 - val_accuracy: 0.8678 - val_precision: 0.2280 - val_recall: 0.1979 - val_f1_score: 0.2119
# Epoch 24/30
# 664/664 [==============================] - 133s 201ms/step - loss: 0.2538 - accuracy: 0.9047 - precision: 0.6261 - recall: 0.5575 - f1_score: 0.5898 - val_loss: 0.4195 - val_accuracy: 0.8718 - val_precision: 0.2207 - val_recall: 0.1689 - val_f1_score: 0.1913
# Epoch 25/30
# 664/664 [==============================] - 136s 205ms/step - loss: 0.2553 - accuracy: 0.9038 - precision: 0.6205 - recall: 0.5588 - f1_score: 0.5880 - val_loss: 0.4043 - val_accuracy: 0.8730 - val_precision: 0.2443 - val_recall: 0.1979 - val_f1_score: 0.2187
# Epoch 26/30
# 664/664 [==============================] - 131s 197ms/step - loss: 0.2618 - accuracy: 0.9028 - precision: 0.6160 - recall: 0.5556 - f1_score: 0.5842 - val_loss: 0.4107 - val_accuracy: 0.8780 - val_precision: 0.2405 - val_recall: 0.1662 - val_f1_score: 0.1966
# Epoch 27/30
# 664/664 [==============================] - 125s 188ms/step - loss: 0.2625 - accuracy: 0.9033 - precision: 0.6208 - recall: 0.5489 - f1_score: 0.5826 - val_loss: 0.4092 - val_accuracy: 0.8637 - val_precision: 0.2200 - val_recall: 0.2032 - val_f1_score: 0.2112
# Epoch 28/30
# 664/664 [==============================] - 131s 197ms/step - loss: 0.2539 - accuracy: 0.9054 - precision: 0.6289 - recall: 0.5611 - f1_score: 0.5931 - val_loss: 0.4143 - val_accuracy: 0.8775 - val_precision: 0.2125 - val_recall: 0.1346 - val_f1_score: 0.1648
# Epoch 29/30
# 664/664 [==============================] - 137s 206ms/step - loss: 0.2543 - accuracy: 0.9056 - precision: 0.6300 - recall: 0.5623 - f1_score: 0.5942 - val_loss: 0.4124 - val_accuracy: 0.8694 - val_precision: 0.2133 - val_recall: 0.1689 - val_f1_score: 0.1885
# Epoch 30/30
# 664/664 [==============================] - 127s 192ms/step - loss: 0.2497 - accuracy: 0.9065 - precision: 0.6366 - recall: 0.5580 - f1_score: 0.5947 - val_loss: 0.4080 - val_accuracy: 0.8770 - val_precision: 0.2426 - val_recall: 0.1741 - val_f1_score: 0.2028

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 90 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 4s 49ms/step
# 664/664 [==============================] - 33s 49ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7898104265402843
# Train accuracy: 0.8599213543996798

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8298578199052132
# Train accuracy: 0.9007040429489745

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8516587677725118
# Train accuracy: 0.9178224116414325

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8770142180094787
# Train accuracy: 0.9267936612588006

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights('./fine_models/model_ri_best_f1_red_weighted_v4.h5')

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 5s 49ms/step
# 664/664 [==============================] - 33s 49ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7649289099526067
# Train accuracy: 0.8398125691680991

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8213270142180095
# Train accuracy: 0.8904612776378064

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8476303317535545
# Train accuracy: 0.909934305022487

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8729857819905213
# Train accuracy: 0.921731145070522
