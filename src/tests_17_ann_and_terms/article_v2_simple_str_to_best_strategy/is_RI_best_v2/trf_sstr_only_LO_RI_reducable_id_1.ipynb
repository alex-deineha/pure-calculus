# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *
# Out:
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 4
#       1 sequence_len = 512
#       2 batch_size = 64
# ----> 4 config = BertConfig(
#       5     vocab_size=9,
#       6     hidden_size=84,
#       7     num_hidden_layers=2,
#       8     num_attention_heads=6,
#       9     intermediate_size=64,
#      10     max_position_embeddings=sequence_len,
#      11     num_labels=2
#      12 )
#      14 epochs = 30
#
# NameError: name 'BertConfig' is not defined

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# number samples: 4251
# number samples only reducable: 4220
#
# max RI steps count: 386
# max LO steps count: 219
# Count TESTING samples: 4220

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# number samples: 44568
# number samples only reducable: 42469
#
# max RI steps count: 400
# max LO steps count: 308
# Count TRAINING samples: 42469

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "is_ri_best": y_train})
test_df = pd.DataFrame({"term_str": x_test, "is_ri_best": y_test})

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define the model

# %%
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model_structure = model.to_json()
# with open("./fine_models/model_ri.json", 'w') as json_file:
#     json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_ri_best_f1_only_reducable.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_ri_only_reducable.h5', save_weights_only=True, save_freq=1)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="ri_best_logs/id_1", histogram_freq=1)

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1, callbacks=[f1_callback, step_callback, tensorboard_callback])
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 664/664 [==============================] - 175s 255ms/step - loss: 0.3533 - accuracy: 0.8758 - precision: 0.3902 - recall: 0.0184 - f1_score: 0.0351 - val_loss: 0.2838 - val_accuracy: 0.9100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 172s 260ms/step - loss: 0.3336 - accuracy: 0.8789 - precision: 0.6179 - recall: 0.0397 - f1_score: 0.0745 - val_loss: 0.2685 - val_accuracy: 0.9104 - val_precision: 0.6667 - val_recall: 0.0053 - val_f1_score: 0.0105
# Epoch 3/30
# 664/664 [==============================] - 163s 246ms/step - loss: 0.3269 - accuracy: 0.8809 - precision: 0.6810 - recall: 0.0577 - f1_score: 0.1063 - val_loss: 0.2702 - val_accuracy: 0.9102 - val_precision: 0.5000 - val_recall: 0.0026 - val_f1_score: 0.0052
# Epoch 4/30
# 664/664 [==============================] - 160s 241ms/step - loss: 0.3231 - accuracy: 0.8826 - precision: 0.7308 - recall: 0.0713 - f1_score: 0.1299 - val_loss: 0.2677 - val_accuracy: 0.9100 - val_precision: 0.4286 - val_recall: 0.0079 - val_f1_score: 0.0155
# Epoch 5/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.3195 - accuracy: 0.8833 - precision: 0.7282 - recall: 0.0801 - f1_score: 0.1443 - val_loss: 0.2662 - val_accuracy: 0.9097 - val_precision: 0.3333 - val_recall: 0.0053 - val_f1_score: 0.0104
# Epoch 6/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.3170 - accuracy: 0.8831 - precision: 0.7038 - recall: 0.0847 - f1_score: 0.1512 - val_loss: 0.2681 - val_accuracy: 0.9078 - val_precision: 0.1875 - val_recall: 0.0079 - val_f1_score: 0.0152
# Epoch 7/30
# 664/664 [==============================] - 165s 249ms/step - loss: 0.3145 - accuracy: 0.8840 - precision: 0.7128 - recall: 0.0946 - f1_score: 0.1671 - val_loss: 0.2650 - val_accuracy: 0.9071 - val_precision: 0.1905 - val_recall: 0.0106 - val_f1_score: 0.0200
# Epoch 8/30
# 664/664 [==============================] - 167s 251ms/step - loss: 0.3118 - accuracy: 0.8840 - precision: 0.6918 - recall: 0.1019 - f1_score: 0.1777 - val_loss: 0.2635 - val_accuracy: 0.9073 - val_precision: 0.2000 - val_recall: 0.0106 - val_f1_score: 0.0201
# Epoch 9/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.3091 - accuracy: 0.8841 - precision: 0.6795 - recall: 0.1084 - f1_score: 0.1870 - val_loss: 0.2675 - val_accuracy: 0.9069 - val_precision: 0.1111 - val_recall: 0.0053 - val_f1_score: 0.0101
# Epoch 10/30
# 664/664 [==============================] - 166s 251ms/step - loss: 0.3067 - accuracy: 0.8860 - precision: 0.7061 - recall: 0.1247 - f1_score: 0.2120 - val_loss: 0.2658 - val_accuracy: 0.9064 - val_precision: 0.1364 - val_recall: 0.0079 - val_f1_score: 0.0150
# Epoch 11/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.3035 - accuracy: 0.8864 - precision: 0.6996 - recall: 0.1330 - f1_score: 0.2234 - val_loss: 0.2676 - val_accuracy: 0.9057 - val_precision: 0.1724 - val_recall: 0.0132 - val_f1_score: 0.0245
# Epoch 12/30
# 664/664 [==============================] - 163s 246ms/step - loss: 0.3016 - accuracy: 0.8868 - precision: 0.6908 - recall: 0.1425 - f1_score: 0.2363 - val_loss: 0.2685 - val_accuracy: 0.9043 - val_precision: 0.1951 - val_recall: 0.0211 - val_f1_score: 0.0381
# Epoch 13/30
# 664/664 [==============================] - 162s 244ms/step - loss: 0.2984 - accuracy: 0.8874 - precision: 0.6871 - recall: 0.1548 - f1_score: 0.2527 - val_loss: 0.2683 - val_accuracy: 0.9081 - val_precision: 0.3043 - val_recall: 0.0185 - val_f1_score: 0.0348
# Epoch 14/30
# 664/664 [==============================] - 162s 244ms/step - loss: 0.2971 - accuracy: 0.8883 - precision: 0.7019 - recall: 0.1588 - f1_score: 0.2590 - val_loss: 0.2711 - val_accuracy: 0.9055 - val_precision: 0.2059 - val_recall: 0.0185 - val_f1_score: 0.0339
# Epoch 15/30
# 664/664 [==============================] - 162s 244ms/step - loss: 0.2940 - accuracy: 0.8884 - precision: 0.6892 - recall: 0.1678 - f1_score: 0.2699 - val_loss: 0.2666 - val_accuracy: 0.9043 - val_precision: 0.2449 - val_recall: 0.0317 - val_f1_score: 0.0561
# Epoch 16/30
# 664/664 [==============================] - 162s 244ms/step - loss: 0.2912 - accuracy: 0.8899 - precision: 0.7000 - recall: 0.1824 - f1_score: 0.2894 - val_loss: 0.2693 - val_accuracy: 0.9026 - val_precision: 0.2143 - val_recall: 0.0317 - val_f1_score: 0.0552
# Epoch 17/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.2899 - accuracy: 0.8897 - precision: 0.6902 - recall: 0.1856 - f1_score: 0.2926 - val_loss: 0.2691 - val_accuracy: 0.9033 - val_precision: 0.2157 - val_recall: 0.0290 - val_f1_score: 0.0512
# Epoch 18/30
# 664/664 [==============================] - 169s 255ms/step - loss: 0.2882 - accuracy: 0.8905 - precision: 0.6980 - recall: 0.1918 - f1_score: 0.3009 - val_loss: 0.2736 - val_accuracy: 0.9012 - val_precision: 0.2432 - val_recall: 0.0475 - val_f1_score: 0.0795
# Epoch 19/30
# 664/664 [==============================] - 167s 251ms/step - loss: 0.2863 - accuracy: 0.8909 - precision: 0.6932 - recall: 0.2021 - f1_score: 0.3130 - val_loss: 0.2747 - val_accuracy: 0.9026 - val_precision: 0.2241 - val_recall: 0.0343 - val_f1_score: 0.0595
# Epoch 20/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.2845 - accuracy: 0.8909 - precision: 0.6868 - recall: 0.2071 - f1_score: 0.3182 - val_loss: 0.2732 - val_accuracy: 0.9038 - val_precision: 0.2000 - val_recall: 0.0237 - val_f1_score: 0.0425
# Epoch 21/30
# 664/664 [==============================] - 163s 245ms/step - loss: 0.2815 - accuracy: 0.8936 - precision: 0.7149 - recall: 0.2234 - f1_score: 0.3404 - val_loss: 0.2697 - val_accuracy: 0.9012 - val_precision: 0.2121 - val_recall: 0.0369 - val_f1_score: 0.0629
# Epoch 22/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.2807 - accuracy: 0.8928 - precision: 0.7005 - recall: 0.2232 - f1_score: 0.3385 - val_loss: 0.2792 - val_accuracy: 0.8986 - val_precision: 0.2421 - val_recall: 0.0607 - val_f1_score: 0.0970
# Epoch 23/30
# 664/664 [==============================] - 172s 259ms/step - loss: 0.2792 - accuracy: 0.8933 - precision: 0.7054 - recall: 0.2270 - f1_score: 0.3435 - val_loss: 0.2799 - val_accuracy: 0.9031 - val_precision: 0.2973 - val_recall: 0.0580 - val_f1_score: 0.0971
# Epoch 24/30
# 664/664 [==============================] - 169s 255ms/step - loss: 0.2762 - accuracy: 0.8947 - precision: 0.7148 - recall: 0.2381 - f1_score: 0.3572 - val_loss: 0.2795 - val_accuracy: 0.9005 - val_precision: 0.2192 - val_recall: 0.0422 - val_f1_score: 0.0708
# Epoch 25/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.2757 - accuracy: 0.8944 - precision: 0.7090 - recall: 0.2385 - f1_score: 0.3569 - val_loss: 0.2807 - val_accuracy: 0.8974 - val_precision: 0.1860 - val_recall: 0.0422 - val_f1_score: 0.0688
# Epoch 26/30
# 664/664 [==============================] - 170s 256ms/step - loss: 0.2720 - accuracy: 0.8963 - precision: 0.7188 - recall: 0.2561 - f1_score: 0.3777 - val_loss: 0.2895 - val_accuracy: 0.8874 - val_precision: 0.1571 - val_recall: 0.0580 - val_f1_score: 0.0848
# Epoch 27/30
# 664/664 [==============================] - 177s 266ms/step - loss: 0.2710 - accuracy: 0.8969 - precision: 0.7232 - recall: 0.2613 - f1_score: 0.3839 - val_loss: 0.2834 - val_accuracy: 0.9000 - val_precision: 0.2208 - val_recall: 0.0449 - val_f1_score: 0.0746
# Epoch 28/30
# 664/664 [==============================] - 179s 270ms/step - loss: 0.2701 - accuracy: 0.8953 - precision: 0.7034 - recall: 0.2567 - f1_score: 0.3761 - val_loss: 0.2826 - val_accuracy: 0.9012 - val_precision: 0.2361 - val_recall: 0.0449 - val_f1_score: 0.0754
# Epoch 29/30
# 664/664 [==============================] - 170s 256ms/step - loss: 0.2672 - accuracy: 0.8971 - precision: 0.7159 - recall: 0.2693 - f1_score: 0.3914 - val_loss: 0.2839 - val_accuracy: 0.8953 - val_precision: 0.1753 - val_recall: 0.0449 - val_f1_score: 0.0714
# Epoch 30/30
# 664/664 [==============================] - 175s 264ms/step - loss: 0.2643 - accuracy: 0.8974 - precision: 0.7154 - recall: 0.2749 - f1_score: 0.3972 - val_loss: 0.2871 - val_accuracy: 0.8917 - val_precision: 0.2045 - val_recall: 0.0712 - val_f1_score: 0.1057

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")
plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['f1_score'], label="F1-score")
plt.plot(range(1, epochs + 1), history.history['val_f1_score'], label="val F1-score")
plt.xlabel("epochs")
plt.title("total F1-score")

plt.legend()
plt.show()

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")
plt.legend()

plt.show()
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['f1_score'], label="F1-score")
plt.plot(range(1, epochs + 1), history.history['val_f1_score'], label="val F1-score")
plt.xlabel("epochs")
plt.title("total F1-score")

plt.legend()
plt.show()
# Out:
# Epoch 1/30
# 664/664 [==============================] - 183s 275ms/step - loss: 0.2641 - accuracy: 0.8979 - precision: 0.7110 - recall: 0.2860 - f1_score: 0.4079 - val_loss: 0.2872 - val_accuracy: 0.8924 - val_precision: 0.2222 - val_recall: 0.0792 - val_f1_score: 0.1167
# Epoch 2/30
# 664/664 [==============================] - 192s 289ms/step - loss: 0.2620 - accuracy: 0.8981 - precision: 0.7150 - recall: 0.2845 - f1_score: 0.4070 - val_loss: 0.2936 - val_accuracy: 0.8936 - val_precision: 0.2308 - val_recall: 0.0792 - val_f1_score: 0.1179
# Epoch 3/30
# 664/664 [==============================] - 183s 276ms/step - loss: 0.2590 - accuracy: 0.8995 - precision: 0.7203 - recall: 0.2985 - f1_score: 0.4221 - val_loss: 0.2925 - val_accuracy: 0.8927 - val_precision: 0.2431 - val_recall: 0.0923 - val_f1_score: 0.1338
# Epoch 4/30
# 664/664 [==============================] - 187s 281ms/step - loss: 0.2572 - accuracy: 0.8996 - precision: 0.7189 - recall: 0.3008 - f1_score: 0.4241 - val_loss: 0.2898 - val_accuracy: 0.8955 - val_precision: 0.2786 - val_recall: 0.1029 - val_f1_score: 0.1503
# Epoch 5/30
# 664/664 [==============================] - 194s 292ms/step - loss: 0.2565 - accuracy: 0.8999 - precision: 0.7171 - recall: 0.3059 - f1_score: 0.4289 - val_loss: 0.2927 - val_accuracy: 0.8934 - val_precision: 0.2517 - val_recall: 0.0950 - val_f1_score: 0.1379
# Epoch 6/30
# 664/664 [==============================] - 196s 295ms/step - loss: 0.2553 - accuracy: 0.9003 - precision: 0.7176 - recall: 0.3115 - f1_score: 0.4344 - val_loss: 0.2941 - val_accuracy: 0.8953 - val_precision: 0.2439 - val_recall: 0.0792 - val_f1_score: 0.1195
# Epoch 7/30
# 664/664 [==============================] - 194s 293ms/step - loss: 0.2548 - accuracy: 0.9010 - precision: 0.7241 - recall: 0.3138 - f1_score: 0.4379 - val_loss: 0.2980 - val_accuracy: 0.8910 - val_precision: 0.2128 - val_recall: 0.0792 - val_f1_score: 0.1154
# Epoch 8/30
# 664/664 [==============================] - 186s 280ms/step - loss: 0.2525 - accuracy: 0.9016 - precision: 0.7209 - recall: 0.3251 - f1_score: 0.4481 - val_loss: 0.2987 - val_accuracy: 0.8889 - val_precision: 0.2152 - val_recall: 0.0897 - val_f1_score: 0.1266
# Epoch 9/30
# 664/664 [==============================] - 165s 248ms/step - loss: 0.2492 - accuracy: 0.9037 - precision: 0.7367 - recall: 0.3366 - f1_score: 0.4621 - val_loss: 0.2938 - val_accuracy: 0.8955 - val_precision: 0.2328 - val_recall: 0.0712 - val_f1_score: 0.1091
# Epoch 10/30
# 664/664 [==============================] - 173s 261ms/step - loss: 0.2499 - accuracy: 0.9022 - precision: 0.7240 - recall: 0.3307 - f1_score: 0.4540 - val_loss: 0.3018 - val_accuracy: 0.8927 - val_precision: 0.2394 - val_recall: 0.0897 - val_f1_score: 0.1305
# Epoch 11/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.2494 - accuracy: 0.9039 - precision: 0.7339 - recall: 0.3423 - f1_score: 0.4669 - val_loss: 0.2965 - val_accuracy: 0.8941 - val_precision: 0.2344 - val_recall: 0.0792 - val_f1_score: 0.1183
# Epoch 12/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.2475 - accuracy: 0.9028 - precision: 0.7256 - recall: 0.3358 - f1_score: 0.4591 - val_loss: 0.3074 - val_accuracy: 0.8872 - val_precision: 0.2197 - val_recall: 0.1003 - val_f1_score: 0.1377
# Epoch 13/30
# 664/664 [==============================] - 167s 252ms/step - loss: 0.2442 - accuracy: 0.9041 - precision: 0.7290 - recall: 0.3504 - f1_score: 0.4733 - val_loss: 0.3003 - val_accuracy: 0.8950 - val_precision: 0.2746 - val_recall: 0.1029 - val_f1_score: 0.1497
# Epoch 14/30
# 664/664 [==============================] - 164s 246ms/step - loss: 0.2426 - accuracy: 0.9050 - precision: 0.7307 - recall: 0.3592 - f1_score: 0.4816 - val_loss: 0.3004 - val_accuracy: 0.8957 - val_precision: 0.2707 - val_recall: 0.0950 - val_f1_score: 0.1406
# Epoch 15/30
# 664/664 [==============================] - 173s 261ms/step - loss: 0.2403 - accuracy: 0.9057 - precision: 0.7378 - recall: 0.3617 - f1_score: 0.4854 - val_loss: 0.3034 - val_accuracy: 0.8950 - val_precision: 0.2576 - val_recall: 0.0897 - val_f1_score: 0.1331
# Epoch 16/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.2377 - accuracy: 0.9071 - precision: 0.7379 - recall: 0.3782 - f1_score: 0.5001 - val_loss: 0.3108 - val_accuracy: 0.8917 - val_precision: 0.2679 - val_recall: 0.1187 - val_f1_score: 0.1645
# Epoch 17/30
# 664/664 [==============================] - 158s 239ms/step - loss: 0.2379 - accuracy: 0.9081 - precision: 0.7488 - recall: 0.3791 - f1_score: 0.5034 - val_loss: 0.3088 - val_accuracy: 0.8960 - val_precision: 0.2541 - val_recall: 0.0818 - val_f1_score: 0.1238
# Epoch 18/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.2378 - accuracy: 0.9074 - precision: 0.7392 - recall: 0.3807 - f1_score: 0.5025 - val_loss: 0.3142 - val_accuracy: 0.8896 - val_precision: 0.2486 - val_recall: 0.1135 - val_f1_score: 0.1558
# Epoch 19/30
# 664/664 [==============================] - 162s 243ms/step - loss: 0.2347 - accuracy: 0.9079 - precision: 0.7396 - recall: 0.3868 - f1_score: 0.5079 - val_loss: 0.3134 - val_accuracy: 0.8941 - val_precision: 0.2976 - val_recall: 0.1319 - val_f1_score: 0.1828
# Epoch 20/30
# 664/664 [==============================] - 163s 245ms/step - loss: 0.2318 - accuracy: 0.9101 - precision: 0.7524 - recall: 0.4000 - f1_score: 0.5223 - val_loss: 0.3208 - val_accuracy: 0.8877 - val_precision: 0.2050 - val_recall: 0.0871 - val_f1_score: 0.1222
# Epoch 21/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.2323 - accuracy: 0.9109 - precision: 0.7655 - recall: 0.3971 - f1_score: 0.5230 - val_loss: 0.3214 - val_accuracy: 0.8964 - val_precision: 0.2986 - val_recall: 0.1135 - val_f1_score: 0.1644
# Epoch 22/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.2305 - accuracy: 0.9102 - precision: 0.7528 - recall: 0.4008 - f1_score: 0.5231 - val_loss: 0.3159 - val_accuracy: 0.8955 - val_precision: 0.2987 - val_recall: 0.1214 - val_f1_score: 0.1726
# Epoch 23/30
# 664/664 [==============================] - 161s 243ms/step - loss: 0.2286 - accuracy: 0.9105 - precision: 0.7488 - recall: 0.4088 - f1_score: 0.5289 - val_loss: 0.3193 - val_accuracy: 0.8886 - val_precision: 0.2370 - val_recall: 0.1082 - val_f1_score: 0.1486
# Epoch 24/30
# 664/664 [==============================] - 163s 246ms/step - loss: 0.2282 - accuracy: 0.9110 - precision: 0.7539 - recall: 0.4096 - f1_score: 0.5308 - val_loss: 0.3207 - val_accuracy: 0.8853 - val_precision: 0.2034 - val_recall: 0.0950 - val_f1_score: 0.1295
# Epoch 25/30
# 664/664 [==============================] - 162s 244ms/step - loss: 0.2250 - accuracy: 0.9128 - precision: 0.7608 - recall: 0.4236 - f1_score: 0.5442 - val_loss: 0.3275 - val_accuracy: 0.8829 - val_precision: 0.2051 - val_recall: 0.1055 - val_f1_score: 0.1394
# Epoch 26/30
# 664/664 [==============================] - 160s 241ms/step - loss: 0.2245 - accuracy: 0.9109 - precision: 0.7417 - recall: 0.4218 - f1_score: 0.5378 - val_loss: 0.3272 - val_accuracy: 0.8898 - val_precision: 0.2244 - val_recall: 0.0923 - val_f1_score: 0.1308
# Epoch 27/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.2239 - accuracy: 0.9133 - precision: 0.7623 - recall: 0.4282 - f1_score: 0.5483 - val_loss: 0.3218 - val_accuracy: 0.8927 - val_precision: 0.2394 - val_recall: 0.0897 - val_f1_score: 0.1305
# Epoch 28/30
# 664/664 [==============================] - 158s 239ms/step - loss: 0.2221 - accuracy: 0.9140 - precision: 0.7680 - recall: 0.4301 - f1_score: 0.5514 - val_loss: 0.3250 - val_accuracy: 0.8934 - val_precision: 0.2710 - val_recall: 0.1108 - val_f1_score: 0.1573
# Epoch 29/30
# 664/664 [==============================] - 155s 233ms/step - loss: 0.2189 - accuracy: 0.9144 - precision: 0.7606 - recall: 0.4425 - f1_score: 0.5595 - val_loss: 0.3206 - val_accuracy: 0.8867 - val_precision: 0.2513 - val_recall: 0.1319 - val_f1_score: 0.1730
# Epoch 30/30
# 664/664 [==============================] - 160s 241ms/step - loss: 0.2183 - accuracy: 0.9145 - precision: 0.7572 - recall: 0.4481 - f1_score: 0.5630 - val_loss: 0.3216 - val_accuracy: 0.8953 - val_precision: 0.3136 - val_recall: 0.1398 - val_f1_score: 0.1934

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])
# Out:
# Epoch 1/30
# 664/664 [==============================] - 156s 234ms/step - loss: 0.2162 - accuracy: 0.9154 - precision: 0.7612 - recall: 0.4542 - f1_score: 0.5689 - val_loss: 0.3298 - val_accuracy: 0.8886 - val_precision: 0.2618 - val_recall: 0.1319 - val_f1_score: 0.1754
# Epoch 2/30
# 664/664 [==============================] - 165s 249ms/step - loss: 0.2178 - accuracy: 0.9144 - precision: 0.7593 - recall: 0.4441 - f1_score: 0.5604 - val_loss: 0.3284 - val_accuracy: 0.8943 - val_precision: 0.2781 - val_recall: 0.1108 - val_f1_score: 0.1585
# Epoch 3/30
# 664/664 [==============================] - 161s 242ms/step - loss: 0.2150 - accuracy: 0.9151 - precision: 0.7579 - recall: 0.4546 - f1_score: 0.5683 - val_loss: 0.3386 - val_accuracy: 0.8855 - val_precision: 0.2234 - val_recall: 0.1108 - val_f1_score: 0.1481
# Epoch 4/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.2129 - accuracy: 0.9164 - precision: 0.7653 - recall: 0.4611 - f1_score: 0.5755 - val_loss: 0.3408 - val_accuracy: 0.8889 - val_precision: 0.2414 - val_recall: 0.1108 - val_f1_score: 0.1519
# Epoch 5/30
# 664/664 [==============================] - 157s 237ms/step - loss: 0.2099 - accuracy: 0.9182 - precision: 0.7755 - recall: 0.4711 - f1_score: 0.5861 - val_loss: 0.3401 - val_accuracy: 0.8917 - val_precision: 0.2809 - val_recall: 0.1319 - val_f1_score: 0.1795
# Epoch 6/30
# 664/664 [==============================] - 156s 235ms/step - loss: 0.2098 - accuracy: 0.9185 - precision: 0.7753 - recall: 0.4745 - f1_score: 0.5887 - val_loss: 0.3435 - val_accuracy: 0.8924 - val_precision: 0.2671 - val_recall: 0.1135 - val_f1_score: 0.1593
# Epoch 7/30
# 664/664 [==============================] - 156s 235ms/step - loss: 0.2110 - accuracy: 0.9174 - precision: 0.7680 - recall: 0.4693 - f1_score: 0.5826 - val_loss: 0.3415 - val_accuracy: 0.8893 - val_precision: 0.2381 - val_recall: 0.1055 - val_f1_score: 0.1463
# Epoch 8/30
# 664/664 [==============================] - 155s 234ms/step - loss: 0.2073 - accuracy: 0.9185 - precision: 0.7723 - recall: 0.4776 - f1_score: 0.5902 - val_loss: 0.3448 - val_accuracy: 0.8853 - val_precision: 0.2251 - val_recall: 0.1135 - val_f1_score: 0.1509
# Epoch 9/30
# 428/664 [==================>...........] - ETA: 52s - loss: 0.2077 - accuracy: 0.9184 - precision: 0.7710 - recall: 0.4884 - f1_score: 0.5980

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")
plt.legend()

plt.show()
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()
plt.plot(range(1, epochs + 1), history.history['f1_score'], label="F1-score")
plt.plot(range(1, epochs + 1), history.history['val_f1_score'], label="val F1-score")
plt.xlabel("epochs")
plt.title("total F1-score")

plt.legend()
plt.show()

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 90 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 6s 70ms/step
# 664/664 [==============================] - 48s 72ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8291469194312796
# Train accuracy: 0.9255221455650003

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.859478672985782
# Train accuracy: 0.9420518495844027

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8739336492890996
# Train accuracy: 0.9438178436035697

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8872037914691943
# Train accuracy: 0.9383550354376133

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights('./fine_models/model_ri_best_f1_only_reducable.h5')

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 5s 51ms/step
# 664/664 [==============================] - 34s 51ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8203791469194313
# Train accuracy: 0.9093927335232758

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8535545023696682
# Train accuracy: 0.9328686806847347

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.8734597156398104
# Train accuracy: 0.9396500977183357

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.888388625592417
# Train accuracy: 0.9396265511314135
