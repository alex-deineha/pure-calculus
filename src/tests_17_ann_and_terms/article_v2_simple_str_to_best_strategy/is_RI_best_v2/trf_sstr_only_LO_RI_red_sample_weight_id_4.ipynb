# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *
# Out:
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\voldo\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 30

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_test = all_data["RI_steps_num"].tolist()
y_lo_test = all_data["LO_steps_num"].tolist()

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# number samples: 4251
# number samples only reducable: 4220
#
# max RI steps count: 386
# max LO steps count: 219
# Count TESTING samples: 4220

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

# drop unreducable by LO or RI
print(f"number samples: {len(all_data)}")
all_data = all_data[[x_ != 1000 for x_ in all_data["RI_steps_num"]]].reset_index(drop=True)
all_data = all_data[[x_ != 1000 for x_ in all_data["LO_steps_num"]]].reset_index(drop=True)
print(f"number samples only reducable: {len(all_data)}\n")

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]
y_ri_train = all_data["RI_steps_num"].tolist()
y_lo_train = all_data["LO_steps_num"].tolist()

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# number samples: 44568
# number samples only reducable: 42469
#
# max RI steps count: 400
# max LO steps count: 308
# Count TRAINING samples: 42469

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_sample_weight(ri_steps, lo_steps):
    if ri_steps > lo_steps:
        return (abs(ri_steps - lo_steps) / (max(ri_steps, lo_steps))) + 0.5
    else:
        return 0.001


x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({
    "term_str": x_train, "is_ri_best": y_train,
    "lo_steps": y_lo_train, "ri_steps": y_ri_train,
    "sample_weights": [get_sample_weight(ri_, lo_) for ri_, lo_ in zip(y_ri_train, y_lo_train)],
})
test_df = pd.DataFrame({
    "term_str": x_test, "is_ri_best": y_test,
    "lo_steps": y_lo_test, "ri_steps": y_ri_test,
    "sample_weights": [get_sample_weight(ri_, lo_)  for ri_, lo_ in zip(y_ri_test, y_lo_test)],
})

# %%
train_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y((x(y((x(y((x((x((xx)(y(((xx)(((yx)(x((yx)...           0         3
# 1  ((((((((y(y(yx)))(y(yx)))(((yx)(y(y((x(y(y(y(y...           0        60
# 2  (y(y(x(((((y(yx))(yx))((y(y(yx)))(y(y(xx)))))(...           0         5
# 3  (y(((x((xx)(x(x(xx)))))((x((x(yx))(xx)))((y(x(...           1         7
# 4  (y((x(y((((x(x(y(y(x((xx)x))))))(x(((y(x((x((y...           0         2
# 5  (y(y(((((((x(x(y(yx))))(x(x(y(x(x(y(yx))))))))...           0        20
# 6  ((y(y(y((y(y((yx)x)))(x(((yx)(yx))((((y(yx))(y...           0         3
# 7  ((y((((y(xx))(y((yx)(y(x(y(yx)))))))(y((y(x((y...           0        11
# 8  (y(((y(yx))(y(y(x((y(x((y(yx))(y(y(y(xx)))))))...           0        10
# 9                 (y(y(y(((y((yx)x))(yx))(y(yx))))))           0         3
#
#    ri_steps  sample_weights
# 0         3        0.001000
# 1       187        1.179144
# 2         8        0.875000
# 3         4        0.001000
# 4         2        0.001000
# 5        78        1.243590
# 6         8        1.125000
# 7        31        1.145161
# 8        16        0.875000
# 9         3        0.001000

# %%
test_df.head(10)
# Out:
#                                             term_str  is_ri_best  lo_steps  \
# 0  (y(y(x(y((x(x(((x(y((xx)(x(y(yx))))))x)(y(y(xx...           0         0
# 1  (((((((y(y(yx)))(y(y(xx))))((y(((y(y(yx)))(y(y...           0        28
# 2  (y(y(y(((x(yx))(yx))((x(y((yx)(y(x((((yx)(((xx...           0         1
# 3  (y((((((((y(y(x(xx))))(y(y(y(y(xx))))))(((y(y(...           0        58
# 4  (y(y(((xx)(y(y(y((x((((yx)(yx))(((yx)(yx))(((y...           0         8
# 5  ((((yx)(y((y(y((xx)(y((yx)x)))))((yx)(y((yx)(x...           0        10
# 6  (y(x(y(y(y(y(x((y(y((yx)(y(y(xx))))))(y(y(((y(...           0         4
# 7  (((((((((yx)(y(xx)))(yx))(((yx)(y(xx)))(yx)))(...           0        84
# 8  (y(((x(yx))(y((xx)((x((((x(xx))(xx))x)(y(y((xx...           0         1
# 9                 (y(y(y(y(y(x(y((y(y(xx)))x))))))))           0         1
#
#    ri_steps  sample_weights
# 0         0        0.001000
# 1        47        0.904255
# 2         2        1.000000
# 3        75        0.726667
# 4         8        0.001000
# 5        23        1.065217
# 6         5        0.700000
# 7        91        0.576923
# 8         1        0.001000
# 9         1        0.001000

# %%
def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    sample_weights = tf.convert_to_tensor(example["sample_weights"])
    return tokenized_texts, labels, sample_weights


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1], tokenized_train_data[2])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define & Train the Model

# %%
# Define the model
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tfa.metrics.F1Score(num_classes=1, threshold=0.5)])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model_structure = model.to_json()
# with open("./fine_models/model_ri.json", 'w') as json_file:
#     json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
f1_callback = ModelCheckpoint(
    filepath='./fine_models/model_ri_best_f1_red_weighted_v3.h5',  # Specify the path to save the best model
    monitor='val_f1_score',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

step_callback = ModelCheckpoint('./fine_models/model_ri_red_weighted_v3.h5', save_weights_only=True, save_freq=1)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="ri_best_logs/id_4", histogram_freq=1)

# %%
def draw_training_statistic(history_):
    plt.plot(range(1, epochs + 1), history_.history['loss'], label="loss")
    plt.plot(range(1, epochs + 1), history_.history['val_loss'], label="val_loss")
    plt.xlabel("epochs")
    plt.title("total loss")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['accuracy'], label="accuracy")
    plt.plot(range(1, epochs + 1), history_.history['val_accuracy'], label="val_accuracy")
    plt.xlabel("epochs")
    plt.title("total accuracy")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['precision'], label="precision")
    plt.plot(range(1, epochs + 1), history_.history['val_precision'], label="val_precision")
    plt.xlabel("epochs")
    plt.title("total precision")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['recall'], label="recall")
    plt.plot(range(1, epochs + 1), history_.history['val_recall'], label="val_recall")
    plt.xlabel("epochs")
    plt.title("total recall")
    plt.legend()
    plt.show()

    plt.plot(range(1, epochs + 1), history_.history['f1_score'], label="F1-score")
    plt.plot(range(1, epochs + 1), history_.history['val_f1_score'], label="val F1-score")
    plt.xlabel("epochs")
    plt.title("total F1-score")
    plt.legend()
    plt.show()

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 664/664 [==============================] - 176s 258ms/step - loss: 0.0016 - accuracy: 0.8770 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7699 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7397 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/30
# 664/664 [==============================] - 167s 252ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7843 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 4/30
# 664/664 [==============================] - 162s 245ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 1.0000 - recall: 1.9157e-04 - f1_score: 3.8307e-04 - val_loss: 0.7707 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 5/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7444 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 6/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0011 - accuracy: 0.8774 - precision: 1.0000 - recall: 0.0025 - f1_score: 0.0050 - val_loss: 0.7381 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 7/30
# 664/664 [==============================] - 167s 251ms/step - loss: 0.0011 - accuracy: 0.8781 - precision: 1.0000 - recall: 0.0079 - f1_score: 0.0156 - val_loss: 0.8028 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 8/30
# 664/664 [==============================] - 166s 249ms/step - loss: 0.0011 - accuracy: 0.8778 - precision: 0.8605 - recall: 0.0071 - f1_score: 0.0141 - val_loss: 0.7427 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 9/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0011 - accuracy: 0.8785 - precision: 0.9265 - recall: 0.0121 - f1_score: 0.0238 - val_loss: 0.7810 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 10/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0011 - accuracy: 0.8781 - precision: 0.9592 - recall: 0.0090 - f1_score: 0.0178 - val_loss: 0.7901 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 11/30
# 664/664 [==============================] - 168s 252ms/step - loss: 0.0011 - accuracy: 0.8780 - precision: 1.0000 - recall: 0.0071 - f1_score: 0.0141 - val_loss: 0.7686 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 12/30
# 664/664 [==============================] - 169s 254ms/step - loss: 0.0011 - accuracy: 0.8811 - precision: 0.9424 - recall: 0.0345 - f1_score: 0.0665 - val_loss: 0.7382 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 13/30
# 664/664 [==============================] - 163s 246ms/step - loss: 0.0011 - accuracy: 0.8773 - precision: 1.0000 - recall: 0.0015 - f1_score: 0.0031 - val_loss: 0.7408 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 14/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8784 - precision: 0.9831 - recall: 0.0111 - f1_score: 0.0220 - val_loss: 0.7447 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 15/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8777 - precision: 1.0000 - recall: 0.0054 - f1_score: 0.0107 - val_loss: 0.8107 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 16/30
# 664/664 [==============================] - 154s 232ms/step - loss: 0.0011 - accuracy: 0.8787 - precision: 0.9136 - recall: 0.0142 - f1_score: 0.0279 - val_loss: 0.7687 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 17/30
# 664/664 [==============================] - 158s 239ms/step - loss: 0.0011 - accuracy: 0.8794 - precision: 0.9626 - recall: 0.0197 - f1_score: 0.0387 - val_loss: 0.7876 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 18/30
# 664/664 [==============================] - 162s 243ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7833 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 19/30
# 664/664 [==============================] - 161s 243ms/step - loss: 0.0011 - accuracy: 0.8779 - precision: 0.9730 - recall: 0.0069 - f1_score: 0.0137 - val_loss: 0.8044 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 20/30
# 664/664 [==============================] - 161s 243ms/step - loss: 0.0011 - accuracy: 0.8795 - precision: 0.9474 - recall: 0.0207 - f1_score: 0.0405 - val_loss: 0.7749 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 21/30
# 664/664 [==============================] - 162s 243ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7919 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 22/30
# 664/664 [==============================] - 159s 240ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8014 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 23/30
# 664/664 [==============================] - 155s 233ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7830 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 24/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.0011 - accuracy: 0.8773 - precision: 1.0000 - recall: 0.0015 - f1_score: 0.0031 - val_loss: 0.7924 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 25/30
# 664/664 [==============================] - 174s 262ms/step - loss: 0.0011 - accuracy: 0.8776 - precision: 1.0000 - recall: 0.0044 - f1_score: 0.0088 - val_loss: 0.7914 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 26/30
# 664/664 [==============================] - 170s 257ms/step - loss: 0.0011 - accuracy: 0.8805 - precision: 0.9500 - recall: 0.0291 - f1_score: 0.0565 - val_loss: 0.7943 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 27/30
# 664/664 [==============================] - 162s 245ms/step - loss: 0.0011 - accuracy: 0.8825 - precision: 0.9494 - recall: 0.0467 - f1_score: 0.0891 - val_loss: 0.8003 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 28/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.0011 - accuracy: 0.8816 - precision: 0.9398 - recall: 0.0389 - f1_score: 0.0747 - val_loss: 0.7986 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 29/30
# 664/664 [==============================] - 168s 253ms/step - loss: 0.0011 - accuracy: 0.8802 - precision: 0.9459 - recall: 0.0268 - f1_score: 0.0522 - val_loss: 0.8026 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 30/30
# 664/664 [==============================] - 166s 250ms/step - loss: 0.0011 - accuracy: 0.8780 - precision: 0.9756 - recall: 0.0077 - f1_score: 0.0152 - val_loss: 0.7766 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 164s 247ms/step - loss: 0.0011 - accuracy: 0.8810 - precision: 0.9563 - recall: 0.0335 - f1_score: 0.0648 - val_loss: 0.7980 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 156s 234ms/step - loss: 0.0011 - accuracy: 0.8777 - precision: 0.9655 - recall: 0.0054 - f1_score: 0.0107 - val_loss: 0.7940 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/30
# 664/664 [==============================] - 220s 331ms/step - loss: 0.0011 - accuracy: 0.8785 - precision: 0.9296 - recall: 0.0126 - f1_score: 0.0249 - val_loss: 0.8018 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 4/30
# 664/664 [==============================] - 157s 236ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7903 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 5/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7973 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 6/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0012 - accuracy: 0.8771 - precision: 0.5000 - recall: 1.9157e-04 - f1_score: 3.8300e-04 - val_loss: 0.7971 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 7/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8201 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 8/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8144 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 9/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7935 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 10/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8021 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 11/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8783 - precision: 0.9483 - recall: 0.0105 - f1_score: 0.0208 - val_loss: 0.7854 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 12/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8774 - precision: 1.0000 - recall: 0.0029 - f1_score: 0.0057 - val_loss: 0.8143 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 13/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8797 - precision: 0.9302 - recall: 0.0230 - f1_score: 0.0449 - val_loss: 0.7882 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 14/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8796 - precision: 0.9219 - recall: 0.0226 - f1_score: 0.0441 - val_loss: 0.8037 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 15/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0012 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7959 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 16/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7914 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 17/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8785 - precision: 0.9836 - recall: 0.0115 - f1_score: 0.0227 - val_loss: 0.8946 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 18/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7516 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 19/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8773 - precision: 0.8889 - recall: 0.0015 - f1_score: 0.0031 - val_loss: 0.7851 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 20/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7771 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 21/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8065 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 22/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7986 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 23/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8243 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 24/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0012 - accuracy: 0.8772 - precision: 0.8000 - recall: 7.6628e-04 - f1_score: 0.0015 - val_loss: 0.7870 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 25/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7803 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 26/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7886 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 27/30
# 664/664 [==============================] - 154s 232ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7879 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 28/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8776 - precision: 0.9167 - recall: 0.0042 - f1_score: 0.0084 - val_loss: 0.7811 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 29/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7960 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 30/30
# 664/664 [==============================] - 152s 229ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7967 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00

# %%
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[f1_callback, step_callback, tensorboard_callback])

draw_training_statistic(history)
# Out:
# Epoch 1/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7981 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7887 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7897 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 4/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8161 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 5/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8111 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 6/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8184 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 7/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.6667 - recall: 3.8314e-04 - f1_score: 7.6584e-04 - val_loss: 0.8227 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 8/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8774 - precision: 0.8750 - recall: 0.0027 - f1_score: 0.0053 - val_loss: 0.7954 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 9/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8147 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 10/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7997 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 11/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8113 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 12/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7808 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 13/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8774 - precision: 0.9412 - recall: 0.0031 - f1_score: 0.0061 - val_loss: 0.8022 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 14/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8788 - precision: 0.9610 - recall: 0.0142 - f1_score: 0.0279 - val_loss: 0.8361 - val_accuracy: 0.9100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 15/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8781 - precision: 0.9184 - recall: 0.0086 - f1_score: 0.0171 - val_loss: 0.7773 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 16/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7853 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 17/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8786 - precision: 0.9851 - recall: 0.0126 - f1_score: 0.0250 - val_loss: 0.7776 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 18/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8778 - precision: 0.8919 - recall: 0.0063 - f1_score: 0.0126 - val_loss: 0.8010 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 19/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7807 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 20/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7878 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 21/30
# 664/664 [==============================] - 152s 230ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 1.0000 - recall: 1.9157e-04 - f1_score: 3.8307e-04 - val_loss: 0.8056 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 22/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8775 - precision: 0.9048 - recall: 0.0036 - f1_score: 0.0073 - val_loss: 0.8178 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 23/30
# 664/664 [==============================] - 153s 230ms/step - loss: 0.0011 - accuracy: 0.8782 - precision: 0.8966 - recall: 0.0100 - f1_score: 0.0197 - val_loss: 0.7966 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 24/30
# 664/664 [==============================] - 155s 233ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7777 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 25/30
# 664/664 [==============================] - 171s 257ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7902 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 26/30
# 664/664 [==============================] - 184s 277ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7924 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 27/30
# 664/664 [==============================] - 186s 280ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8007 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 28/30
# 664/664 [==============================] - 177s 266ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.8174 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 29/30
# 664/664 [==============================] - 168s 252ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 1.0000 - recall: 1.9157e-04 - f1_score: 3.8307e-04 - val_loss: 0.7911 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 30/30
# 664/664 [==============================] - 165s 248ms/step - loss: 0.0011 - accuracy: 0.8771 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.7998 - val_accuracy: 0.9102 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # TRAINED MODEL (after 90 epochs)

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 5s 72ms/step
# 664/664 [==============================] - 59s 88ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8805717111304716

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8803126986743272

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8802420589135604

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8770868162659823

# %% [markdown]
# # Best validation F1-score model

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/model_ri.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights('./fine_models/model_ri_best_f1_red_weighted_v3.h5')

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 66/66 [==============================] - 6s 71ms/step
# 664/664 [==============================] - 48s 72ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8770868162659823

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8770868162659823

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8770868162659823

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True,
                      title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.9101895734597156
# Train accuracy: 0.8770868162659823
