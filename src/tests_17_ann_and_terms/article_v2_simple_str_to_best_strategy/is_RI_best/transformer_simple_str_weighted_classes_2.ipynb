# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 40

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# max RI steps count: 1000
# max LO steps count: 219
# Count TESTING samples: 4251

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los > ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# max RI steps count: 1000
# max LO steps count: 1000
# Count TRAINING samples: 44568

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "is_ri_best": y_train})
test_df = pd.DataFrame({"term_str": x_test, "is_ri_best": y_test})

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define the model

# %%
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy', tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_structure = model.to_json()
with open("./fine_models/transformer_model_ext_weighted_classes_v2.json", 'w') as json_file:
    json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath='./fine_models/transformer_model_ext_weighted_classes_v2.h5',  # Specify the path to save the best model
    monitor='val_accuracy',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

# %%
class_weights = {
    0: 0.1,
    1: 0.9,
}
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1, callbacks=[checkpoint_callback], class_weight=class_weights)
# Out:
# Epoch 1/40
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 697/697 [==============================] - 147s 203ms/step - loss: 0.1279 - accuracy: 0.5328 - precision: 0.1608 - recall: 0.7062 - val_loss: 0.8658 - val_accuracy: 0.3423 - val_precision: 0.1145 - val_recall: 0.9472
# Epoch 2/40
# 697/697 [==============================] - 143s 206ms/step - loss: 0.1216 - accuracy: 0.5571 - precision: 0.1767 - recall: 0.7578 - val_loss: 0.7064 - val_accuracy: 0.5427 - val_precision: 0.1435 - val_recall: 0.8311
# Epoch 3/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1181 - accuracy: 0.5708 - precision: 0.1845 - recall: 0.7768 - val_loss: 0.6500 - val_accuracy: 0.5726 - val_precision: 0.1500 - val_recall: 0.8127
# Epoch 4/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1168 - accuracy: 0.5766 - precision: 0.1874 - recall: 0.7810 - val_loss: 0.6681 - val_accuracy: 0.5660 - val_precision: 0.1493 - val_recall: 0.8232
# Epoch 5/40
# 697/697 [==============================] - 143s 206ms/step - loss: 0.1162 - accuracy: 0.5817 - precision: 0.1899 - recall: 0.7850 - val_loss: 0.6437 - val_accuracy: 0.5761 - val_precision: 0.1497 - val_recall: 0.8021
# Epoch 6/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1155 - accuracy: 0.5862 - precision: 0.1924 - recall: 0.7894 - val_loss: 0.6794 - val_accuracy: 0.5679 - val_precision: 0.1475 - val_recall: 0.8047
# Epoch 7/40
# 697/697 [==============================] - 143s 205ms/step - loss: 0.1152 - accuracy: 0.5874 - precision: 0.1927 - recall: 0.7882 - val_loss: 0.6639 - val_accuracy: 0.5817 - val_precision: 0.1511 - val_recall: 0.7995
# Epoch 8/40
# 697/697 [==============================] - 147s 212ms/step - loss: 0.1143 - accuracy: 0.5972 - precision: 0.1963 - recall: 0.7857 - val_loss: 0.6723 - val_accuracy: 0.5799 - val_precision: 0.1495 - val_recall: 0.7916
# Epoch 9/40
# 697/697 [==============================] - 145s 208ms/step - loss: 0.1136 - accuracy: 0.6034 - precision: 0.1987 - recall: 0.7842 - val_loss: 0.6387 - val_accuracy: 0.6001 - val_precision: 0.1507 - val_recall: 0.7520
# Epoch 10/40
# 697/697 [==============================] - 146s 209ms/step - loss: 0.1130 - accuracy: 0.6066 - precision: 0.1995 - recall: 0.7806 - val_loss: 0.6179 - val_accuracy: 0.6257 - val_precision: 0.1584 - val_recall: 0.7414
# Epoch 11/40
# 697/697 [==============================] - 146s 209ms/step - loss: 0.1118 - accuracy: 0.6185 - precision: 0.2050 - recall: 0.7815 - val_loss: 0.6265 - val_accuracy: 0.6316 - val_precision: 0.1551 - val_recall: 0.7045
# Epoch 12/40
# 697/697 [==============================] - 146s 209ms/step - loss: 0.1114 - accuracy: 0.6244 - precision: 0.2081 - recall: 0.7840 - val_loss: 0.6098 - val_accuracy: 0.6528 - val_precision: 0.1653 - val_recall: 0.7150
# Epoch 13/40
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1103 - accuracy: 0.6329 - precision: 0.2120 - recall: 0.7831 - val_loss: 0.5759 - val_accuracy: 0.6697 - val_precision: 0.1721 - val_recall: 0.7098
# Epoch 14/40
# 697/697 [==============================] - 150s 216ms/step - loss: 0.1094 - accuracy: 0.6355 - precision: 0.2140 - recall: 0.7877 - val_loss: 0.6317 - val_accuracy: 0.6330 - val_precision: 0.1549 - val_recall: 0.6992
# Epoch 15/40
# 697/697 [==============================] - 145s 207ms/step - loss: 0.1079 - accuracy: 0.6446 - precision: 0.2187 - recall: 0.7878 - val_loss: 0.6254 - val_accuracy: 0.6415 - val_precision: 0.1590 - val_recall: 0.7045
# Epoch 16/40
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1072 - accuracy: 0.6470 - precision: 0.2207 - recall: 0.7928 - val_loss: 0.6006 - val_accuracy: 0.6584 - val_precision: 0.1611 - val_recall: 0.6728
# Epoch 17/40
# 697/697 [==============================] - 151s 217ms/step - loss: 0.1060 - accuracy: 0.6519 - precision: 0.2235 - recall: 0.7940 - val_loss: 0.6157 - val_accuracy: 0.6403 - val_precision: 0.1577 - val_recall: 0.6992
# Epoch 18/40
# 697/697 [==============================] - 150s 215ms/step - loss: 0.1055 - accuracy: 0.6575 - precision: 0.2267 - recall: 0.7957 - val_loss: 0.6057 - val_accuracy: 0.6528 - val_precision: 0.1587 - val_recall: 0.6728
# Epoch 19/40
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1046 - accuracy: 0.6611 - precision: 0.2300 - recall: 0.8033 - val_loss: 0.5848 - val_accuracy: 0.6728 - val_precision: 0.1675 - val_recall: 0.6728
# Epoch 20/40
# 697/697 [==============================] - 148s 212ms/step - loss: 0.1039 - accuracy: 0.6655 - precision: 0.2312 - recall: 0.7953 - val_loss: 0.5676 - val_accuracy: 0.6972 - val_precision: 0.1748 - val_recall: 0.6438
# Epoch 21/40
# 697/697 [==============================] - 149s 214ms/step - loss: 0.1034 - accuracy: 0.6672 - precision: 0.2335 - recall: 0.8039 - val_loss: 0.5808 - val_accuracy: 0.6737 - val_precision: 0.1649 - val_recall: 0.6544
# Epoch 22/40
# 697/697 [==============================] - 146s 209ms/step - loss: 0.1028 - accuracy: 0.6680 - precision: 0.2337 - recall: 0.8024 - val_loss: 0.5846 - val_accuracy: 0.6820 - val_precision: 0.1702 - val_recall: 0.6623
# Epoch 23/40
# 697/697 [==============================] - 142s 203ms/step - loss: 0.1023 - accuracy: 0.6750 - precision: 0.2380 - recall: 0.8033 - val_loss: 0.5966 - val_accuracy: 0.6596 - val_precision: 0.1603 - val_recall: 0.6649
# Epoch 24/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1009 - accuracy: 0.6787 - precision: 0.2406 - recall: 0.8052 - val_loss: 0.5793 - val_accuracy: 0.6791 - val_precision: 0.1634 - val_recall: 0.6306
# Epoch 25/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1009 - accuracy: 0.6805 - precision: 0.2421 - recall: 0.8081 - val_loss: 0.5520 - val_accuracy: 0.6975 - val_precision: 0.1768 - val_recall: 0.6544
# Epoch 26/40
# 697/697 [==============================] - 141s 202ms/step - loss: 0.1011 - accuracy: 0.6790 - precision: 0.2410 - recall: 0.8073 - val_loss: 0.5671 - val_accuracy: 0.7008 - val_precision: 0.1743 - val_recall: 0.6306
# Epoch 27/40
# 697/697 [==============================] - 138s 199ms/step - loss: 0.1003 - accuracy: 0.6831 - precision: 0.2435 - recall: 0.8068 - val_loss: 0.5601 - val_accuracy: 0.6883 - val_precision: 0.1702 - val_recall: 0.6438
# Epoch 28/40
# 697/697 [==============================] - 138s 198ms/step - loss: 0.0987 - accuracy: 0.6893 - precision: 0.2479 - recall: 0.8098 - val_loss: 0.5581 - val_accuracy: 0.6951 - val_precision: 0.1616 - val_recall: 0.5778
# Epoch 29/40
# 697/697 [==============================] - 137s 197ms/step - loss: 0.0980 - accuracy: 0.6890 - precision: 0.2487 - recall: 0.8157 - val_loss: 0.5359 - val_accuracy: 0.7088 - val_precision: 0.1744 - val_recall: 0.6069
# Epoch 30/40
# 697/697 [==============================] - 137s 196ms/step - loss: 0.0981 - accuracy: 0.6909 - precision: 0.2485 - recall: 0.8066 - val_loss: 0.5796 - val_accuracy: 0.6860 - val_precision: 0.1657 - val_recall: 0.6253
# Epoch 31/40
# 697/697 [==============================] - 137s 197ms/step - loss: 0.0973 - accuracy: 0.6965 - precision: 0.2540 - recall: 0.8182 - val_loss: 0.5502 - val_accuracy: 0.7092 - val_precision: 0.1706 - val_recall: 0.5858
# Epoch 32/40
# 697/697 [==============================] - 137s 197ms/step - loss: 0.0969 - accuracy: 0.6966 - precision: 0.2533 - recall: 0.8136 - val_loss: 0.5958 - val_accuracy: 0.6758 - val_precision: 0.1600 - val_recall: 0.6201
# Epoch 33/40
# 697/697 [==============================] - 137s 196ms/step - loss: 0.0958 - accuracy: 0.6997 - precision: 0.2559 - recall: 0.8165 - val_loss: 0.5444 - val_accuracy: 0.7057 - val_precision: 0.1636 - val_recall: 0.5594
# Epoch 34/40
# 697/697 [==============================] - 138s 198ms/step - loss: 0.0953 - accuracy: 0.7032 - precision: 0.2581 - recall: 0.8154 - val_loss: 0.5641 - val_accuracy: 0.7038 - val_precision: 0.1741 - val_recall: 0.6201
# Epoch 35/40
# 697/697 [==============================] - 150s 216ms/step - loss: 0.0941 - accuracy: 0.7071 - precision: 0.2612 - recall: 0.8173 - val_loss: 0.5444 - val_accuracy: 0.7109 - val_precision: 0.1685 - val_recall: 0.5699
# Epoch 36/40
# 697/697 [==============================] - 159s 228ms/step - loss: 0.0943 - accuracy: 0.7083 - precision: 0.2626 - recall: 0.8215 - val_loss: 0.5909 - val_accuracy: 0.6914 - val_precision: 0.1689 - val_recall: 0.6280
# Epoch 37/40
# 697/697 [==============================] - 151s 216ms/step - loss: 0.0934 - accuracy: 0.7106 - precision: 0.2641 - recall: 0.8200 - val_loss: 0.5877 - val_accuracy: 0.6803 - val_precision: 0.1625 - val_recall: 0.6227
# Epoch 38/40
# 697/697 [==============================] - 141s 203ms/step - loss: 0.0933 - accuracy: 0.7126 - precision: 0.2654 - recall: 0.8194 - val_loss: 0.5775 - val_accuracy: 0.6871 - val_precision: 0.1663 - val_recall: 0.6253
# Epoch 39/40
# 697/697 [==============================] - 142s 203ms/step - loss: 0.0926 - accuracy: 0.7123 - precision: 0.2660 - recall: 0.8249 - val_loss: 0.5476 - val_accuracy: 0.7102 - val_precision: 0.1712 - val_recall: 0.5858
# Epoch 40/40
# 697/697 [==============================] - 142s 203ms/step - loss: 0.0923 - accuracy: 0.7151 - precision: 0.2685 - recall: 0.8272 - val_loss: 0.6023 - val_accuracy: 0.6794 - val_precision: 0.1746 - val_recall: 0.6966

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy', tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall()])

# %%
class_weights = {
    0: 0.1,
    1: 0.9,
}
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1,
                    callbacks=[checkpoint_callback], class_weight=class_weights)
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()

plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()
# Out:
# Epoch 1/40
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_1/bert/pooler/dense/kernel:0', 'tf_bert_model_1/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model_1/bert/pooler/dense/kernel:0', 'tf_bert_model_1/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 697/697 [==============================] - 118s 162ms/step - loss: 0.0939 - accuracy: 0.7110 - precision_1: 0.2653 - recall_1: 0.8261 - val_loss: 0.5803 - val_accuracy: 0.6907 - val_precision_1: 0.1676 - val_recall_1: 0.6227
# Epoch 2/40
# 697/697 [==============================] - 112s 161ms/step - loss: 0.0935 - accuracy: 0.7107 - precision_1: 0.2641 - recall_1: 0.8196 - val_loss: 0.6239 - val_accuracy: 0.6603 - val_precision_1: 0.1606 - val_recall_1: 0.6649
# Epoch 3/40
# 697/697 [==============================] - 112s 161ms/step - loss: 0.0935 - accuracy: 0.7110 - precision_1: 0.2646 - recall_1: 0.8215 - val_loss: 0.5682 - val_accuracy: 0.7067 - val_precision_1: 0.1727 - val_recall_1: 0.6042
# Epoch 4/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0924 - accuracy: 0.7113 - precision_1: 0.2659 - recall_1: 0.8289 - val_loss: 0.5922 - val_accuracy: 0.6925 - val_precision_1: 0.1643 - val_recall_1: 0.5989
# Epoch 5/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0916 - accuracy: 0.7180 - precision_1: 0.2711 - recall_1: 0.8299 - val_loss: 0.5622 - val_accuracy: 0.7069 - val_precision_1: 0.1728 - val_recall_1: 0.6042
# Epoch 6/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0911 - accuracy: 0.7193 - precision_1: 0.2717 - recall_1: 0.8280 - val_loss: 0.5719 - val_accuracy: 0.6944 - val_precision_1: 0.1637 - val_recall_1: 0.5910
# Epoch 7/40
# 697/697 [==============================] - 115s 164ms/step - loss: 0.0908 - accuracy: 0.7216 - precision_1: 0.2736 - recall_1: 0.8286 - val_loss: 0.5637 - val_accuracy: 0.7001 - val_precision_1: 0.1647 - val_recall_1: 0.5805
# Epoch 8/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0900 - accuracy: 0.7246 - precision_1: 0.2759 - recall_1: 0.8286 - val_loss: 0.5437 - val_accuracy: 0.7189 - val_precision_1: 0.1688 - val_recall_1: 0.5488
# Epoch 9/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0903 - accuracy: 0.7200 - precision_1: 0.2725 - recall_1: 0.8297 - val_loss: 0.5847 - val_accuracy: 0.6845 - val_precision_1: 0.1655 - val_recall_1: 0.6280
# Epoch 10/40
# 697/697 [==============================] - 113s 162ms/step - loss: 0.0889 - accuracy: 0.7258 - precision_1: 0.2776 - recall_1: 0.8341 - val_loss: 0.5635 - val_accuracy: 0.7074 - val_precision_1: 0.1655 - val_recall_1: 0.5646
# Epoch 11/40
# 697/697 [==============================] - 111s 159ms/step - loss: 0.0889 - accuracy: 0.7290 - precision_1: 0.2808 - recall_1: 0.8387 - val_loss: 0.5622 - val_accuracy: 0.7031 - val_precision_1: 0.1643 - val_recall_1: 0.5699
# Epoch 12/40
# 697/697 [==============================] - 113s 163ms/step - loss: 0.0880 - accuracy: 0.7309 - precision_1: 0.2820 - recall_1: 0.8356 - val_loss: 0.5753 - val_accuracy: 0.6996 - val_precision_1: 0.1624 - val_recall_1: 0.5699
# Epoch 13/40
# 697/697 [==============================] - 115s 164ms/step - loss: 0.0878 - accuracy: 0.7298 - precision_1: 0.2805 - recall_1: 0.8318 - val_loss: 0.5638 - val_accuracy: 0.7048 - val_precision_1: 0.1667 - val_recall_1: 0.5778
# Epoch 14/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0874 - accuracy: 0.7346 - precision_1: 0.2854 - recall_1: 0.8385 - val_loss: 0.5724 - val_accuracy: 0.6963 - val_precision_1: 0.1577 - val_recall_1: 0.5541
# Epoch 15/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0871 - accuracy: 0.7371 - precision_1: 0.2875 - recall_1: 0.8389 - val_loss: 0.6056 - val_accuracy: 0.6831 - val_precision_1: 0.1558 - val_recall_1: 0.5778
# Epoch 16/40
# 697/697 [==============================] - 112s 161ms/step - loss: 0.0854 - accuracy: 0.7377 - precision_1: 0.2885 - recall_1: 0.8421 - val_loss: 0.5567 - val_accuracy: 0.7116 - val_precision_1: 0.1537 - val_recall_1: 0.4960
# Epoch 17/40
# 697/697 [==============================] - 110s 158ms/step - loss: 0.0853 - accuracy: 0.7427 - precision_1: 0.2927 - recall_1: 0.8414 - val_loss: 0.6123 - val_accuracy: 0.6838 - val_precision_1: 0.1516 - val_recall_1: 0.5541
# Epoch 18/40
# 697/697 [==============================] - 111s 159ms/step - loss: 0.0851 - accuracy: 0.7409 - precision_1: 0.2917 - recall_1: 0.8450 - val_loss: 0.5673 - val_accuracy: 0.7109 - val_precision_1: 0.1685 - val_recall_1: 0.5699
# Epoch 19/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0854 - accuracy: 0.7411 - precision_1: 0.2919 - recall_1: 0.8454 - val_loss: 0.5731 - val_accuracy: 0.7114 - val_precision_1: 0.1570 - val_recall_1: 0.5119
# Epoch 20/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0829 - accuracy: 0.7493 - precision_1: 0.2986 - recall_1: 0.8423 - val_loss: 0.5971 - val_accuracy: 0.7074 - val_precision_1: 0.1592 - val_recall_1: 0.5330
# Epoch 21/40
# 697/697 [==============================] - 114s 164ms/step - loss: 0.0840 - accuracy: 0.7471 - precision_1: 0.2973 - recall_1: 0.8463 - val_loss: 0.5751 - val_accuracy: 0.7125 - val_precision_1: 0.1531 - val_recall_1: 0.4908
# Epoch 22/40
# 697/697 [==============================] - 111s 160ms/step - loss: 0.0831 - accuracy: 0.7523 - precision_1: 0.3022 - recall_1: 0.8479 - val_loss: 0.5381 - val_accuracy: 0.7379 - val_precision_1: 0.1619 - val_recall_1: 0.4644
# Epoch 23/40
# 697/697 [==============================] - 110s 158ms/step - loss: 0.0828 - accuracy: 0.7504 - precision_1: 0.3002 - recall_1: 0.8463 - val_loss: 0.5984 - val_accuracy: 0.6944 - val_precision_1: 0.1515 - val_recall_1: 0.5277
# Epoch 24/40
# 697/697 [==============================] - 129s 185ms/step - loss: 0.0814 - accuracy: 0.7553 - precision_1: 0.3053 - recall_1: 0.8503 - val_loss: 0.5762 - val_accuracy: 0.7116 - val_precision_1: 0.1543 - val_recall_1: 0.4987
# Epoch 25/40
# 697/697 [==============================] - 139s 199ms/step - loss: 0.0818 - accuracy: 0.7545 - precision_1: 0.3048 - recall_1: 0.8521 - val_loss: 0.5633 - val_accuracy: 0.7212 - val_precision_1: 0.1608 - val_recall_1: 0.5040
# Epoch 26/40
# 697/697 [==============================] - 140s 201ms/step - loss: 0.0808 - accuracy: 0.7584 - precision_1: 0.3086 - recall_1: 0.8528 - val_loss: 0.5767 - val_accuracy: 0.7248 - val_precision_1: 0.1599 - val_recall_1: 0.4908
# Epoch 27/40
# 697/697 [==============================] - 142s 204ms/step - loss: 0.0801 - accuracy: 0.7645 - precision_1: 0.3154 - recall_1: 0.8593 - val_loss: 0.5943 - val_accuracy: 0.7100 - val_precision_1: 0.1534 - val_recall_1: 0.4987
# Epoch 28/40
# 697/697 [==============================] - 142s 203ms/step - loss: 0.0788 - accuracy: 0.7655 - precision_1: 0.3169 - recall_1: 0.8628 - val_loss: 0.6171 - val_accuracy: 0.7085 - val_precision_1: 0.1510 - val_recall_1: 0.4908
# Epoch 29/40
# 697/697 [==============================] - 140s 200ms/step - loss: 0.0797 - accuracy: 0.7622 - precision_1: 0.3124 - recall_1: 0.8540 - val_loss: 0.6232 - val_accuracy: 0.6930 - val_precision_1: 0.1492 - val_recall_1: 0.5198
# Epoch 30/40
# 697/697 [==============================] - 142s 204ms/step - loss: 0.0786 - accuracy: 0.7642 - precision_1: 0.3149 - recall_1: 0.8578 - val_loss: 0.6228 - val_accuracy: 0.6963 - val_precision_1: 0.1514 - val_recall_1: 0.5224
# Epoch 31/40
# 697/697 [==============================] - 142s 203ms/step - loss: 0.0793 - accuracy: 0.7650 - precision_1: 0.3154 - recall_1: 0.8559 - val_loss: 0.5665 - val_accuracy: 0.7314 - val_precision_1: 0.1597 - val_recall_1: 0.4723
# Epoch 32/40
# 697/697 [==============================] - 142s 204ms/step - loss: 0.0773 - accuracy: 0.7713 - precision_1: 0.3229 - recall_1: 0.8645 - val_loss: 0.5849 - val_accuracy: 0.7241 - val_precision_1: 0.1530 - val_recall_1: 0.4617
# Epoch 33/40
# 697/697 [==============================] - 141s 203ms/step - loss: 0.0767 - accuracy: 0.7735 - precision_1: 0.3252 - recall_1: 0.8645 - val_loss: 0.5910 - val_accuracy: 0.7267 - val_precision_1: 0.1587 - val_recall_1: 0.4802
# Epoch 34/40
# 697/697 [==============================] - 143s 205ms/step - loss: 0.0782 - accuracy: 0.7668 - precision_1: 0.3178 - recall_1: 0.8601 - val_loss: 0.5884 - val_accuracy: 0.7299 - val_precision_1: 0.1594 - val_recall_1: 0.4749
# Epoch 35/40
# 697/697 [==============================] - 141s 203ms/step - loss: 0.0764 - accuracy: 0.7760 - precision_1: 0.3282 - recall_1: 0.8674 - val_loss: 0.5808 - val_accuracy: 0.7267 - val_precision_1: 0.1622 - val_recall_1: 0.4960
# Epoch 36/40
# 697/697 [==============================] - 141s 203ms/step - loss: 0.0757 - accuracy: 0.7769 - precision_1: 0.3285 - recall_1: 0.8622 - val_loss: 0.6054 - val_accuracy: 0.7259 - val_precision_1: 0.1466 - val_recall_1: 0.4301
# Epoch 37/40
# 697/697 [==============================] - 146s 209ms/step - loss: 0.0761 - accuracy: 0.7778 - precision_1: 0.3299 - recall_1: 0.8664 - val_loss: 0.6044 - val_accuracy: 0.7083 - val_precision_1: 0.1463 - val_recall_1: 0.4697
# Epoch 38/40
# 697/697 [==============================] - 144s 206ms/step - loss: 0.0756 - accuracy: 0.7783 - precision_1: 0.3306 - recall_1: 0.8666 - val_loss: 0.6201 - val_accuracy: 0.7100 - val_precision_1: 0.1579 - val_recall_1: 0.5198
# Epoch 39/40
# 697/697 [==============================] - 143s 205ms/step - loss: 0.0755 - accuracy: 0.7784 - precision_1: 0.3305 - recall_1: 0.8656 - val_loss: 0.5816 - val_accuracy: 0.7309 - val_precision_1: 0.1576 - val_recall_1: 0.4644
# Epoch 40/40
# 697/697 [==============================] - 137s 197ms/step - loss: 0.0750 - accuracy: 0.7815 - precision_1: 0.3342 - recall_1: 0.8681 - val_loss: 0.6029 - val_accuracy: 0.7090 - val_precision_1: 0.1529 - val_recall_1: 0.4987
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [28], line 21
#      19 plt.legend()
#      20 plt.show()
# ---> 21 plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
#      22 plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
#      23 plt.xlabel("epochs")
#
# KeyError: 'precision'

# %%
plt.plot(range(1, epochs + 1), history.history['precision_1'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision_1'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()

plt.plot(range(1, epochs + 1), history.history['recall_1'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall_1'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/transformer_model_ext_weighted_classes_v2.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights("./fine_models/transformer_model_ext_weighted_classes_v2.h5")

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 5s 56ms/step
# 697/697 [==============================] - 35s 51ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.49988238061632556
# Train accuracy: 0.5652261712439418

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.5683368619148436
# Train accuracy: 0.6460240531322923

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.6365561044460127
# Train accuracy: 0.7096347154909352

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7090096447894613
# Train accuracy: 0.7885253993896967

# %%
def ite_term():
    x, y, c = Var(), Var(), Var()
    x_, y_, c_ = Atom(x), Atom(y), Atom(c)
    return Lambda(c, Lambda(x, Lambda(y, multi_app_term(c_, x_, y_))))


def true_term():
    x, y = Var(), Var()
    x_ = Atom(x)
    return Lambda(x, Lambda(y, x_))


def num_zero_term():
    s, z = Var(), Var()
    z_ = Atom(z)
    return Lambda(s, Lambda(z, z_))


def num_term(n: int):
    if n <= 0:
        return num_zero_term()
    s, z = Var(), Var()
    s_, z_ = Atom(s), Atom(z)
    core_term = App(s_, z_)
    for _ in range(n - 1):
        core_term = App(s_, core_term)
    return Lambda(s, Lambda(z, core_term))


def multi_app_term(term_0: Term, term_1: Term, *terms: Term):
    res_app_term = App(term_0, term_1)
    for term in terms:
        res_app_term = App(res_app_term, term)
    return res_app_term


def false_term():
    x, y = Var(), Var()
    y_ = Atom(y)
    return Lambda(x, Lambda(y, y_))


def pair_term():
    x, y, p = Var(), Var(), Var()
    x_, y_, p_ = Atom(x), Atom(y), Atom(p)
    return Lambda(x, Lambda(y, Lambda(p, multi_app_term(p_, x_, y_))))


def first_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(p, App(p_, true_term()))


def second_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(p, App(p_, false_term()))


def succ_term():
    x, y, n = Var(), Var(), Var()
    x_, y_, n_ = Atom(x), Atom(y), Atom(n)
    return Lambda(n, Lambda(x, Lambda(y, App(x_, multi_app_term(n_, x_, y_)))))


def sinc_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(
        p,
        multi_app_term(
            pair_term(),
            App(second_term(), p_),
            App(succ_term(), App(second_term(), p_)),
        ),
    )


def pred_term():
    n, f, x, g, h, u = Var(), Var(), Var(), Var(), Var(), Var()
    n_, f_, x_ = Atom(n), Atom(f), Atom(x)
    g_, h_, u_ = Atom(g), Atom(h), Atom(u)

    return Lambda(n, Lambda(f, Lambda(x, multi_app_term(
        n_,
        Lambda(g, Lambda(h, App(h_, App(g_, f_)))),
        Lambda(u, x_),
        Lambda(u, u_)
    ))))


def plus_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(m, Lambda(n, multi_app_term(n_, succ_term(), m_)))


def subtract_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(n, Lambda(m, multi_app_term(m_, pred_term(), n_)))


def iszero_term():
    x, n = Var(), Var()
    n_ = Atom(n)
    return Lambda(n, App(App(n_, Lambda(x, false_term())), true_term()))


def leq_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(
        n, Lambda(m, App(iszero_term(), multi_app_term(subtract_term(), n_, m_)))
    )


def and_term():
    a, b = Var(), Var()
    a_, b_ = Atom(a), Atom(b)
    return Lambda(a, Lambda(b, multi_app_term(ite_term(), a_, b_, a_)))


def eq_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(
        n,
        Lambda(
            m,
            multi_app_term(
                and_term(),
                multi_app_term(leq_term(), n_, m_),
                multi_app_term(leq_term(), m_, n_),
            ),
        ),
    )


def i_term():
    x = Var()
    x_ = Atom(x)
    return Lambda(x, x_)


def omega_term(n: int):
    x = Var()
    x_ = Atom(x)
    body_app_term = x_
    for _ in range(n - 1):
        body_app_term = App(body_app_term, x_)
    return Lambda(x, body_app_term)


def multi_i_term(m: int):
    app_term = i_term()
    for _ in range(m - 1):
        app_term = App(app_term, i_term())
    return app_term


def omega_multi_i_term(n: int, m: int):
    return App(omega_term(n), multi_i_term(m))


def term_test_1():
    x, y = Var(), Var()
    x_, y_ = Atom(x), Atom(y)

    return "(λx. (λy.y)) ((λx. (xx)) (λx. (xx))) == I == λx. x", \
        App(
            Lambda(x, Lambda(y, y_)),
            App(
                Lambda(x, App(x_, x_)),
                Lambda(x, App(x_, x_))
            )
        )


def term_test_2():
    return "(ITE TRUE 3 1) == 3 == λx. λy. (x (x (x y)))", \
        multi_app_term(ite_term(), true_term(), num_term(3), num_term(1))


def term_test_3():
    return "(ITE FALSE 0 4) == 4 == λx. λy. (x (x (x (x y))))", \
        multi_app_term(ite_term(), false_term(), num_term(0), num_term(4))


def term_test_4():
    return "(PRED 0) == 0 == λx. λy. y", \
        multi_app_term(pred_term(), num_term(0))


def term_test_5():
    return "(PRED 5) == 4 == λx. λy. (x (x (x (x y))))", \
        multi_app_term(pred_term(), num_term(5))


def term_test_6():
    return "(PLUS 0 0) == 0 == λx. λy. y", \
        multi_app_term(plus_term(), num_term(0), num_term(0))


def term_test_7():
    return "(PLUS 2 3) == 5 == λx. λy. (x (x (x (x (x y)))))", \
        multi_app_term(plus_term(), num_term(2), num_term(3))


def term_test_8():
    return "(SUBTRACT 4 1) == 3 == λx. λy. (x (x (x y)))", \
        multi_app_term(subtract_term(), num_term(4), num_term(1))


def term_test_9():
    return "(SUBTRACT 3 5) == 0 == λx. λy. y", \
        multi_app_term(subtract_term(), num_term(3), num_term(5))


def term_test_10():
    return "(LEQ 3 2) == FALSE == λx. λy. y", \
        multi_app_term(leq_term(), num_term(3), num_term(2))


def term_test_11():
    return "(LEQ 2 5) == TRUE == λx. λy. x", \
        multi_app_term(leq_term(), num_term(2), num_term(5))


def term_test_12():
    return "(EQ 2 2) == TRUE == λx. λy. x", \
        multi_app_term(eq_term(), num_term(2), num_term(2))


def term_test_13():
    return "(EQ 1 4) == FALSE == λx. λy. y", \
        multi_app_term(eq_term(), num_term(1), num_term(4))


def term_test_14():
    return "Omega(3, 3)  == I == λx. x", \
        omega_multi_i_term(3, 3)


def term_test_15():
    return "GCD_vO 5 2", \
        multi_app_term(gcd_term_v0(), num_term(5), num_term(2))


def term_test_16():
    return "GCD_v1 5 2", \
        multi_app_term(gcd_term_v1(), num_term(5), num_term(2))


def term_test_17():
    return "GCD_v3 5 2", \
        multi_app_term(gcd_term_v3(), num_term(5), num_term(2))


def term_test_18():
    return "PYTHAGOREAN 5 2 2", \
        multi_app_term(
            pythagorean_term(), num_term(5), num_term(2), num_term(2)
        )


def test_function(term_deskr_: str, term_: Term, model_: Sequential):
    simple_str = term.simple_str()
    simple_str = simple_str.replace("@x.", "y").replace(" ", "")

    tokenized_texts = tokenizer([simple_str], truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")

    prediction_ = model_.predict([tokenized_texts["input_ids"], tokenized_texts["attention_mask"]], verbose=0)

    los = term_.normalize(LOStrategy())[1]
    ris = term_.normalize(RIStrategy())[1]
    res_real =  2 if los == ris else 1 if los > ris else 0
    class_labels = ["LO", "RI", "LO == RI"]
    print(f"{term_deskr_}\nbest real -> {class_labels[res_real]}\tRI best prob = {prediction_[0]}\n")


list_test_functions = (
term_test_1, term_test_2, term_test_3, term_test_4, term_test_5, term_test_6, term_test_7, term_test_9, term_test_10,
term_test_11, term_test_12, term_test_13, term_test_14, term_test_15, term_test_16, term_test_17, term_test_18)

for term_function in list_test_functions:
    term_deskr, term = term_function()
    test_function(term_deskr, term, model)
# Out:
# (λx. (λy.y)) ((λx. (xx)) (λx. (xx))) == I == λx. x
# best real -> LO	RI best prob = [0.33111307]
#
# (ITE TRUE 3 1) == 3 == λx. λy. (x (x (x y)))
# best real -> LO == RI	RI best prob = [0.40297645]
#
# (ITE FALSE 0 4) == 4 == λx. λy. (x (x (x (x y))))
# best real -> LO == RI	RI best prob = [0.31999686]
#
# (PRED 0) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.33103967]
#
# (PRED 5) == 4 == λx. λy. (x (x (x (x y))))
# best real -> LO == RI	RI best prob = [0.7243098]
#
# (PLUS 0 0) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.36918622]
#
# (PLUS 2 3) == 5 == λx. λy. (x (x (x (x (x y)))))
# best real -> LO == RI	RI best prob = [0.6810974]
#
# (SUBTRACT 3 5) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.41911137]
#
# (LEQ 3 2) == FALSE == λx. λy. y
# best real -> LO	RI best prob = [0.16079259]
#
# (LEQ 2 5) == TRUE == λx. λy. x
# best real -> LO == RI	RI best prob = [0.2240379]
#
# (EQ 2 2) == TRUE == λx. λy. x
# best real -> LO	RI best prob = [0.6053524]
#
# (EQ 1 4) == FALSE == λx. λy. y
# best real -> LO	RI best prob = [0.6269777]
#
# Omega(3, 3)  == I == λx. x
# best real -> RI	RI best prob = [0.6742525]
#
# GCD_vO 5 2
# best real -> LO == RI	RI best prob = [0.24462834]
#
# GCD_v1 5 2
# best real -> LO == RI	RI best prob = [0.24462834]
#
# GCD_v3 5 2
# best real -> LO == RI	RI best prob = [0.05106589]
#
# PYTHAGOREAN 5 2 2
# best real -> LO == RI	RI best prob = [0.00176438]
