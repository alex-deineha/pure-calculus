# %% [markdown]
# # Import the dependencies

# %%
import re
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Conv1D, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from transformers import BertConfig
from transformers import RobertaTokenizerFast

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

from matplotlib import pyplot as plt
from matplotlib import rcParams

import sys
import time

sys.path.append("../../../")
from calculus_path_mod.terms.pseudonym import *
from calculus_path_mod.reduction_strategy import *
from calculus_path_mod.terms.arithm_complex_ops import *

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:", physical_devices)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sequence_len = 512
batch_size = 64

config = BertConfig(
    vocab_size=9,
    hidden_size=84,
    num_hidden_layers=2,
    num_attention_heads=6,
    intermediate_size=64,
    max_position_embeddings=sequence_len,
    num_labels=2
)

epochs = 60

# %% [markdown]
# # Load & Prepare the data

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_test = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_test = [1 if los >= ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TESTING samples: {len(y_test)}")
# Out:
# Count all terms: 4251
#
# Count original terms: 4251
#
# max RI steps count: 1000
# max LO steps count: 219
# Count TESTING samples: 4251

# %%
all_data = pd.read_csv("../../article_models_reduct_steps_by_simple_str/data_steps/steps_simple_term_str_extended.csv", delimiter=',')

# leave only unique terms
print(f"Count all terms: {len(all_data)}\n")
all_data = all_data.drop_duplicates(subset="simple_terms").reset_index(drop=True)
print(f"Count original terms: {len(all_data)}\n")

# shuffle the dataset
all_data = shuffle(all_data, random_state=33).reset_index(drop=True)
all_data = all_data.drop_duplicates(["simple_terms"])

print(f"max RI steps count: {max(all_data['RI_steps_num'])}")
print(f"max LO steps count: {max(all_data['LO_steps_num'])}")

x_train = all_data["simple_terms"].tolist()
# RI has fewer steps -> 1
# Otherwise 0
y_train = [1 if los >= ris else 0 for los, ris in zip(all_data["LO_steps_num"].tolist(), all_data["RI_steps_num"].tolist())]

print(f"Count TRAINING samples: {len(y_train)}")
# Out:
# Count all terms: 44568
#
# Count original terms: 44568
#
# max RI steps count: 1000
# max LO steps count: 1000
# Count TRAINING samples: 44568

# %%
counter = Counter(y_test)
print(f"Test Distribution: {counter}")
counter = Counter(y_train)
print(f"Test Distribution: {counter}")
# Out:
# Test Distribution: Counter({0: 2395, 1: 1856})
# Test Distribution: Counter({0: 25769, 1: 18799})

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("../../transformers_to_lo_steps_prediciton/fine_models", max_len=sequence_len)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
x_train = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_train]
x_test = [x_.replace("@x.", "y").replace(" ", "") for x_ in x_test]

train_df = pd.DataFrame({"term_str": x_train, "is_ri_best": y_train})
test_df = pd.DataFrame({"term_str": x_test, "is_ri_best": y_test})

def preprocess(example):
    # Tokenize the prompt
    tokenized_texts = tokenizer(example['term_str'].to_list(), truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")
    labels = tf.convert_to_tensor(example["is_ri_best"])
    return tokenized_texts, labels


tokenized_train_data = preprocess(train_df)
tokenized_test_data = preprocess(test_df)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_train_data[0]), tokenized_train_data[1])).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(tokenized_test_data[0]), tokenized_test_data[1])).batch(batch_size)

# %% [markdown]
# # Define the model

# %%
from transformers import TFBertModel
from keras.layers import Dense, Input, Flatten, AveragePooling1D, Dropout
from keras.models import Model

bert = TFBertModel(config=config)
bert.build()

input_ids_in = Input(shape=(sequence_len,), name='input_ids', dtype='int32')
input_masks_in = Input(shape=(sequence_len,), name='attention_mask', dtype='int32')

embedding_layer = bert(input_ids_in, attention_mask=input_masks_in)[0]
outputs = AveragePooling1D(pool_size=50)(embedding_layer)
outputs = Flatten()(outputs)
outputs = Dropout(rate=0.1)(outputs)
outputs = Dense(units=1, activation="sigmoid")(outputs)
model = Model(inputs=[input_ids_in, input_masks_in], outputs=outputs)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy', tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 512)]        0           []
#
#  attention_mask (InputLayer)    [(None, 512)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  130832      ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 512,
#                                  84),
#                                  pooler_output=(Non
#                                 e, 84),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  average_pooling1d (AveragePool  (None, 10, 84)      0           ['tf_bert_model[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 840)          0           ['average_pooling1d[0][0]']
#
#  dropout_7 (Dropout)            (None, 840)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 1)            841         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 131,673
# Trainable params: 131,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_structure = model.to_json()
with open("./fine_models/transformer_model_RI_ext.json", 'w') as json_file:
    json_file.write(model_structure)

# %%
# Define the ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath='./fine_models/transformer_model_RI_ext.h5',  # Specify the path to save the best model
    monitor='val_accuracy',  # Metric to monitor (e.g., validation loss)
    save_best_only=True,  # Save only the best model
    mode='max',  # 'min' or 'max' depending on the monitored metric
    verbose=0  # Print a message when saving the model
)

# %%
# class_weights = {
#     0: 0.5,
#     1: 0.5,
# }
# history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1, callbacks=[checkpoint_callback], class_weight=class_weights)

history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, verbose=1, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/60
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 697/697 [==============================] - 120s 166ms/step - loss: 0.5625 - accuracy: 0.7192 - precision: 0.7125 - recall: 0.5604 - val_loss: 0.5491 - val_accuracy: 0.7092 - val_precision: 0.6580 - val_recall: 0.6956
# Epoch 2/60
# 697/697 [==============================] - 116s 166ms/step - loss: 0.5376 - accuracy: 0.7364 - precision: 0.7384 - recall: 0.5808 - val_loss: 0.5433 - val_accuracy: 0.7175 - val_precision: 0.6710 - val_recall: 0.6923
# Epoch 3/60
# 697/697 [==============================] - 115s 165ms/step - loss: 0.5263 - accuracy: 0.7423 - precision: 0.7463 - recall: 0.5895 - val_loss: 0.5315 - val_accuracy: 0.7295 - val_precision: 0.7001 - val_recall: 0.6654
# Epoch 4/60
# 697/697 [==============================] - 115s 165ms/step - loss: 0.5216 - accuracy: 0.7439 - precision: 0.7480 - recall: 0.5926 - val_loss: 0.5288 - val_accuracy: 0.7332 - val_precision: 0.7096 - val_recall: 0.6584
# Epoch 5/60
# 697/697 [==============================] - 116s 166ms/step - loss: 0.5189 - accuracy: 0.7454 - precision: 0.7484 - recall: 0.5971 - val_loss: 0.5311 - val_accuracy: 0.7349 - val_precision: 0.7101 - val_recall: 0.6638
# Epoch 6/60
# 697/697 [==============================] - 114s 164ms/step - loss: 0.5152 - accuracy: 0.7469 - precision: 0.7492 - recall: 0.6012 - val_loss: 0.5353 - val_accuracy: 0.7257 - val_precision: 0.6958 - val_recall: 0.6606
# Epoch 7/60
# 697/697 [==============================] - 116s 166ms/step - loss: 0.5126 - accuracy: 0.7482 - precision: 0.7504 - recall: 0.6038 - val_loss: 0.5292 - val_accuracy: 0.7358 - val_precision: 0.7191 - val_recall: 0.6482
# Epoch 8/60
# 697/697 [==============================] - 119s 170ms/step - loss: 0.5099 - accuracy: 0.7486 - precision: 0.7498 - recall: 0.6064 - val_loss: 0.5359 - val_accuracy: 0.7316 - val_precision: 0.7044 - val_recall: 0.6638
# Epoch 9/60
# 697/697 [==============================] - 112s 160ms/step - loss: 0.5069 - accuracy: 0.7510 - precision: 0.7527 - recall: 0.6100 - val_loss: 0.5341 - val_accuracy: 0.7361 - val_precision: 0.7190 - val_recall: 0.6492
# Epoch 10/60
# 697/697 [==============================] - 114s 163ms/step - loss: 0.5042 - accuracy: 0.7511 - precision: 0.7523 - recall: 0.6112 - val_loss: 0.5305 - val_accuracy: 0.7337 - val_precision: 0.7165 - val_recall: 0.6455
# Epoch 11/60
# 697/697 [==============================] - 115s 165ms/step - loss: 0.5017 - accuracy: 0.7527 - precision: 0.7514 - recall: 0.6184 - val_loss: 0.5355 - val_accuracy: 0.7311 - val_precision: 0.7067 - val_recall: 0.6568
# Epoch 12/60
# 697/697 [==============================] - 125s 180ms/step - loss: 0.4996 - accuracy: 0.7546 - precision: 0.7534 - recall: 0.6216 - val_loss: 0.5281 - val_accuracy: 0.7365 - val_precision: 0.7297 - val_recall: 0.6298
# Epoch 13/60
# 697/697 [==============================] - 121s 173ms/step - loss: 0.4967 - accuracy: 0.7544 - precision: 0.7512 - recall: 0.6248 - val_loss: 0.5391 - val_accuracy: 0.7314 - val_precision: 0.7076 - val_recall: 0.6557
# Epoch 14/60
# 697/697 [==============================] - 121s 174ms/step - loss: 0.4941 - accuracy: 0.7565 - precision: 0.7537 - recall: 0.6279 - val_loss: 0.5388 - val_accuracy: 0.7351 - val_precision: 0.7253 - val_recall: 0.6331
# Epoch 15/60
# 697/697 [==============================] - 123s 176ms/step - loss: 0.4922 - accuracy: 0.7588 - precision: 0.7562 - recall: 0.6320 - val_loss: 0.5437 - val_accuracy: 0.7365 - val_precision: 0.7326 - val_recall: 0.6245
# Epoch 16/60
# 697/697 [==============================] - 126s 181ms/step - loss: 0.4897 - accuracy: 0.7610 - precision: 0.7576 - recall: 0.6373 - val_loss: 0.5345 - val_accuracy: 0.7375 - val_precision: 0.7507 - val_recall: 0.5970
# Epoch 17/60
# 697/697 [==============================] - 123s 176ms/step - loss: 0.4869 - accuracy: 0.7615 - precision: 0.7578 - recall: 0.6389 - val_loss: 0.5484 - val_accuracy: 0.7325 - val_precision: 0.7309 - val_recall: 0.6131
# Epoch 18/60
# 697/697 [==============================] - 121s 174ms/step - loss: 0.4850 - accuracy: 0.7617 - precision: 0.7551 - recall: 0.6440 - val_loss: 0.5382 - val_accuracy: 0.7321 - val_precision: 0.7225 - val_recall: 0.6272
# Epoch 19/60
# 697/697 [==============================] - 121s 173ms/step - loss: 0.4806 - accuracy: 0.7658 - precision: 0.7617 - recall: 0.6473 - val_loss: 0.5503 - val_accuracy: 0.7351 - val_precision: 0.7340 - val_recall: 0.6169
# Epoch 20/60
# 697/697 [==============================] - 119s 171ms/step - loss: 0.4796 - accuracy: 0.7651 - precision: 0.7589 - recall: 0.6494 - val_loss: 0.5399 - val_accuracy: 0.7330 - val_precision: 0.7304 - val_recall: 0.6158
# Epoch 21/60
# 697/697 [==============================] - 120s 172ms/step - loss: 0.4778 - accuracy: 0.7676 - precision: 0.7628 - recall: 0.6515 - val_loss: 0.5548 - val_accuracy: 0.7344 - val_precision: 0.7350 - val_recall: 0.6126
# Epoch 22/60
# 697/697 [==============================] - 123s 176ms/step - loss: 0.4770 - accuracy: 0.7686 - precision: 0.7637 - recall: 0.6536 - val_loss: 0.5590 - val_accuracy: 0.7302 - val_precision: 0.7096 - val_recall: 0.6466
# Epoch 23/60
# 697/697 [==============================] - 122s 176ms/step - loss: 0.4747 - accuracy: 0.7693 - precision: 0.7636 - recall: 0.6561 - val_loss: 0.5521 - val_accuracy: 0.7297 - val_precision: 0.7214 - val_recall: 0.6207
# Epoch 24/60
# 697/697 [==============================] - 122s 175ms/step - loss: 0.4727 - accuracy: 0.7708 - precision: 0.7645 - recall: 0.6598 - val_loss: 0.5607 - val_accuracy: 0.7316 - val_precision: 0.7208 - val_recall: 0.6288
# Epoch 25/60
# 697/697 [==============================] - 122s 175ms/step - loss: 0.4697 - accuracy: 0.7701 - precision: 0.7631 - recall: 0.6600 - val_loss: 0.5630 - val_accuracy: 0.7311 - val_precision: 0.7238 - val_recall: 0.6212
# Epoch 26/60
# 697/697 [==============================] - 121s 173ms/step - loss: 0.4674 - accuracy: 0.7735 - precision: 0.7660 - recall: 0.6666 - val_loss: 0.5739 - val_accuracy: 0.7330 - val_precision: 0.7184 - val_recall: 0.6390
# Epoch 27/60
# 697/697 [==============================] - 123s 176ms/step - loss: 0.4664 - accuracy: 0.7735 - precision: 0.7659 - recall: 0.6669 - val_loss: 0.5675 - val_accuracy: 0.7339 - val_precision: 0.7239 - val_recall: 0.6315
# Epoch 28/60
# 697/697 [==============================] - 120s 173ms/step - loss: 0.4632 - accuracy: 0.7764 - precision: 0.7684 - recall: 0.6726 - val_loss: 0.5715 - val_accuracy: 0.7337 - val_precision: 0.7181 - val_recall: 0.6422
# Epoch 29/60
# 697/697 [==============================] - 114s 164ms/step - loss: 0.4624 - accuracy: 0.7761 - precision: 0.7693 - recall: 0.6701 - val_loss: 0.5808 - val_accuracy: 0.7241 - val_precision: 0.6966 - val_recall: 0.6519
# Epoch 30/60
# 697/697 [==============================] - 114s 163ms/step - loss: 0.4590 - accuracy: 0.7780 - precision: 0.7700 - recall: 0.6755 - val_loss: 0.5648 - val_accuracy: 0.7339 - val_precision: 0.7296 - val_recall: 0.6207
# Epoch 31/60
# 697/697 [==============================] - 114s 163ms/step - loss: 0.4577 - accuracy: 0.7787 - precision: 0.7711 - recall: 0.6760 - val_loss: 0.5785 - val_accuracy: 0.7295 - val_precision: 0.7055 - val_recall: 0.6530
# Epoch 32/60
# 697/697 [==============================] - 114s 164ms/step - loss: 0.4566 - accuracy: 0.7785 - precision: 0.7716 - recall: 0.6745 - val_loss: 0.5642 - val_accuracy: 0.7325 - val_precision: 0.7294 - val_recall: 0.6158
# Epoch 33/60
# 697/697 [==============================] - 114s 163ms/step - loss: 0.4531 - accuracy: 0.7813 - precision: 0.7725 - recall: 0.6826 - val_loss: 0.5776 - val_accuracy: 0.7332 - val_precision: 0.7256 - val_recall: 0.6255
# Epoch 34/60
# 697/697 [==============================] - 116s 166ms/step - loss: 0.4533 - accuracy: 0.7805 - precision: 0.7721 - recall: 0.6805 - val_loss: 0.5794 - val_accuracy: 0.7375 - val_precision: 0.7342 - val_recall: 0.6250
# Epoch 35/60
# 697/697 [==============================] - 121s 174ms/step - loss: 0.4499 - accuracy: 0.7833 - precision: 0.7759 - recall: 0.6836 - val_loss: 0.5748 - val_accuracy: 0.7257 - val_precision: 0.7093 - val_recall: 0.6298
# Epoch 36/60
# 697/697 [==============================] - 120s 172ms/step - loss: 0.4488 - accuracy: 0.7830 - precision: 0.7752 - recall: 0.6840 - val_loss: 0.5903 - val_accuracy: 0.7262 - val_precision: 0.6982 - val_recall: 0.6568
# Epoch 37/60
# 697/697 [==============================] - 119s 171ms/step - loss: 0.4474 - accuracy: 0.7831 - precision: 0.7747 - recall: 0.6848 - val_loss: 0.5887 - val_accuracy: 0.7250 - val_precision: 0.7122 - val_recall: 0.6212
# Epoch 38/60
# 697/697 [==============================] - 118s 169ms/step - loss: 0.4458 - accuracy: 0.7855 - precision: 0.7755 - recall: 0.6917 - val_loss: 0.5915 - val_accuracy: 0.7276 - val_precision: 0.7246 - val_recall: 0.6067
# Epoch 39/60
# 697/697 [==============================] - 126s 181ms/step - loss: 0.4436 - accuracy: 0.7864 - precision: 0.7757 - recall: 0.6943 - val_loss: 0.5885 - val_accuracy: 0.7325 - val_precision: 0.7265 - val_recall: 0.6212
# Epoch 40/60
# 697/697 [==============================] - 128s 183ms/step - loss: 0.4391 - accuracy: 0.7896 - precision: 0.7815 - recall: 0.6958 - val_loss: 0.5931 - val_accuracy: 0.7208 - val_precision: 0.7129 - val_recall: 0.6034
# Epoch 41/60
# 697/697 [==============================] - 119s 171ms/step - loss: 0.4375 - accuracy: 0.7907 - precision: 0.7829 - recall: 0.6972 - val_loss: 0.5990 - val_accuracy: 0.7241 - val_precision: 0.7034 - val_recall: 0.6363
# Epoch 42/60
# 697/697 [==============================] - 119s 170ms/step - loss: 0.4368 - accuracy: 0.7907 - precision: 0.7828 - recall: 0.6975 - val_loss: 0.5910 - val_accuracy: 0.7299 - val_precision: 0.7224 - val_recall: 0.6196
# Epoch 43/60
# 697/697 [==============================] - 118s 169ms/step - loss: 0.4364 - accuracy: 0.7899 - precision: 0.7804 - recall: 0.6984 - val_loss: 0.5966 - val_accuracy: 0.7262 - val_precision: 0.7198 - val_recall: 0.6105
# Epoch 44/60
# 697/697 [==============================] - 108s 155ms/step - loss: 0.4319 - accuracy: 0.7931 - precision: 0.7836 - recall: 0.7037 - val_loss: 0.5883 - val_accuracy: 0.7309 - val_precision: 0.7282 - val_recall: 0.6121
# Epoch 45/60
# 697/697 [==============================] - 108s 155ms/step - loss: 0.4304 - accuracy: 0.7963 - precision: 0.7884 - recall: 0.7066 - val_loss: 0.5978 - val_accuracy: 0.7281 - val_precision: 0.7249 - val_recall: 0.6078
# Epoch 46/60
# 697/697 [==============================] - 110s 158ms/step - loss: 0.4299 - accuracy: 0.7941 - precision: 0.7842 - recall: 0.7061 - val_loss: 0.5887 - val_accuracy: 0.7236 - val_precision: 0.7137 - val_recall: 0.6126
# Epoch 47/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4263 - accuracy: 0.7972 - precision: 0.7893 - recall: 0.7082 - val_loss: 0.6069 - val_accuracy: 0.7259 - val_precision: 0.7163 - val_recall: 0.6164
# Epoch 48/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4250 - accuracy: 0.7958 - precision: 0.7866 - recall: 0.7080 - val_loss: 0.6099 - val_accuracy: 0.7238 - val_precision: 0.7105 - val_recall: 0.6202
# Epoch 49/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4232 - accuracy: 0.7986 - precision: 0.7891 - recall: 0.7130 - val_loss: 0.6095 - val_accuracy: 0.7245 - val_precision: 0.7166 - val_recall: 0.6105
# Epoch 50/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4208 - accuracy: 0.8015 - precision: 0.7912 - recall: 0.7192 - val_loss: 0.5916 - val_accuracy: 0.7250 - val_precision: 0.7162 - val_recall: 0.6131
# Epoch 51/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4188 - accuracy: 0.8007 - precision: 0.7907 - recall: 0.7173 - val_loss: 0.6111 - val_accuracy: 0.7255 - val_precision: 0.7146 - val_recall: 0.6180
# Epoch 52/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4173 - accuracy: 0.8008 - precision: 0.7918 - recall: 0.7159 - val_loss: 0.6069 - val_accuracy: 0.7224 - val_precision: 0.7142 - val_recall: 0.6072
# Epoch 53/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4164 - accuracy: 0.8012 - precision: 0.7912 - recall: 0.7182 - val_loss: 0.6100 - val_accuracy: 0.7278 - val_precision: 0.7087 - val_recall: 0.6395
# Epoch 54/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4137 - accuracy: 0.8027 - precision: 0.7922 - recall: 0.7216 - val_loss: 0.6240 - val_accuracy: 0.7241 - val_precision: 0.7032 - val_recall: 0.6369
# Epoch 55/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4120 - accuracy: 0.8044 - precision: 0.7947 - recall: 0.7232 - val_loss: 0.6189 - val_accuracy: 0.7234 - val_precision: 0.7136 - val_recall: 0.6121
# Epoch 56/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4103 - accuracy: 0.8047 - precision: 0.7936 - recall: 0.7256 - val_loss: 0.6271 - val_accuracy: 0.7264 - val_precision: 0.7167 - val_recall: 0.6175
# Epoch 57/60
# 697/697 [==============================] - 111s 159ms/step - loss: 0.4101 - accuracy: 0.8048 - precision: 0.7940 - recall: 0.7254 - val_loss: 0.6407 - val_accuracy: 0.7187 - val_precision: 0.7118 - val_recall: 0.5975
# Epoch 58/60
# 697/697 [==============================] - 114s 163ms/step - loss: 0.4093 - accuracy: 0.8055 - precision: 0.7948 - recall: 0.7265 - val_loss: 0.6405 - val_accuracy: 0.7201 - val_precision: 0.7168 - val_recall: 0.5932
# Epoch 59/60
# 697/697 [==============================] - 113s 162ms/step - loss: 0.4055 - accuracy: 0.8091 - precision: 0.7998 - recall: 0.7303 - val_loss: 0.6668 - val_accuracy: 0.7100 - val_precision: 0.6910 - val_recall: 0.6072
# Epoch 60/60
# 697/697 [==============================] - 111s 160ms/step - loss: 0.4055 - accuracy: 0.8076 - precision: 0.7978 - recall: 0.7285 - val_loss: 0.6363 - val_accuracy: 0.7217 - val_precision: 0.7051 - val_recall: 0.6234

# %%
plt.plot(range(1, epochs + 1), history.history['loss'], label="loss")
plt.plot(range(1, epochs + 1), history.history['val_loss'], label="val_loss")
plt.xlabel("epochs")
plt.title("total loss")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['accuracy'], label="accuracy")
plt.plot(range(1, epochs + 1), history.history['val_accuracy'], label="val_accuracy")
plt.xlabel("epochs")
plt.title("total accuracy")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['precision'], label="precision")
plt.plot(range(1, epochs + 1), history.history['val_precision'], label="val_precision")
plt.xlabel("epochs")
plt.title("total precision")

plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history.history['recall'], label="recall")
plt.plot(range(1, epochs + 1), history.history['val_recall'], label="val_recall")
plt.xlabel("epochs")
plt.title("total recall")

plt.legend()
plt.show()

# %%
def calculate_accuracy(actual_labels, predicted_labels):
    correct_predictions = sum(1 for actual, predicted in zip(actual_labels, predicted_labels) if actual == predicted)
    total_predictions = len(actual_labels)
    accuracy = correct_predictions / total_predictions
    return accuracy


from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes, class_labels, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix of a classification model.

    Args:
        y_true (numpy.ndarray): The ground truth labels.
        y_pred (numpy.ndarray): The predicted labels.
        classes (list): The list of class labels.
        class_labels: The list of class names.
        normalize (bool, optional): Whether to normalize the confusion matrix. Defaults to False.
        title (str, optional): The title of the plot. Defaults to None.
        cmap (matplotlib.colors.Colormap, optional): The colormap to use for the plot. Defaults to plt.cm.Blues.
    """

    cm = confusion_matrix(y_true, y_pred, labels=classes)

    if normalize:
        cm = confusion_matrix(y_true, y_pred, labels=classes).astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(class_labels)
    ax.set_yticklabels(class_labels)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_title(title)
    fig.colorbar(im)

    thresh = cm.max() / 2.
    for i in range(len(classes)):
        for j in range(len(classes)):
            ij = float(cm[i, j])
            ax.text(j, i, f"{ij:.2f}", ha='center', va='center', color='white' if ij > thresh else 'black')

    plt.tight_layout()
    plt.show()

# %%
# load the model
from transformers import TFBertModel

with open("./fine_models/transformer_model_RI_ext.json", "r") as file:
    loaded_model_json = file.read()

model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={"TFBertModel": TFBertModel})
model.load_weights("./fine_models/transformer_model_RI_ext.h5")

# %%
y_test_pred = model.predict(test_dataset)
y_train_pred = model.predict(train_dataset)

y_test_nums = y_test
y_train_nums = y_train
# Out:
# 67/67 [==============================] - 4s 51ms/step
# 697/697 [==============================] - 35s 50ms/step

# %%
THRESHOLD = 0.15

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.5615149376617267
# Train accuracy: 0.5996454855501705

# %%
THRESHOLD = 0.25

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.6389084921195013
# Train accuracy: 0.6994704720875965

# %%
THRESHOLD = 0.35

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7038343919077864
# Train accuracy: 0.7488556812062467

# %%
THRESHOLD = 0.5

y_test_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_test_pred]
y_train_pred_nums = [0 if x_ < THRESHOLD else 1 for x_ in y_train_pred]

print("Test accuracy:", calculate_accuracy(y_test_nums, y_test_pred_nums))
plot_confusion_matrix(y_test_nums, y_test_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")

print("Train accuracy:", calculate_accuracy(y_train_nums, y_train_pred_nums))
plot_confusion_matrix(y_train_nums, y_train_pred_nums, classes=[0, 1], class_labels=["LO", "RI"], normalize=True, title=f"Test set, threshold={THRESHOLD}")
# Out:
# Test accuracy: 0.7374735356386732
# Train accuracy: 0.7653922096571532

# %%
def ite_term():
    x, y, c = Var(), Var(), Var()
    x_, y_, c_ = Atom(x), Atom(y), Atom(c)
    return Lambda(c, Lambda(x, Lambda(y, multi_app_term(c_, x_, y_))))


def true_term():
    x, y = Var(), Var()
    x_ = Atom(x)
    return Lambda(x, Lambda(y, x_))


def num_zero_term():
    s, z = Var(), Var()
    z_ = Atom(z)
    return Lambda(s, Lambda(z, z_))


def num_term(n: int):
    if n <= 0:
        return num_zero_term()
    s, z = Var(), Var()
    s_, z_ = Atom(s), Atom(z)
    core_term = App(s_, z_)
    for _ in range(n - 1):
        core_term = App(s_, core_term)
    return Lambda(s, Lambda(z, core_term))


def multi_app_term(term_0: Term, term_1: Term, *terms: Term):
    res_app_term = App(term_0, term_1)
    for term in terms:
        res_app_term = App(res_app_term, term)
    return res_app_term


def false_term():
    x, y = Var(), Var()
    y_ = Atom(y)
    return Lambda(x, Lambda(y, y_))


def pair_term():
    x, y, p = Var(), Var(), Var()
    x_, y_, p_ = Atom(x), Atom(y), Atom(p)
    return Lambda(x, Lambda(y, Lambda(p, multi_app_term(p_, x_, y_))))


def first_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(p, App(p_, true_term()))


def second_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(p, App(p_, false_term()))


def succ_term():
    x, y, n = Var(), Var(), Var()
    x_, y_, n_ = Atom(x), Atom(y), Atom(n)
    return Lambda(n, Lambda(x, Lambda(y, App(x_, multi_app_term(n_, x_, y_)))))


def sinc_term():
    p = Var()
    p_ = Atom(p)
    return Lambda(
        p,
        multi_app_term(
            pair_term(),
            App(second_term(), p_),
            App(succ_term(), App(second_term(), p_)),
        ),
    )


def pred_term():
    n, f, x, g, h, u = Var(), Var(), Var(), Var(), Var(), Var()
    n_, f_, x_ = Atom(n), Atom(f), Atom(x)
    g_, h_, u_ = Atom(g), Atom(h), Atom(u)

    return Lambda(n, Lambda(f, Lambda(x, multi_app_term(
        n_,
        Lambda(g, Lambda(h, App(h_, App(g_, f_)))),
        Lambda(u, x_),
        Lambda(u, u_)
    ))))


def plus_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(m, Lambda(n, multi_app_term(n_, succ_term(), m_)))


def subtract_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(n, Lambda(m, multi_app_term(m_, pred_term(), n_)))


def iszero_term():
    x, n = Var(), Var()
    n_ = Atom(n)
    return Lambda(n, App(App(n_, Lambda(x, false_term())), true_term()))


def leq_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(
        n, Lambda(m, App(iszero_term(), multi_app_term(subtract_term(), n_, m_)))
    )


def and_term():
    a, b = Var(), Var()
    a_, b_ = Atom(a), Atom(b)
    return Lambda(a, Lambda(b, multi_app_term(ite_term(), a_, b_, a_)))


def eq_term():
    n, m = Var(), Var()
    n_, m_ = Atom(n), Atom(m)
    return Lambda(
        n,
        Lambda(
            m,
            multi_app_term(
                and_term(),
                multi_app_term(leq_term(), n_, m_),
                multi_app_term(leq_term(), m_, n_),
            ),
        ),
    )


def i_term():
    x = Var()
    x_ = Atom(x)
    return Lambda(x, x_)


def omega_term(n: int):
    x = Var()
    x_ = Atom(x)
    body_app_term = x_
    for _ in range(n - 1):
        body_app_term = App(body_app_term, x_)
    return Lambda(x, body_app_term)


def multi_i_term(m: int):
    app_term = i_term()
    for _ in range(m - 1):
        app_term = App(app_term, i_term())
    return app_term


def omega_multi_i_term(n: int, m: int):
    return App(omega_term(n), multi_i_term(m))


def term_test_1():
    x, y = Var(), Var()
    x_, y_ = Atom(x), Atom(y)

    return "(λx. (λy.y)) ((λx. (xx)) (λx. (xx))) == I == λx. x", \
        App(
            Lambda(x, Lambda(y, y_)),
            App(
                Lambda(x, App(x_, x_)),
                Lambda(x, App(x_, x_))
            )
        )


def term_test_2():
    return "(ITE TRUE 3 1) == 3 == λx. λy. (x (x (x y)))", \
        multi_app_term(ite_term(), true_term(), num_term(3), num_term(1))


def term_test_3():
    return "(ITE FALSE 0 4) == 4 == λx. λy. (x (x (x (x y))))", \
        multi_app_term(ite_term(), false_term(), num_term(0), num_term(4))


def term_test_4():
    return "(PRED 0) == 0 == λx. λy. y", \
        multi_app_term(pred_term(), num_term(0))


def term_test_5():
    return "(PRED 5) == 4 == λx. λy. (x (x (x (x y))))", \
        multi_app_term(pred_term(), num_term(5))


def term_test_6():
    return "(PLUS 0 0) == 0 == λx. λy. y", \
        multi_app_term(plus_term(), num_term(0), num_term(0))


def term_test_7():
    return "(PLUS 2 3) == 5 == λx. λy. (x (x (x (x (x y)))))", \
        multi_app_term(plus_term(), num_term(2), num_term(3))


def term_test_8():
    return "(SUBTRACT 4 1) == 3 == λx. λy. (x (x (x y)))", \
        multi_app_term(subtract_term(), num_term(4), num_term(1))


def term_test_9():
    return "(SUBTRACT 3 5) == 0 == λx. λy. y", \
        multi_app_term(subtract_term(), num_term(3), num_term(5))


def term_test_10():
    return "(LEQ 3 2) == FALSE == λx. λy. y", \
        multi_app_term(leq_term(), num_term(3), num_term(2))


def term_test_11():
    return "(LEQ 2 5) == TRUE == λx. λy. x", \
        multi_app_term(leq_term(), num_term(2), num_term(5))


def term_test_12():
    return "(EQ 2 2) == TRUE == λx. λy. x", \
        multi_app_term(eq_term(), num_term(2), num_term(2))


def term_test_13():
    return "(EQ 1 4) == FALSE == λx. λy. y", \
        multi_app_term(eq_term(), num_term(1), num_term(4))


def term_test_14():
    return "Omega(3, 3)  == I == λx. x", \
        omega_multi_i_term(3, 3)


def term_test_15():
    return "GCD_vO 5 2", \
        multi_app_term(gcd_term_v0(), num_term(5), num_term(2))


def term_test_16():
    return "GCD_v1 5 2", \
        multi_app_term(gcd_term_v1(), num_term(5), num_term(2))


def term_test_17():
    return "GCD_v3 5 2", \
        multi_app_term(gcd_term_v3(), num_term(5), num_term(2))


def term_test_18():
    return "PYTHAGOREAN 5 2 2", \
        multi_app_term(
            pythagorean_term(), num_term(5), num_term(2), num_term(2)
        )


def test_function(term_deskr_: str, term_: Term, model_: Sequential):
    simple_str = term.simple_str()
    simple_str = simple_str.replace("@x.", "y").replace(" ", "")

    tokenized_texts = tokenizer([simple_str], truncation=True, padding='max_length', max_length=sequence_len, return_tensors="tf")

    prediction_ = model_.predict([tokenized_texts["input_ids"], tokenized_texts["attention_mask"]], verbose=0)

    los = term_.normalize(LOStrategy())[1]
    ris = term_.normalize(RIStrategy())[1]
    res_real =  2 if los == ris else 1 if los > ris else 0
    class_labels = ["LO", "RI", "LO == RI"]
    print(f"{term_deskr_}\nbest real -> {class_labels[res_real]}\tRI best prob = {prediction_[0]}\n")


list_test_functions = (
term_test_1, term_test_2, term_test_3, term_test_4, term_test_5, term_test_6, term_test_7, term_test_9, term_test_10,
term_test_11, term_test_12, term_test_13, term_test_14, term_test_15, term_test_16, term_test_17, term_test_18)

for term_function in list_test_functions:
    term_deskr, term = term_function()
    test_function(term_deskr, term, model)
# Out:
# (λx. (λy.y)) ((λx. (xx)) (λx. (xx))) == I == λx. x
# best real -> LO	RI best prob = [0.7849613]
#
# (ITE TRUE 3 1) == 3 == λx. λy. (x (x (x y)))
# best real -> LO == RI	RI best prob = [0.6606508]
#
# (ITE FALSE 0 4) == 4 == λx. λy. (x (x (x (x y))))
# best real -> LO == RI	RI best prob = [0.6842413]
#
# (PRED 0) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.6972505]
#
# (PRED 5) == 4 == λx. λy. (x (x (x (x y))))
# best real -> LO == RI	RI best prob = [0.51457924]
#
# (PLUS 0 0) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.7852083]
#
# (PLUS 2 3) == 5 == λx. λy. (x (x (x (x (x y)))))
# best real -> LO == RI	RI best prob = [0.851196]
#
# (SUBTRACT 3 5) == 0 == λx. λy. y
# best real -> LO == RI	RI best prob = [0.47311836]
#
# (LEQ 3 2) == FALSE == λx. λy. y
# best real -> LO	RI best prob = [0.07773789]
#
# (LEQ 2 5) == TRUE == λx. λy. x
# best real -> LO == RI	RI best prob = [0.10101834]
#
# (EQ 2 2) == TRUE == λx. λy. x
# best real -> LO	RI best prob = [0.18871848]
#
# (EQ 1 4) == FALSE == λx. λy. y
# best real -> LO	RI best prob = [0.26610875]
#
# Omega(3, 3)  == I == λx. x
# best real -> RI	RI best prob = [0.9445516]
#
# GCD_vO 5 2
# best real -> LO == RI	RI best prob = [0.0450815]
#
# GCD_v1 5 2
# best real -> LO == RI	RI best prob = [0.0450815]
#
# GCD_v3 5 2
# best real -> LO == RI	RI best prob = [0.02639254]
#
# PYTHAGOREAN 5 2 2
# best real -> LO == RI	RI best prob = [0.02141309]
